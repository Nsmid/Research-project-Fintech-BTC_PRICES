# %% [markdown]
# # Research Project

# %% [markdown]
# #### Finding data
# - BTC price from API? or from different sources
# - Oil, Gold, S&P 500 from Yahoo/Crsp/FactSet?
# - Google trend - we can find google trend also through api --> pytrends: https://pypi.org/project/pytrends/
# - Inflation, Interest rate in the US - CRSP or some other webpage with reliable info
# + Deciding whether we will use returns/ prices/ so on :)

# %%
#pip install pandas-datareader

# %%
import pandas_datareader.data as web
import pandas as pd
import datetime as dt
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.formula.api import ols
from statsmodels.tsa.api import VAR
from statsmodels.tools.eval_measures import rmse, aic
from sklearn.preprocessing import StandardScaler

# %%
# yahoo finance data
df1 = web.DataReader(['GC=F', 'CL=F', '^GSPC'], 'yahoo', start='2019-12-31', end='2022-01-18')["Adj Close"]
df1.rename(columns={'GC=F': 'GOLD', 'CL=F': 'OIL', '^GSPC': 'SP500'}, inplace=True)

# %%
# df1.tail()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 518 entries, 2019-12-31 to 2022-01-18
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GOLD    518 non-null    float64
#  1   OIL     518 non-null    float64
#  2   SP500   517 non-null    float64
# dtypes: float64(3)
# memory usage: 16.2 KB

# %%
returns = df1.copy()
for i in range(1,len(df1+1)):
    returns.iloc[i] = np.log(df1.iloc[i]/df1.iloc[i-1])
returns = returns[1:]
# Out:
# /Users/nezasmid/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# effective federal funds rate (https://fred.stlouisfed.org/series/EFFR)
df2 = web.DataReader(['EFFR'], 'fred', start='2020-01-01', end='2022-01-01')
df2.rename(columns={'EFFR': 'IR'}, inplace=True)
df2['IR']= df2['IR']/100

# %%
df = returns.merge(df2, how= 'left', left_index = True, right_index = True)

# %%
# df.info()
df.head()
# df.tail()
# Out:
#                 GOLD       OIL     SP500      IR
# Date
# 2020-01-02  0.003285  0.001963  0.008344  0.0155
# 2020-01-03  0.016072  0.030108 -0.007085  0.0155
# 2020-01-06  0.010914  0.003483  0.003527  0.0155
# 2020-01-07  0.003569 -0.009050 -0.002807  0.0155
# 2020-01-08 -0.009204 -0.050538  0.004890  0.0155

# %%
# df3 = web.DataReader(['CPIAUCSL'], 'fred', start='2019-11-30', end='2022-01-01')
# df3.rename(columns={'CPIAUCSL': 'INFL'}, inplace=True)

# %%
# infl = df3.copy()
# for i in range(1,len(df3+1)):
#     infl.iloc[i] = np.log(df3.iloc[i]/df3.iloc[i-1])
# infl = infl[1:]
# infl.head()

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Other possible factors

# %%
# US Daily News Index (http://www.policyuncertainty.com/us_monthly.html)
df_data = pd.read_csv('data/All_Daily_Policy_Data.csv')
df_data['date'] = pd.to_datetime(dict(year=df_data.year, month=df_data.month, day=df_data.day))
df_data.set_index('date', inplace = True)
df_data = pd.DataFrame(df_data.daily_policy_index)
df_data = df_data.loc['2019-12-31':]
df_data.rename(columns = {'daily_policy_index': 'EPU'}, inplace=True)

# %%
# The number of daily confirmed Bitcoin transactions (https://data.nasdaq.com/data/BCHAIN/NTRAN-bitcoin-number-of-transactions)
transactions = pd.read_csv('data/BCHAIN-NTRAN.csv')
transactions.sort_values(by=['Date'], ascending=True, inplace=True)
transactions['Date'] = pd.to_datetime(transactions['Date'])
transactions.set_index('Date', inplace = True)
transactions = transactions.loc['2019-12-31':]
transactions.rename(columns = {'Value': 'transactions'}, inplace=True)

# %%
df101 = df_data.merge(transactions, left_index = True, right_index = True)

# %%
#The VIX Index is recognized as the world’s premier gauge of U.S. equity market volatility
# (https://www.cboe.com/tradable_products/vix/)
VIX = pd.read_csv('data/VIX_History.csv')
VIX['DATE'] = pd.to_datetime(VIX['DATE'])
VIX.set_index('DATE', inplace = True)
VIX = VIX.loc['2019-12-31':]
VIX.rename(columns = {'CLOSE': 'VIX'}, inplace=True)
VIX = pd.DataFrame(VIX.VIX)

# %%
# all three factors in one table, raw data
df202 = df101.merge(VIX, left_index = True, right_index = True)

# %%
df202_returns = df202.copy()
for i in range(1,len(df202+1)):
    df202_returns.iloc[i] = np.log(df202.iloc[i]/df202.iloc[i-1])
df202_returns = df202_returns[1:]

# %%
path = os.path.join('data','D_infections_volatility_tracker.xlsx')
df_InfVol = pd.read_excel(path)
df_EMV= df_InfVol.drop(columns=['day', 'month', 'year'])
df_emv= df_EMV.set_index('date')

# %%
path = os.path.join('data','DOW JONES GLOBAL_DJUSCA.csv')
df_DOWJ = pd.read_csv(path)
df_DOWJG= df_DOWJ[["Close", "Date"]]
df_DOWJG.rename(columns = {'Close': 'DOWJ'}, inplace=True)
df_DOWJG['Date'] = pd.to_datetime(df_DOWJG['Date'])
df_DOW=df_DOWJG.set_index('Date')
df_DOW.sort_values(by= 'Date', axis=0, ascending=True, inplace=True)
df_dow = pd.to_numeric(df_DOW['DOWJ'], errors='coerce')
# Out:
# <ipython-input-37-1868f98fd445>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_DOWJG['Date'] = pd.to_datetime(df_DOWJG['Date'])

# %%
df303 = df202.merge(df_dow, left_index = True, right_index = True)
df404 = df303.merge(df_emv, left_index = True, right_index = True)

# %%
df_merge_returns = df303.copy()
for i in range(1,len(df303+1)):
    df_merge_returns.iloc[i] = np.log(df303.iloc[i]/df303.iloc[i-1])
df_merge_returns = df_merge_returns[1:]

# %%
df_all= df_merge_returns.merge(df_emv, left_index=True, right_index=True)

# %%
df_merge_returns.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# I think for the daily infectious diseasse tracker, we cant take log --> it will divide somethin with 0 and the result will be nan/-inf. So for that i thik its better to standardize, but for all others i think it is fine.

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------

# %%
#pip install pytrends

# %%
from pytrends.request import TrendReq
from pytrends import dailydata

Bitcoin_df = dailydata.get_daily_data('Bitcoin', 2020, 1, 2022, 1, geo = 'US')
# Out:
# Bitcoin:2020-01-01 2020-01-31
# Bitcoin:2020-02-01 2020-02-29
# Bitcoin:2020-03-01 2020-03-31
# Bitcoin:2020-04-01 2020-04-30
# Bitcoin:2020-05-01 2020-05-31
# Bitcoin:2020-06-01 2020-06-30
# Bitcoin:2020-07-01 2020-07-31
# Bitcoin:2020-08-01 2020-08-31
# Bitcoin:2020-09-01 2020-09-30
# Bitcoin:2020-10-01 2020-10-31
# Bitcoin:2020-11-01 2020-11-30
# Bitcoin:2020-12-01 2020-12-31
# Bitcoin:2021-01-01 2021-01-31
# Bitcoin:2021-02-01 2021-02-28
# Bitcoin:2021-03-01 2021-03-31
# Bitcoin:2021-04-01 2021-04-30
# Bitcoin:2021-05-01 2021-05-31
# Bitcoin:2021-06-01 2021-06-30
# Bitcoin:2021-07-01 2021-07-31
# Bitcoin:2021-08-01 2021-08-31
# Bitcoin:2021-09-01 2021-09-30
# Bitcoin:2021-10-01 2021-10-31
# Bitcoin:2021-11-01 2021-11-30
# Bitcoin:2021-12-01 2021-12-31
# Bitcoin:2022-01-01 2022-01-31

# %%
Bitcoin_df
# Out:
#             Bitcoin_unscaled  Bitcoin_monthly isPartial  scale  Bitcoin
# date
# 2020-01-01                52              NaN       NaN    NaN      NaN
# 2020-01-02                64              NaN       NaN    NaN      NaN
# 2020-01-03                79              NaN       NaN    NaN      NaN
# 2020-01-04                70              NaN       NaN    NaN      NaN
# 2020-01-05                61             13.0     False   0.13     7.93
# ...                      ...              ...       ...    ...      ...
# 2022-01-13                68             33.0       NaN   0.33    22.44
# 2022-01-14                64             33.0       NaN   0.33    21.12
# 2022-01-15                50             33.0       NaN   0.33    16.50
# 2022-01-16                54             26.0      True   0.26    14.04
# 2022-01-17                65             26.0       NaN   0.26    16.90
#
# [748 rows x 5 columns]

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Standardising Bitcoin data (changed from unscaled to Bitcoin)

# %%
df_x = Bitcoin_df[["Bitcoin"]]

# %%
df_x.dropna(inplace=True)
# Out:
# <ipython-input-78-99f8a002d145>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_x.dropna(inplace=True)

# %%
df_x
# Out:
#             Bitcoin
# date
# 2020-01-05     7.93
# 2020-01-06     8.84
# 2020-01-07    11.31
# 2020-01-08    13.00
# 2020-01-09     9.36
# ...             ...
# 2022-01-13    22.44
# 2022-01-14    21.12
# 2022-01-15    16.50
# 2022-01-16    14.04
# 2022-01-17    16.90
#
# [744 rows x 1 columns]

# %%
# create a scaler object
std_scaler = StandardScaler()
std_scaler
# fit and transform the data
df_data_st = pd.DataFrame(std_scaler.fit_transform(df_x), columns=df_x.columns)

df_data_st
# Out:
#       Bitcoin
# 0   -0.819188
# 1   -0.760793
# 2   -0.602292
# 3   -0.493844
# 4   -0.727425
# ..        ...
# 739  0.111925
# 740  0.027220
# 741 -0.269248
# 742 -0.427107
# 743 -0.243579
#
# [744 rows x 1 columns]

# %%
df_data_st.index=df_x.index

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------

# %%
path = os.path.join('data','BTC-USD-2.csv')
df_data = pd.read_csv(path)
df_data.drop(columns=['Open', 'High', 'Low', 'Adj Close', 'Volume'], inplace=True)
df_data['Date']=pd.to_datetime(df_data['Date'])

# %%
df_btc=df_data.set_index('Date')

# %%
returns_btc = df_btc.copy()
for i in range(1,len(df_btc+1)):
    returns_btc.iloc[i] = np.log(df_btc.iloc[i]/df_btc.iloc[i-1])
returns_btc = returns_btc[1:]

# %%
returns_btc
# Out:
#                Close
# Date
# 2020-01-02 -0.030273
# 2020-01-03  0.050172
# 2020-01-04  0.008915
# 2020-01-05  0.000089
# 2020-01-06  0.047161
# ...              ...
# 2022-01-11  0.021633
# 2022-01-12  0.027994
# 2022-01-13 -0.031376
# 2022-01-14  0.011860
# 2022-01-15  0.001801
#
# [745 rows x 1 columns]

# %%
btc_merged=returns_btc.join(df_data_st)
btc_df= btc_merged.merge(df, left_index=True, right_index=True)
btc_data= btc_df.merge(df_merge_returns, left_index=True, right_index=True)

# %%
data_btc=btc_data.dropna()

# %%
data_btc.rename(columns={"Bitcoin": "GoogleTrend", "Close": "BTC_ret"}, inplace=True)
# Out:
# /Users/nezasmid/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# ### Descriptives - get to know the data

# %%
data_btc.hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'BTC_ret'}>,
#         <AxesSubplot:title={'center':'GoogleTrend'}>,
#         <AxesSubplot:title={'center':'GOLD'}>],
#        [<AxesSubplot:title={'center':'OIL'}>,
#         <AxesSubplot:title={'center':'SP500'}>,
#         <AxesSubplot:title={'center':'IR'}>],
#        [<AxesSubplot:title={'center':'EPU'}>,
#         <AxesSubplot:title={'center':'transactions'}>,
#         <AxesSubplot:title={'center':'VIX'}>],
#        [<AxesSubplot:title={'center':'DOWJ'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
data_btc.describe()
# Out:
#           BTC_ret  GoogleTrend        GOLD         OIL       SP500  \
# count  480.000000   480.000000  480.000000  480.000000  480.000000
# mean     0.003848     0.025624    0.000363    0.002016    0.000894
# std      0.046000     1.051168    0.011858    0.044742    0.016691
# min     -0.464730    -1.135549   -0.051069   -0.282206   -0.127652
# 25%     -0.015790    -0.713307   -0.004419   -0.011881   -0.004417
# 50%      0.002509    -0.330851    0.000983    0.002624    0.001676
# 75%      0.025792     0.374061    0.006180    0.016815    0.008010
# max      0.171821     5.088984    0.057775    0.319634    0.089683
#
#                IR         EPU  transactions         VIX        DOWJ
# count  480.000000  480.000000    480.000000  480.000000  480.000000
# mean     0.002227    0.002206     -0.000595   -0.000339   -0.000280
# std      0.004270    0.408618      0.096987    0.087595    0.034447
# min      0.000400   -1.426062     -0.492266   -0.266228   -0.268934
# 25%      0.000700   -0.256170     -0.056303   -0.047618   -0.017785
# 50%      0.000900   -0.001416     -0.001831   -0.010288   -0.000725
# 75%      0.000900    0.242917      0.047081    0.037940    0.015675
# max      0.016000    1.448161      0.389788    0.480214    0.115166

# %% [markdown]
# ### Should we standardized/winsorized ? When doing histograms i did not see any outliers maybe not necessary ?

# %%
sns.pairplot(data_btc)

# %% [markdown]
# ### Dickey-Fuller test (if needed)
#
# https://www.statsmodels.org/dev/generated/statsmodels.tsa.stattools.adfuller.html
# https://www.statology.org/dickey-fuller-test-python/
# https://www.hackdeploy.com/augmented-dickey-fuller-test-in-python/

# %%
#Def function for ADF, i found it on the internet :) --> same link as for the VAR
def adfuller_test(series, signif=0.05, name='', verbose=False):
    """Perform ADFuller to test for Stationarity of given series and print report"""
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    # Print Summary
    print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")

# %%
# ADF Test on each column
for name, column in data_btc.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "BTC_ret"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -15.1029
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.444
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "GoogleTrend"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.1162
#  No. Lags Chosen       = 17
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.2381. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "GOLD"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -11.0551
#  No. Lags Chosen       = 5
#  Critical value 1%     = -3.444
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "OIL"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.2378
#  No. Lags Chosen       = 10
#  Critical value 1%     = -3.444
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0006. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "SP500"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.2384
#  No. Lags Chosen       = 9
#  Critical value 1%     = -3.444
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "IR"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.9759
#  No. Lags Chosen       = 16
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0015. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "EPU"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -8.8741
#  No. Lags Chosen       = 12
#  Critical value 1%     = -3.444
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "transactions"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -6.8678
#  No. Lags Chosen       = 18
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "VIX"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -24.6515
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.444
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "DOWJ"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.9421
#  No. Lags Chosen       = 11
#  Critical value 1%     = -3.444
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %% [markdown]
# This thing probably looks much nicer than what i did, one variable after another. I let both options in here, but for the final output we can use just one :)

# %% [markdown]
# ### Correlation matirx

# %%
data_btc.corr()

# Plotting the seaborn heatmap 
fig = plt.figure(figsize=[10,10])
sns.heatmap(data_btc.corr(), annot=True, cmap="Greens")
plt.show()

# %%
data_btc.corr()
# Out:
#                BTC_ret  GoogleTrend      GOLD       OIL     SP500        IR  \
# BTC_ret       1.000000    -0.002417  0.157241  0.148691  0.359746 -0.031891
# GoogleTrend  -0.002417     1.000000 -0.072027  0.021107  0.000036 -0.220448
# GOLD          0.157241    -0.072027  1.000000  0.095975  0.148635 -0.008380
# OIL           0.148691     0.021107  0.095975  1.000000  0.299899 -0.116038
# SP500         0.359746     0.000036  0.148635  0.299899  1.000000 -0.088371
# IR           -0.031891    -0.220448 -0.008380 -0.116038 -0.088371  1.000000
# EPU          -0.021650     0.008800  0.050982 -0.022719  0.053849  0.013485
# transactions -0.001140    -0.002923  0.013443  0.018095 -0.008466 -0.004131
# VIX          -0.363022    -0.004358 -0.059909 -0.239211 -0.695410  0.110085
# DOWJ          0.271047     0.020939  0.044107  0.270116  0.674946 -0.099500
#
#                    EPU  transactions       VIX      DOWJ
# BTC_ret      -0.021650     -0.001140 -0.363022  0.271047
# GoogleTrend   0.008800     -0.002923 -0.004358  0.020939
# GOLD          0.050982      0.013443 -0.059909  0.044107
# OIL          -0.022719      0.018095 -0.239211  0.270116
# SP500         0.053849     -0.008466 -0.695410  0.674946
# IR            0.013485     -0.004131  0.110085 -0.099500
# EPU           1.000000      0.013679 -0.038020  0.044803
# transactions  0.013679      1.000000 -0.004745  0.026925
# VIX          -0.038020     -0.004745  1.000000 -0.515919
# DOWJ          0.044803      0.026925 -0.515919  1.000000

# %% [markdown]
# ### Classic OLS model
# https://www.statsmodels.org/dev/examples/notebooks/generated/ols.html

# %%
x=data_btc.drop(columns=['BTC_ret'])

# %%
y=data_btc.BTC_ret

# %%
#Model without the constant - just the variables also considering IR but we can replace it later
results = sm.OLS(y, x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                BTC_ret   R-squared (uncentered):                   0.174
# Model:                            OLS   Adj. R-squared (uncentered):              0.159
# Method:                 Least Squares   F-statistic:                              11.05
# Date:                Thu, 20 Jan 2022   Prob (F-statistic):                    1.08e-15
# Time:                        16:51:27   Log-Likelihood:                          841.68
# No. Observations:                 480   AIC:                                     -1665.
# Df Residuals:                     471   BIC:                                     -1628.
# Df Model:                           9
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# GoogleTrend      0.0007      0.002      0.349      0.727      -0.003       0.004
# GOLD             0.4689      0.167      2.816      0.005       0.142       0.796
# OIL              0.0318      0.046      0.696      0.487      -0.058       0.122
# SP500            0.4345      0.191      2.270      0.024       0.058       0.811
# IR               0.4709      0.412      1.143      0.253      -0.338       1.280
# EPU             -0.0052      0.005     -1.100      0.272      -0.015       0.004
# transactions    -0.0017      0.020     -0.085      0.932      -0.041       0.038
# VIX             -0.1178      0.031     -3.804      0.000      -0.179      -0.057
# DOWJ             0.0549      0.077      0.712      0.477      -0.096       0.206
# ==============================================================================
# Omnibus:                      198.543   Durbin-Watson:                   2.124
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3267.730
# Skew:                          -1.341   Prob(JB):                         0.00
# Kurtosis:                      15.498   Cond. No.                         224.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = ols("BTC_ret ~ OIL + GOLD + SP500 + GoogleTrend", data_btc)
fit = model.fit()
print(fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                BTC_ret   R-squared:                       0.142
# Model:                            OLS   Adj. R-squared:                  0.135
# Method:                 Least Squares   F-statistic:                     19.62
# Date:                Thu, 20 Jan 2022   Prob (F-statistic):           5.81e-15
# Time:                        16:51:27   Log-Likelihood:                 834.09
# No. Observations:                 480   AIC:                            -1658.
# Df Residuals:                     475   BIC:                            -1637.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0028      0.002      1.428      0.154      -0.001       0.007
# OIL             0.0399      0.046      0.870      0.385      -0.050       0.130
# GOLD            0.4050      0.167      2.418      0.016       0.076       0.734
# SP500           0.9166      0.124      7.405      0.000       0.673       1.160
# GoogleTrend     0.0002      0.002      0.100      0.920      -0.003       0.004
# ==============================================================================
# Omnibus:                      180.527   Durbin-Watson:                   2.112
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2612.883
# Skew:                          -1.212   Prob(JB):                         0.00
# Kurtosis:                      14.170   Cond. No.                         91.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## VAR model
# https://www.machinelearningplus.com/time-series/vector-autoregression-examples-python/
# https://analyticsindiamag.com/hands-on-tutorial-on-vector-autoregressionvar-for-time-series-modeling/

# %%
data_btc.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Granger's causality test - should we do that also ?
# By using granger’s causality test, we can find the relationship between the variables before building the model because it is known that if there is no relationship between the variables, we can drop the variables and separately do the modeling. If there is a relationship between them, we need to consider the variable in the modeling part.
#
# In mathematics, the test provides the p-value between the variables, and if the p-value is higher than 0.05 then we will be required to accept the null hypothesis, and if the p-value is lesser than 0.05 we are required to reject the null hypothesis.
#
# Statsmodel also provides a module to perform the test, so using the statsmodel next, I am performing the granger’s causality test.

# %%
from statsmodels.tsa.stattools import grangercausalitytests

# %% [markdown]
# ### Cointegration test-  should we do that also ?
#
# Cointegration helps to find out the statistical connection between two or more time series. When two or more time series are cointegrated, they have a long run, statistically significant relationship.

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

# %% [markdown]
# ### VAR

# %%
var = VAR(data_btc)
# Out:
# /Users/nezasmid/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'

# %%
x= var.select_order()
x.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
results = var.fit(9)
#We can check the summary of the model by.
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 20, Jan, 2022
# Time:                     16:51:43
# --------------------------------------------------------------------
# No. of Equations:         10.0000    BIC:                   -59.3296
# Nobs:                     471.000    HQIC:                  -64.1992
# Log likelihood:           10089.4    FPE:                5.86889e-30
# AIC:                     -67.3571    Det(Omega_mle):     1.00323e-30
# --------------------------------------------------------------------
# Results for equation BTC_ret
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.006238         0.002761            2.260           0.024
# L1.BTC_ret              0.013021         0.055838            0.233           0.816
# L1.GoogleTrend          0.005488         0.004366            1.257           0.209
# L1.GOLD                -0.024290         0.197227           -0.123           0.902
# L1.OIL                  0.038532         0.061515            0.626           0.531
# L1.SP500               -0.092956         0.292870           -0.317           0.751
# L1.IR                 -11.031222         5.814440           -1.897           0.058
# L1.EPU                  0.001119         0.006174            0.181           0.856
# L1.transactions         0.059014         0.029045            2.032           0.042
# L1.VIX                  0.018697         0.038594            0.484           0.628
# L1.DOWJ                 0.126728         0.094879            1.336           0.182
# L2.BTC_ret             -0.070600         0.057087           -1.237           0.216
# L2.GoogleTrend         -0.008581         0.005625           -1.525           0.127
# L2.GOLD                 0.170539         0.197613            0.863           0.388
# L2.OIL                 -0.089709         0.060142           -1.492           0.136
# L2.SP500               -0.445256         0.293474           -1.517           0.129
# L2.IR                   7.544665         8.188540            0.921           0.357
# L2.EPU                  0.006609         0.007097            0.931           0.352
# L2.transactions         0.068484         0.036950            1.853           0.064
# L2.VIX                 -0.027290         0.038379           -0.711           0.477
# L2.DOWJ                 0.212821         0.094727            2.247           0.025
# L3.BTC_ret              0.068428         0.058498            1.170           0.242
# L3.GoogleTrend          0.008594         0.005631            1.526           0.127
# L3.GOLD                -0.196044         0.198769           -0.986           0.324
# L3.OIL                  0.070766         0.059638            1.187           0.235
# L3.SP500                0.144397         0.285985            0.505           0.614
# L3.IR                 -12.386513         8.368913           -1.480           0.139
# L3.EPU                  0.004872         0.007597            0.641           0.521
# L3.transactions         0.033594         0.039308            0.855           0.393
# L3.VIX                  0.029267         0.037797            0.774           0.439
# L3.DOWJ                 0.031167         0.094810            0.329           0.742
# L4.BTC_ret              0.101793         0.058505            1.740           0.082
# L4.GoogleTrend         -0.013961         0.005707           -2.446           0.014
# L4.GOLD                -0.323522         0.204536           -1.582           0.114
# L4.OIL                 -0.087331         0.059876           -1.459           0.145
# L4.SP500               -0.060244         0.273563           -0.220           0.826
# L4.IR                  15.334014         8.568781            1.790           0.074
# L4.EPU                  0.008506         0.008031            1.059           0.290
# L4.transactions         0.012130         0.039547            0.307           0.759
# L4.VIX                  0.046295         0.037966            1.219           0.223
# L4.DOWJ                 0.102222         0.095649            1.069           0.285
# L5.BTC_ret             -0.014128         0.058141           -0.243           0.808
# L5.GoogleTrend          0.018506         0.005840            3.169           0.002
# L5.GOLD                -0.252378         0.205432           -1.229           0.219
# L5.OIL                 -0.011178         0.058760           -0.190           0.849
# L5.SP500               -0.015409         0.266573           -0.058           0.954
# L5.IR                  -8.531671         8.623491           -0.989           0.322
# L5.EPU                 -0.002410         0.008019           -0.301           0.764
# L5.transactions        -0.017407         0.039785           -0.438           0.662
# L5.VIX                 -0.064117         0.038428           -1.668           0.095
# L5.DOWJ                -0.062562         0.093901           -0.666           0.505
# L6.BTC_ret              0.046827         0.056561            0.828           0.408
# L6.GoogleTrend         -0.001792         0.005880           -0.305           0.761
# L6.GOLD                -0.079817         0.204515           -0.390           0.696
# L6.OIL                 -0.004660         0.058777           -0.079           0.937
# L6.SP500               -0.482556         0.266603           -1.810           0.070
# L6.IR                  40.848545         8.625517            4.736           0.000
# L6.EPU                  0.009807         0.007955            1.233           0.218
# L6.transactions        -0.038125         0.039104           -0.975           0.330
# L6.VIX                 -0.039302         0.038365           -1.024           0.306
# L6.DOWJ                 0.109274         0.094035            1.162           0.245
# L7.BTC_ret              0.055035         0.057028            0.965           0.335
# L7.GoogleTrend         -0.005988         0.005842           -1.025           0.305
# L7.GOLD                -0.087926         0.204355           -0.430           0.667
# L7.OIL                 -0.034658         0.055064           -0.629           0.529
# L7.SP500                0.100661         0.263083            0.383           0.702
# L7.IR                 -42.670326         8.632269           -4.943           0.000
# L7.EPU                  0.007275         0.007511            0.969           0.333
# L7.transactions        -0.007259         0.038206           -0.190           0.849
# L7.VIX                 -0.029358         0.037959           -0.773           0.439
# L7.DOWJ                 0.049828         0.094485            0.527           0.598
# L8.BTC_ret             -0.080846         0.056915           -1.420           0.155
# L8.GoogleTrend          0.002470         0.005825            0.424           0.672
# L8.GOLD                 0.178287         0.206818            0.862           0.389
# L8.OIL                 -0.046599         0.054335           -0.858           0.391
# L8.SP500               -0.541923         0.264860           -2.046           0.041
# L8.IR                  19.997369         8.940312            2.237           0.025
# L8.EPU                  0.009238         0.007086            1.304           0.192
# L8.transactions         0.005911         0.035865            0.165           0.869
# L8.VIX                 -0.027738         0.037406           -0.742           0.458
# L8.DOWJ                 0.045533         0.093880            0.485           0.628
# L9.BTC_ret              0.022351         0.057302            0.390           0.697
# L9.GoogleTrend         -0.007912         0.004463           -1.773           0.076
# L9.GOLD                 0.279468         0.206434            1.354           0.176
# L9.OIL                  0.033326         0.055622            0.599           0.549
# L9.SP500                0.235003         0.256079            0.918           0.359
# L9.IR                  -9.910258         6.474749           -1.531           0.126
# L9.EPU                  0.008924         0.006086            1.466           0.143
# L9.transactions         0.017547         0.028222            0.622           0.534
# L9.VIX                  0.023582         0.037034            0.637           0.524
# L9.DOWJ                 0.026054         0.094433            0.276           0.783
# ==================================================================================
#
# Results for equation GoogleTrend
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.005268         0.032312           -0.163           0.870
# L1.BTC_ret              0.981222         0.653560            1.501           0.133
# L1.GoogleTrend          0.799025         0.051107           15.634           0.000
# L1.GOLD                 0.495371         2.308440            0.215           0.830
# L1.OIL                 -0.111530         0.720000           -0.155           0.877
# L1.SP500               -2.010778         3.427892           -0.587           0.557
# L1.IR                  24.083709        68.055110            0.354           0.723
# L1.EPU                 -0.036519         0.072264           -0.505           0.613
# L1.transactions        -0.323100         0.339955           -0.950           0.342
# L1.VIX                  0.327643         0.451729            0.725           0.468
# L1.DOWJ                 1.548315         1.110517            1.394           0.163
# L2.BTC_ret             -0.150856         0.668174           -0.226           0.821
# L2.GoogleTrend          0.074130         0.065841            1.126           0.260
# L2.GOLD                 1.618256         2.312967            0.700           0.484
# L2.OIL                  0.016604         0.703936            0.024           0.981
# L2.SP500                1.655570         3.434970            0.482           0.630
# L2.IR                  13.505637        95.842773            0.141           0.888
# L2.EPU                 -0.071715         0.083068           -0.863           0.388
# L2.transactions         0.256727         0.432486            0.594           0.553
# L2.VIX                  0.222307         0.449203            0.495           0.621
# L2.DOWJ                -0.261447         1.108728           -0.236           0.814
# L3.BTC_ret              0.502350         0.684693            0.734           0.463
# L3.GoogleTrend         -0.117184         0.065908           -1.778           0.075
# L3.GOLD                -3.545990         2.326492           -1.524           0.127
# L3.OIL                  0.012519         0.698038            0.018           0.986
# L3.SP500                1.783707         3.347317            0.533           0.594
# L3.IR                 -66.098785        97.953949           -0.675           0.500
# L3.EPU                 -0.161800         0.088915           -1.820           0.069
# L3.transactions         0.270631         0.460085            0.588           0.556
# L3.VIX                 -0.095662         0.442399           -0.216           0.829
# L3.DOWJ                -1.846468         1.109703           -1.664           0.096
# L4.BTC_ret             -0.320077         0.684768           -0.467           0.640
# L4.GoogleTrend          0.208632         0.066799            3.123           0.002
# L4.GOLD                 1.920368         2.393989            0.802           0.422
# L4.OIL                 -0.284150         0.700818           -0.405           0.685
# L4.SP500               -1.631523         3.201914           -0.510           0.610
# L4.IR                  18.413171       100.293301            0.184           0.854
# L4.EPU                 -0.143006         0.094000           -1.521           0.128
# L4.transactions        -0.088533         0.462872           -0.191           0.848
# L4.VIX                 -0.593855         0.444368           -1.336           0.181
# L4.DOWJ                -0.304552         1.119522           -0.272           0.786
# L5.BTC_ret             -0.187092         0.680509           -0.275           0.783
# L5.GoogleTrend         -0.070768         0.068355           -1.035           0.301
# L5.GOLD                 0.962686         2.404478            0.400           0.689
# L5.OIL                  0.463687         0.687753            0.674           0.500
# L5.SP500                2.431433         3.120104            0.779           0.436
# L5.IR                  32.001564       100.933658            0.317           0.751
# L5.EPU                 -0.118010         0.093856           -1.257           0.209
# L5.transactions         0.293617         0.465664            0.631           0.528
# L5.VIX                  0.262776         0.449785            0.584           0.559
# L5.DOWJ                -0.753512         1.099069           -0.686           0.493
# L6.BTC_ret              1.061292         0.662015            1.603           0.109
# L6.GoogleTrend         -0.052049         0.068822           -0.756           0.449
# L6.GOLD                -0.254575         2.393742           -0.106           0.915
# L6.OIL                  0.159994         0.687956            0.233           0.816
# L6.SP500               -0.850938         3.120453           -0.273           0.785
# L6.IR                -104.034465       100.957363           -1.030           0.303
# L6.EPU                 -0.056160         0.093104           -0.603           0.546
# L6.transactions         0.557064         0.457687            1.217           0.224
# L6.VIX                  0.414813         0.449045            0.924           0.356
# L6.DOWJ                 0.082756         1.100627            0.075           0.940
# L7.BTC_ret              0.841426         0.667488            1.261           0.207
# L7.GoogleTrend          0.082536         0.068373            1.207           0.227
# L7.GOLD                 3.769439         2.391877            1.576           0.115
# L7.OIL                 -0.684901         0.644499           -1.063           0.288
# L7.SP500               -1.715229         3.079251           -0.557           0.578
# L7.IR                 -17.290530       101.036395           -0.171           0.864
# L7.EPU                 -0.069287         0.087917           -0.788           0.431
# L7.transactions         0.177741         0.447185            0.397           0.691
# L7.VIX                 -0.356985         0.444287           -0.804           0.422
# L7.DOWJ                -0.875177         1.105897           -0.791           0.429
# L8.BTC_ret              1.080019         0.666158            1.621           0.105
# L8.GoogleTrend         -0.076226         0.068178           -1.118           0.264
# L8.GOLD                 2.910104         2.420701            1.202           0.229
# L8.OIL                  0.179263         0.635970            0.282           0.778
# L8.SP500                1.098608         3.100060            0.354           0.723
# L8.IR                 146.550759       104.641886            1.400           0.161
# L8.EPU                  0.004464         0.082940            0.054           0.957
# L8.transactions        -0.068319         0.419784           -0.163           0.871
# L8.VIX                  0.637435         0.437815            1.456           0.145
# L8.DOWJ                 0.458314         1.098820            0.417           0.677
# L9.BTC_ret              0.064950         0.670692            0.097           0.923
# L9.GoogleTrend          0.076372         0.052243            1.462           0.144
# L9.GOLD                 1.057872         2.416208            0.438           0.662
# L9.OIL                  0.143332         0.651029            0.220           0.826
# L9.SP500                4.609094         2.997278            1.538           0.124
# L9.IR                 -53.613382        75.783706           -0.707           0.479
# L9.EPU                 -0.039898         0.071237           -0.560           0.575
# L9.transactions         0.198663         0.330323            0.601           0.548
# L9.VIX                  0.834466         0.433459            1.925           0.054
# L9.DOWJ                -0.483208         1.105288           -0.437           0.662
# ==================================================================================
#
# Results for equation GOLD
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.000022         0.000734           -0.030           0.976
# L1.BTC_ret              0.014984         0.014853            1.009           0.313
# L1.GoogleTrend         -0.000903         0.001161           -0.777           0.437
# L1.GOLD                -0.019986         0.052461           -0.381           0.703
# L1.OIL                 -0.003023         0.016363           -0.185           0.853
# L1.SP500                0.100135         0.077901            1.285           0.199
# L1.IR                  -2.450863         1.546603           -1.585           0.113
# L1.EPU                  0.000809         0.001642            0.492           0.622
# L1.transactions        -0.008085         0.007726           -1.046           0.295
# L1.VIX                  0.003559         0.010266            0.347           0.729
# L1.DOWJ                -0.008493         0.025237           -0.337           0.736
# L2.BTC_ret              0.013993         0.015185            0.922           0.357
# L2.GoogleTrend          0.000227         0.001496            0.151           0.880
# L2.GOLD                -0.030358         0.052564           -0.578           0.564
# L2.OIL                 -0.005352         0.015997           -0.335           0.738
# L2.SP500               -0.008913         0.078062           -0.114           0.909
# L2.IR                   4.844112         2.178098            2.224           0.026
# L2.EPU                  0.000427         0.001888            0.226           0.821
# L2.transactions        -0.001312         0.009829           -0.134           0.894
# L2.VIX                  0.003230         0.010208            0.316           0.752
# L2.DOWJ                 0.045874         0.025197            1.821           0.069
# L3.BTC_ret              0.017621         0.015560            1.132           0.257
# L3.GoogleTrend          0.000832         0.001498            0.556           0.579
# L3.GOLD                -0.009514         0.052871           -0.180           0.857
# L3.OIL                  0.002294         0.015863            0.145           0.885
# L3.SP500                0.058610         0.076070            0.770           0.441
# L3.IR                  -1.986225         2.226076           -0.892           0.372
# L3.EPU                 -0.002898         0.002021           -1.434           0.151
# L3.transactions        -0.001870         0.010456           -0.179           0.858
# L3.VIX                  0.017025         0.010054            1.693           0.090
# L3.DOWJ                 0.029184         0.025219            1.157           0.247
# L4.BTC_ret              0.002715         0.015562            0.174           0.862
# L4.GoogleTrend         -0.001816         0.001518           -1.196           0.232
# L4.GOLD                -0.165488         0.054405           -3.042           0.002
# L4.OIL                 -0.015490         0.015927           -0.973           0.331
# L4.SP500                0.069858         0.072766            0.960           0.337
# L4.IR                   0.655818         2.279239            0.288           0.774
# L4.EPU                  0.001634         0.002136            0.765           0.444
# L4.transactions        -0.006707         0.010519           -0.638           0.524
# L4.VIX                 -0.022122         0.010099           -2.191           0.028
# L4.DOWJ                -0.060003         0.025442           -2.358           0.018
# L5.BTC_ret              0.006968         0.015465            0.451           0.652
# L5.GoogleTrend          0.000088         0.001553            0.056           0.955
# L5.GOLD                -0.136768         0.054644           -2.503           0.012
# L5.OIL                  0.011541         0.015630            0.738           0.460
# L5.SP500                0.112429         0.070907            1.586           0.113
# L5.IR                  -3.925707         2.293792           -1.711           0.087
# L5.EPU                  0.002101         0.002133            0.985           0.325
# L5.transactions        -0.016566         0.010583           -1.565           0.117
# L5.VIX                 -0.005176         0.010222           -0.506           0.613
# L5.DOWJ                -0.069736         0.024977           -2.792           0.005
# L6.BTC_ret              0.003107         0.015045            0.206           0.836
# L6.GoogleTrend          0.000793         0.001564            0.507           0.612
# L6.GOLD                -0.017698         0.054400           -0.325           0.745
# L6.OIL                 -0.017072         0.015634           -1.092           0.275
# L6.SP500               -0.064807         0.070915           -0.914           0.361
# L6.IR                   2.085199         2.294331            0.909           0.363
# L6.EPU                  0.002748         0.002116            1.299           0.194
# L6.transactions        -0.012014         0.010401           -1.155           0.248
# L6.VIX                 -0.017187         0.010205           -1.684           0.092
# L6.DOWJ                -0.010840         0.025013           -0.433           0.665
# L7.BTC_ret             -0.022100         0.015169           -1.457           0.145
# L7.GoogleTrend         -0.000687         0.001554           -0.442           0.658
# L7.GOLD                 0.002908         0.054357            0.054           0.957
# L7.OIL                  0.022753         0.014647            1.553           0.120
# L7.SP500                0.016079         0.069978            0.230           0.818
# L7.IR                   4.122511         2.296127            1.795           0.073
# L7.EPU                  0.002400         0.001998            1.201           0.230
# L7.transactions        -0.014341         0.010163           -1.411           0.158
# L7.VIX                 -0.001960         0.010097           -0.194           0.846
# L7.DOWJ                 0.005334         0.025132            0.212           0.832
# L8.BTC_ret              0.007233         0.015139            0.478           0.633
# L8.GoogleTrend          0.000244         0.001549            0.157           0.875
# L8.GOLD                 0.085625         0.055012            1.556           0.120
# L8.OIL                 -0.010137         0.014453           -0.701           0.483
# L8.SP500               -0.056634         0.070451           -0.804           0.421
# L8.IR                  -2.163331         2.378064           -0.910           0.363
# L8.EPU                  0.001070         0.001885            0.568           0.570
# L8.transactions        -0.012324         0.009540           -1.292           0.196
# L8.VIX                 -0.005195         0.009950           -0.522           0.602
# L8.DOWJ                -0.003370         0.024972           -0.135           0.893
# L9.BTC_ret             -0.022292         0.015242           -1.463           0.144
# L9.GoogleTrend          0.000031         0.001187            0.026           0.979
# L9.GOLD                 0.049075         0.054910            0.894           0.371
# L9.OIL                  0.003649         0.014795            0.247           0.805
# L9.SP500                0.109599         0.068115            1.609           0.108
# L9.IR                  -1.118997         1.722241           -0.650           0.516
# L9.EPU                  0.002891         0.001619            1.786           0.074
# L9.transactions        -0.009905         0.007507           -1.319           0.187
# L9.VIX                  0.005550         0.009851            0.563           0.573
# L9.DOWJ                -0.015862         0.025118           -0.631           0.528
# ==================================================================================
#
# Results for equation OIL
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.005325         0.002411            2.209           0.027
# L1.BTC_ret              0.101019         0.048765            2.072           0.038
# L1.GoogleTrend          0.005341         0.003813            1.401           0.161
# L1.GOLD                 0.092121         0.172243            0.535           0.593
# L1.OIL                  0.022394         0.053723            0.417           0.677
# L1.SP500                0.027008         0.255771            0.106           0.916
# L1.IR                   3.483762         5.077905            0.686           0.493
# L1.EPU                  0.000702         0.005392            0.130           0.896
# L1.transactions        -0.003035         0.025366           -0.120           0.905
# L1.VIX                 -0.017768         0.033706           -0.527           0.598
# L1.DOWJ                -0.009244         0.082861           -0.112           0.911
# L2.BTC_ret              0.085171         0.049856            1.708           0.088
# L2.GoogleTrend         -0.008270         0.004913           -1.683           0.092
# L2.GOLD                -0.268442         0.172581           -1.555           0.120
# L2.OIL                 -0.191427         0.052524           -3.645           0.000
# L2.SP500               -0.022085         0.256299           -0.086           0.931
# L2.IR                  18.174680         7.151270            2.541           0.011
# L2.EPU                  0.001541         0.006198            0.249           0.804
# L2.transactions        -0.043989         0.032270           -1.363           0.173
# L2.VIX                 -0.011480         0.033517           -0.343           0.732
# L2.DOWJ                 0.138378         0.082727            1.673           0.094
# L3.BTC_ret              0.058584         0.051088            1.147           0.251
# L3.GoogleTrend          0.003449         0.004918            0.701           0.483
# L3.GOLD                -0.461768         0.173590           -2.660           0.008
# L3.OIL                 -0.109100         0.052084           -2.095           0.036
# L3.SP500               -0.079400         0.249759           -0.318           0.751
# L3.IR                 -15.533737         7.308795           -2.125           0.034
# L3.EPU                  0.000468         0.006634            0.071           0.944
# L3.transactions        -0.011037         0.034329           -0.321           0.748
# L3.VIX                 -0.031000         0.033009           -0.939           0.348
# L3.DOWJ                -0.104821         0.082800           -1.266           0.206
# L4.BTC_ret              0.069081         0.051094            1.352           0.176
# L4.GoogleTrend          0.005016         0.004984            1.006           0.314
# L4.GOLD                -0.083566         0.178627           -0.468           0.640
# L4.OIL                  0.034109         0.052291            0.652           0.514
# L4.SP500               -0.118565         0.238909           -0.496           0.620
# L4.IR                  -9.206593         7.483345           -1.230           0.219
# L4.EPU                  0.005838         0.007014            0.832           0.405
# L4.transactions         0.004248         0.034537            0.123           0.902
# L4.VIX                 -0.029905         0.033156           -0.902           0.367
# L4.DOWJ                 0.047066         0.083533            0.563           0.573
# L5.BTC_ret             -0.117220         0.050776           -2.309           0.021
# L5.GoogleTrend         -0.007311         0.005100           -1.434           0.152
# L5.GOLD                -0.023506         0.179409           -0.131           0.896
# L5.OIL                  0.061173         0.051316            1.192           0.233
# L5.SP500               -0.817159         0.232805           -3.510           0.000
# L5.IR                   7.209091         7.531125            0.957           0.338
# L5.EPU                  0.008052         0.007003            1.150           0.250
# L5.transactions         0.015199         0.034745            0.437           0.662
# L5.VIX                 -0.058737         0.033561           -1.750           0.080
# L5.DOWJ                 0.025094         0.082007            0.306           0.760
# L6.BTC_ret              0.045669         0.049396            0.925           0.355
# L6.GoogleTrend          0.005058         0.005135            0.985           0.325
# L6.GOLD                 0.353731         0.178608            1.980           0.048
# L6.OIL                 -0.048385         0.051332           -0.943           0.346
# L6.SP500                0.040220         0.232831            0.173           0.863
# L6.IR                  -7.487293         7.532893           -0.994           0.320
# L6.EPU                  0.005456         0.006947            0.785           0.432
# L6.transactions        -0.064922         0.034150           -1.901           0.057
# L6.VIX                 -0.037491         0.033505           -1.119           0.263
# L6.DOWJ                 0.119405         0.082123            1.454           0.146
# L7.BTC_ret             -0.017246         0.049804           -0.346           0.729
# L7.GoogleTrend         -0.006433         0.005102           -1.261           0.207
# L7.GOLD                -0.034052         0.178469           -0.191           0.849
# L7.OIL                  0.024767         0.048089            0.515           0.607
# L7.SP500                0.807114         0.229757            3.513           0.000
# L7.IR                  -9.330845         7.538790           -1.238           0.216
# L7.EPU                  0.010741         0.006560            1.637           0.102
# L7.transactions        -0.075175         0.033367           -2.253           0.024
# L7.VIX                  0.030223         0.033150            0.912           0.362
# L7.DOWJ                 0.068150         0.082516            0.826           0.409
# L8.BTC_ret              0.006320         0.049705            0.127           0.899
# L8.GoogleTrend          0.001874         0.005087            0.368           0.713
# L8.GOLD                 0.182300         0.180620            1.009           0.313
# L8.OIL                  0.146240         0.047453            3.082           0.002
# L8.SP500               -0.428011         0.231310           -1.850           0.064
# L8.IR                  22.878623         7.807813            2.930           0.003
# L8.EPU                  0.007318         0.006189            1.183           0.237
# L8.transactions        -0.025948         0.031322           -0.828           0.407
# L8.VIX                  0.060577         0.032667            1.854           0.064
# L8.DOWJ                 0.231610         0.081988            2.825           0.005
# L9.BTC_ret             -0.022176         0.050043           -0.443           0.658
# L9.GoogleTrend         -0.000080         0.003898           -0.021           0.984
# L9.GOLD                 0.110348         0.180284            0.612           0.540
# L9.OIL                 -0.053120         0.048576           -1.094           0.274
# L9.SP500               -0.035050         0.223641           -0.157           0.875
# L9.IR                 -11.114985         5.654571           -1.966           0.049
# L9.EPU                  0.004062         0.005315            0.764           0.445
# L9.transactions        -0.007001         0.024647           -0.284           0.776
# L9.VIX                  0.001713         0.032342            0.053           0.958
# L9.DOWJ                 0.169497         0.082471            2.055           0.040
# ==================================================================================
#
# Results for equation SP500
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.002765         0.000827            3.345           0.001
# L1.BTC_ret              0.004526         0.016719            0.271           0.787
# L1.GoogleTrend         -0.000087         0.001307           -0.067           0.947
# L1.GOLD                 0.086892         0.059052            1.471           0.141
# L1.OIL                 -0.033496         0.018418           -1.819           0.069
# L1.SP500               -0.320694         0.087689           -3.657           0.000
# L1.IR                   1.498879         1.740916            0.861           0.389
# L1.EPU                 -0.000262         0.001849           -0.141           0.888
# L1.transactions         0.010944         0.008696            1.258           0.208
# L1.VIX                 -0.020182         0.011556           -1.746           0.081
# L1.DOWJ                 0.053340         0.028408            1.878           0.060
# L2.BTC_ret              0.040733         0.017093            2.383           0.017
# L2.GoogleTrend         -0.001128         0.001684           -0.670           0.503
# L2.GOLD                 0.096576         0.059168            1.632           0.103
# L2.OIL                 -0.013865         0.018007           -0.770           0.441
# L2.SP500               -0.008071         0.087870           -0.092           0.927
# L2.IR                  -1.157233         2.451752           -0.472           0.637
# L2.EPU                  0.000344         0.002125            0.162           0.871
# L2.transactions        -0.000475         0.011063           -0.043           0.966
# L2.VIX                  0.005499         0.011491            0.479           0.632
# L2.DOWJ                 0.085175         0.028362            3.003           0.003
# L3.BTC_ret             -0.006853         0.017515           -0.391           0.696
# L3.GoogleTrend         -0.000121         0.001686           -0.072           0.943
# L3.GOLD                -0.066756         0.059514           -1.122           0.262
# L3.OIL                  0.041018         0.017856            2.297           0.022
# L3.SP500               -0.086092         0.085628           -1.005           0.315
# L3.IR                   7.138378         2.505758            2.849           0.004
# L3.EPU                 -0.000528         0.002275           -0.232           0.817
# L3.transactions         0.005208         0.011769            0.443           0.658
# L3.VIX                  0.004413         0.011317            0.390           0.697
# L3.DOWJ                 0.045572         0.028387            1.605           0.108
# L4.BTC_ret              0.009152         0.017517            0.522           0.601
# L4.GoogleTrend          0.001885         0.001709            1.103           0.270
# L4.GOLD                -0.104999         0.061241           -1.715           0.086
# L4.OIL                 -0.016510         0.017928           -0.921           0.357
# L4.SP500               -0.139566         0.081908           -1.704           0.088
# L4.IR                  -8.538333         2.565601           -3.328           0.001
# L4.EPU                  0.003432         0.002405            1.427           0.153
# L4.transactions         0.002860         0.011841            0.242           0.809
# L4.VIX                 -0.008038         0.011367           -0.707           0.480
# L4.DOWJ                 0.001299         0.028638            0.045           0.964
# L5.BTC_ret             -0.013496         0.017408           -0.775           0.438
# L5.GoogleTrend         -0.001560         0.001749           -0.892           0.372
# L5.GOLD                 0.092933         0.061509            1.511           0.131
# L5.OIL                 -0.017874         0.017593           -1.016           0.310
# L5.SP500                0.034574         0.079815            0.433           0.665
# L5.IR                   4.635582         2.581981            1.795           0.073
# L5.EPU                 -0.000427         0.002401           -0.178           0.859
# L5.transactions         0.005146         0.011912            0.432           0.666
# L5.VIX                 -0.005396         0.011506           -0.469           0.639
# L5.DOWJ                -0.016467         0.028115           -0.586           0.558
# L6.BTC_ret              0.031498         0.016935            1.860           0.063
# L6.GoogleTrend          0.001422         0.001761            0.808           0.419
# L6.GOLD                 0.007006         0.061234            0.114           0.909
# L6.OIL                 -0.028698         0.017599           -1.631           0.103
# L6.SP500               -0.182675         0.079824           -2.288           0.022
# L6.IR                   1.986764         2.582588            0.769           0.442
# L6.EPU                  0.002403         0.002382            1.009           0.313
# L6.transactions        -0.019222         0.011708           -1.642           0.101
# L6.VIX                 -0.031685         0.011487           -2.758           0.006
# L6.DOWJ                -0.049925         0.028155           -1.773           0.076
# L7.BTC_ret              0.010342         0.017075            0.606           0.545
# L7.GoogleTrend         -0.000841         0.001749           -0.481           0.631
# L7.GOLD                -0.105576         0.061187           -1.725           0.084
# L7.OIL                 -0.029819         0.016487           -1.809           0.071
# L7.SP500                0.279008         0.078770            3.542           0.000
# L7.IR                 -14.347698         2.584610           -5.551           0.000
# L7.EPU                  0.003144         0.002249            1.398           0.162
# L7.transactions        -0.015713         0.011439           -1.374           0.170
# L7.VIX                  0.015317         0.011365            1.348           0.178
# L7.DOWJ                 0.002507         0.028290            0.089           0.929
# L8.BTC_ret              0.008434         0.017041            0.495           0.621
# L8.GoogleTrend         -0.000111         0.001744           -0.064           0.949
# L8.GOLD                 0.015400         0.061924            0.249           0.804
# L8.OIL                 -0.038383         0.016269           -2.359           0.018
# L8.SP500               -0.070325         0.079303           -0.887           0.375
# L8.IR                  13.104299         2.676842            4.895           0.000
# L8.EPU                  0.003059         0.002122            1.442           0.149
# L8.transactions        -0.011340         0.010738           -1.056           0.291
# L8.VIX                  0.002922         0.011200            0.261           0.794
# L8.DOWJ                -0.006785         0.028109           -0.241           0.809
# L9.BTC_ret              0.014805         0.017157            0.863           0.388
# L9.GoogleTrend         -0.000052         0.001336           -0.039           0.969
# L9.GOLD                 0.028800         0.061809            0.466           0.641
# L9.OIL                 -0.001840         0.016654           -0.110           0.912
# L9.SP500                0.130878         0.076673            1.707           0.088
# L9.IR                  -4.885891         1.938621           -2.520           0.012
# L9.EPU                  0.000816         0.001822            0.448           0.654
# L9.transactions        -0.009670         0.008450           -1.144           0.252
# L9.VIX                  0.004236         0.011088            0.382           0.702
# L9.DOWJ                -0.006522         0.028274           -0.231           0.818
# ==================================================================================
#
# Results for equation IR
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.000023         0.000021           -1.100           0.271
# L1.BTC_ret             -0.000235         0.000431           -0.545           0.586
# L1.GoogleTrend         -0.000038         0.000034           -1.133           0.257
# L1.GOLD                 0.001170         0.001522            0.769           0.442
# L1.OIL                  0.000046         0.000475            0.097           0.923
# L1.SP500               -0.000512         0.002260           -0.226           0.821
# L1.IR                   0.992449         0.044876           22.115           0.000
# L1.EPU                  0.000045         0.000048            0.941           0.347
# L1.transactions         0.000045         0.000224            0.200           0.841
# L1.VIX                  0.000062         0.000298            0.207           0.836
# L1.DOWJ                 0.000251         0.000732            0.342           0.732
# L2.BTC_ret              0.002130         0.000441            4.833           0.000
# L2.GoogleTrend          0.000046         0.000043            1.058           0.290
# L2.GOLD                 0.001322         0.001525            0.866           0.386
# L2.OIL                 -0.000055         0.000464           -0.118           0.906
# L2.SP500                0.003787         0.002265            1.672           0.095
# L2.IR                  -0.145129         0.063199           -2.296           0.022
# L2.EPU                  0.000091         0.000055            1.664           0.096
# L2.transactions        -0.000077         0.000285           -0.271           0.786
# L2.VIX                  0.000906         0.000296            3.057           0.002
# L2.DOWJ                 0.001176         0.000731            1.609           0.108
# L3.BTC_ret              0.000494         0.000451            1.094           0.274
# L3.GoogleTrend         -0.000027         0.000043           -0.615           0.539
# L3.GOLD                 0.007046         0.001534            4.593           0.000
# L3.OIL                  0.000371         0.000460            0.805           0.421
# L3.SP500               -0.001590         0.002207           -0.720           0.471
# L3.IR                   0.033012         0.064591            0.511           0.609
# L3.EPU                  0.000007         0.000059            0.117           0.907
# L3.transactions        -0.000020         0.000303           -0.066           0.947
# L3.VIX                  0.000362         0.000292            1.239           0.215
# L3.DOWJ                 0.002623         0.000732            3.585           0.000
# L4.BTC_ret             -0.000337         0.000452           -0.747           0.455
# L4.GoogleTrend         -0.000002         0.000044           -0.041           0.967
# L4.GOLD                -0.000137         0.001579           -0.087           0.931
# L4.OIL                 -0.000737         0.000462           -1.596           0.111
# L4.SP500               -0.005973         0.002111           -2.829           0.005
# L4.IR                   0.115610         0.066134            1.748           0.080
# L4.EPU                  0.000033         0.000062            0.538           0.590
# L4.transactions        -0.000326         0.000305           -1.067           0.286
# L4.VIX                 -0.001096         0.000293           -3.742           0.000
# L4.DOWJ                 0.000051         0.000738            0.068           0.945
# L5.BTC_ret              0.000916         0.000449            2.042           0.041
# L5.GoogleTrend         -0.000021         0.000045           -0.469           0.639
# L5.GOLD                 0.000128         0.001586            0.081           0.936
# L5.OIL                  0.001686         0.000454            3.717           0.000
# L5.SP500                0.002333         0.002057            1.134           0.257
# L5.IR                  -0.087673         0.066556           -1.317           0.188
# L5.EPU                  0.000035         0.000062            0.563           0.573
# L5.transactions        -0.000190         0.000307           -0.618           0.536
# L5.VIX                  0.000410         0.000297            1.382           0.167
# L5.DOWJ                 0.001208         0.000725            1.667           0.095
# L6.BTC_ret             -0.000458         0.000437           -1.048           0.294
# L6.GoogleTrend          0.000022         0.000045            0.478           0.633
# L6.GOLD                 0.001950         0.001578            1.236           0.217
# L6.OIL                 -0.001163         0.000454           -2.565           0.010
# L6.SP500                0.010077         0.002058            4.897           0.000
# L6.IR                   0.176206         0.066572            2.647           0.008
# L6.EPU                  0.000000         0.000061            0.000           1.000
# L6.transactions        -0.000036         0.000302           -0.120           0.905
# L6.VIX                  0.000215         0.000296            0.726           0.468
# L6.DOWJ                -0.001676         0.000726           -2.309           0.021
# L7.BTC_ret             -0.000165         0.000440           -0.374           0.708
# L7.GoogleTrend          0.000005         0.000045            0.101           0.920
# L7.GOLD                -0.000264         0.001577           -0.167           0.867
# L7.OIL                  0.000044         0.000425            0.103           0.918
# L7.SP500                0.002801         0.002030            1.380           0.168
# L7.IR                  -0.103298         0.066624           -1.550           0.121
# L7.EPU                  0.000002         0.000058            0.035           0.972
# L7.transactions        -0.000050         0.000295           -0.169           0.866
# L7.VIX                 -0.000535         0.000293           -1.828           0.068
# L7.DOWJ                -0.000566         0.000729           -0.776           0.438
# L8.BTC_ret              0.000450         0.000439            1.024           0.306
# L8.GoogleTrend         -0.000021         0.000045           -0.466           0.641
# L8.GOLD                -0.000309         0.001596           -0.194           0.847
# L8.OIL                 -0.000138         0.000419           -0.329           0.742
# L8.SP500               -0.002588         0.002044           -1.266           0.206
# L8.IR                   0.565990         0.069001            8.203           0.000
# L8.EPU                 -0.000046         0.000055           -0.838           0.402
# L8.transactions        -0.000149         0.000277           -0.538           0.590
# L8.VIX                 -0.000218         0.000289           -0.756           0.450
# L8.DOWJ                 0.000272         0.000725            0.376           0.707
# L9.BTC_ret             -0.000279         0.000442           -0.631           0.528
# L9.GoogleTrend          0.000043         0.000034            1.252           0.211
# L9.GOLD                -0.003672         0.001593           -2.305           0.021
# L9.OIL                 -0.000484         0.000429           -1.128           0.259
# L9.SP500                0.005371         0.001976            2.718           0.007
# L9.IR                  -0.557558         0.049972          -11.157           0.000
# L9.EPU                 -0.000028         0.000047           -0.598           0.550
# L9.transactions        -0.000258         0.000218           -1.184           0.236
# L9.VIX                 -0.000201         0.000286           -0.702           0.483
# ...
# L2.GoogleTrend          0.011819         0.011124            1.062           0.288
# L2.GOLD                 0.127959         0.390774            0.327           0.743
# L2.OIL                  0.070800         0.118930            0.595           0.552
# L2.SP500                0.690853         0.580336            1.190           0.234
# L2.IR                  30.936815        16.192580            1.911           0.056
# L2.EPU                  0.009311         0.014034            0.663           0.507
# L2.transactions         0.040136         0.073068            0.549           0.583
# L2.VIX                 -0.071805         0.075893           -0.946           0.344
# L2.DOWJ                -0.518399         0.187319           -2.767           0.006
# L3.BTC_ret              0.067042         0.115678            0.580           0.562
# L3.GoogleTrend         -0.002863         0.011135           -0.257           0.797
# L3.GOLD                 0.785123         0.393059            1.997           0.046
# L3.OIL                 -0.175688         0.117933           -1.490           0.136
# L3.SP500                0.154114         0.565527            0.273           0.785
# L3.IR                 -34.603986        16.549262           -2.091           0.037
# L3.EPU                 -0.003994         0.015022           -0.266           0.790
# L3.transactions         0.008251         0.077731            0.106           0.915
# L3.VIX                 -0.067860         0.074743           -0.908           0.364
# L3.DOWJ                -0.032569         0.187484           -0.174           0.862
# L4.BTC_ret             -0.096264         0.115691           -0.832           0.405
# L4.GoogleTrend         -0.008069         0.011286           -0.715           0.475
# L4.GOLD                 0.396161         0.404463            0.979           0.327
# L4.OIL                  0.053169         0.118403            0.449           0.653
# L4.SP500                0.163929         0.540961            0.303           0.762
# L4.IR                  48.554647        16.944494            2.866           0.004
# L4.EPU                 -0.026728         0.015881           -1.683           0.092
# L4.transactions         0.057351         0.078202            0.733           0.463
# L4.VIX                 -0.115217         0.075076           -1.535           0.125
# L4.DOWJ                -0.117783         0.189143           -0.623           0.533
# L5.BTC_ret              0.028860         0.114972            0.251           0.802
# L5.GoogleTrend          0.006651         0.011549            0.576           0.565
# L5.GOLD                -0.176648         0.406235           -0.435           0.664
# L5.OIL                  0.113447         0.116196            0.976           0.329
# L5.SP500                0.189270         0.527140            0.359           0.720
# L5.IR                 -30.689828        17.052682           -1.800           0.072
# L5.EPU                 -0.010011         0.015857           -0.631           0.528
# L5.transactions         0.003047         0.078674            0.039           0.969
# L5.VIX                 -0.010100         0.075991           -0.133           0.894
# L5.DOWJ                 0.077019         0.185687            0.415           0.678
# L6.BTC_ret             -0.214227         0.111847           -1.915           0.055
# L6.GoogleTrend         -0.013196         0.011627           -1.135           0.256
# L6.GOLD                -0.018157         0.404421           -0.045           0.964
# L6.OIL                  0.213019         0.116230            1.833           0.067
# L6.SP500                0.758107         0.527199            1.438           0.150
# L6.IR                 -33.663445        17.056687           -1.974           0.048
# L6.EPU                 -0.028123         0.015730           -1.788           0.074
# L6.transactions         0.111188         0.077326            1.438           0.150
# L6.VIX                  0.147914         0.075866            1.950           0.051
# L6.DOWJ                 0.143491         0.185950            0.772           0.440
# L7.BTC_ret             -0.051200         0.112772           -0.454           0.650
# L7.GoogleTrend          0.013296         0.011552            1.151           0.250
# L7.GOLD                -0.231068         0.404106           -0.572           0.567
# L7.OIL                  0.093737         0.108888            0.861           0.389
# L7.SP500               -0.113903         0.520238           -0.219           0.827
# L7.IR                  50.965515        17.070040            2.986           0.003
# L7.EPU                 -0.028026         0.014854           -1.887           0.059
# L7.transactions         0.091487         0.075552            1.211           0.226
# L7.VIX                 -0.007884         0.075062           -0.105           0.916
# L7.DOWJ                -0.127723         0.186841           -0.684           0.494
# L8.BTC_ret              0.017959         0.112547            0.160           0.873
# L8.GoogleTrend          0.007571         0.011519            0.657           0.511
# L8.GOLD                -0.421720         0.408976           -1.031           0.302
# L8.OIL                  0.189444         0.107447            1.763           0.078
# L8.SP500                0.296105         0.523753            0.565           0.572
# L8.IR                 -32.202453        17.679185           -1.821           0.069
# L8.EPU                 -0.037995         0.014013           -2.712           0.007
# L8.transactions         0.118035         0.070922            1.664           0.096
# L8.VIX                  0.026942         0.073969            0.364           0.716
# L8.DOWJ                 0.064298         0.185645            0.346           0.729
# L9.BTC_ret             -0.092379         0.113313           -0.815           0.415
# L9.GoogleTrend         -0.002497         0.008826           -0.283           0.777
# L9.GOLD                -0.258185         0.408217           -0.632           0.527
# L9.OIL                  0.111833         0.109991            1.017           0.309
# L9.SP500                0.156278         0.506388            0.309           0.758
# L9.IR                  24.232299        12.803613            1.893           0.058
# L9.EPU                 -0.022175         0.012035           -1.843           0.065
# L9.transactions         0.092806         0.055808            1.663           0.096
# L9.VIX                  0.039747         0.073233            0.543           0.587
# L9.DOWJ                -0.003458         0.186738           -0.019           0.985
# ==================================================================================
#
# Results for equation DOWJ
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.002042         0.001875            1.089           0.276
# L1.BTC_ret              0.038589         0.037920            1.018           0.309
# L1.GoogleTrend          0.000042         0.002965            0.014           0.989
# L1.GOLD                 0.219794         0.133937            1.641           0.101
# L1.OIL                 -0.020348         0.041775           -0.487           0.626
# L1.SP500               -0.375569         0.198888           -1.888           0.059
# L1.IR                  10.284652         3.948595            2.605           0.009
# L1.EPU                 -0.002362         0.004193           -0.563           0.573
# L1.transactions         0.006883         0.019724            0.349           0.727
# L1.VIX                 -0.032214         0.026210           -1.229           0.219
# L1.DOWJ                 0.038555         0.064433            0.598           0.550
# L2.BTC_ret              0.082193         0.038768            2.120           0.034
# L2.GoogleTrend         -0.000900         0.003820           -0.236           0.814
# L2.GOLD                 0.080731         0.134200            0.602           0.547
# L2.OIL                 -0.054102         0.040843           -1.325           0.185
# L2.SP500                0.203905         0.199299            1.023           0.306
# L2.IR                  -2.018336         5.560851           -0.363           0.717
# L2.EPU                 -0.006233         0.004820           -1.293           0.196
# L2.transactions        -0.003580         0.025093           -0.143           0.887
# L2.VIX                  0.022662         0.026063            0.870           0.385
# L2.DOWJ                 0.129226         0.064329            2.009           0.045
# L3.BTC_ret              0.036563         0.039726            0.920           0.357
# L3.GoogleTrend         -0.001120         0.003824           -0.293           0.770
# L3.GOLD                -0.025242         0.134984           -0.187           0.852
# L3.OIL                  0.118113         0.040501            2.916           0.004
# L3.SP500               -0.218080         0.194213           -1.123           0.261
# L3.IR                  -7.703847         5.683343           -1.356           0.175
# L3.EPU                 -0.006330         0.005159           -1.227           0.220
# L3.transactions        -0.022189         0.026694           -0.831           0.406
# L3.VIX                 -0.001947         0.025668           -0.076           0.940
# L3.DOWJ                 0.007709         0.064386            0.120           0.905
# L4.BTC_ret              0.026827         0.039731            0.675           0.500
# L4.GoogleTrend         -0.000017         0.003876           -0.004           0.996
# L4.GOLD                -0.235266         0.138901           -1.694           0.090
# L4.OIL                  0.036872         0.040662            0.907           0.365
# L4.SP500               -0.160346         0.185777           -0.863           0.388
# L4.IR                 -15.506547         5.819073           -2.665           0.008
# L4.EPU                 -0.000013         0.005454           -0.002           0.998
# L4.transactions        -0.038989         0.026856           -1.452           0.147
# L4.VIX                  0.010196         0.025783            0.395           0.692
# L4.DOWJ                -0.001316         0.064955           -0.020           0.984
# L5.BTC_ret              0.022521         0.039483            0.570           0.568
# L5.GoogleTrend          0.004086         0.003966            1.030           0.303
# L5.GOLD                 0.177650         0.139509            1.273           0.203
# L5.OIL                 -0.055435         0.039904           -1.389           0.165
# L5.SP500                0.428924         0.181030            2.369           0.018
# L5.IR                  15.265535         5.856227            2.607           0.009
# L5.EPU                 -0.007173         0.005446           -1.317           0.188
# L5.transactions        -0.014488         0.027018           -0.536           0.592
# L5.VIX                  0.033588         0.026097            1.287           0.198
# L5.DOWJ                -0.091350         0.063769           -1.433           0.152
# L6.BTC_ret              0.009012         0.038410            0.235           0.814
# L6.GoogleTrend         -0.001979         0.003993           -0.496           0.620
# L6.GOLD                -0.105978         0.138886           -0.763           0.445
# L6.OIL                  0.026429         0.039916            0.662           0.508
# L6.SP500               -0.067106         0.181050           -0.371           0.711
# L6.IR                  10.034327         5.857602            1.713           0.087
# L6.EPU                 -0.003534         0.005402           -0.654           0.513
# L6.transactions        -0.028639         0.026555           -1.078           0.281
# L6.VIX                 -0.028727         0.026054           -1.103           0.270
# L6.DOWJ                -0.115693         0.063859           -1.812           0.070
# L7.BTC_ret             -0.027959         0.038728           -0.722           0.470
# L7.GoogleTrend         -0.002717         0.003967           -0.685           0.493
# L7.GOLD                -0.195469         0.138778           -1.409           0.159
# L7.OIL                 -0.078154         0.037394           -2.090           0.037
# L7.SP500                0.200395         0.178660            1.122           0.262
# L7.IR                 -27.748453         5.862188           -4.733           0.000
# L7.EPU                 -0.006092         0.005101           -1.194           0.232
# L7.transactions        -0.030779         0.025946           -1.186           0.236
# L7.VIX                 -0.014458         0.025778           -0.561           0.575
# L7.DOWJ                -0.035450         0.064165           -0.552           0.581
# L8.BTC_ret             -0.026332         0.038651           -0.681           0.496
# L8.GoogleTrend          0.007148         0.003956            1.807           0.071
# L8.GOLD                 0.019334         0.140450            0.138           0.891
# L8.OIL                 -0.092015         0.036899           -2.494           0.013
# L8.SP500               -0.149511         0.179867           -0.831           0.406
# L8.IR                  33.100739         6.071380            5.452           0.000
# L8.EPU                  0.000107         0.004812            0.022           0.982
# L8.transactions        -0.040648         0.024356           -1.669           0.095
# L8.VIX                 -0.013815         0.025402           -0.544           0.587
# L8.DOWJ                -0.021853         0.063754           -0.343           0.732
# L9.BTC_ret              0.036687         0.038914            0.943           0.346
# L9.GoogleTrend         -0.005856         0.003031           -1.932           0.053
# L9.GOLD                 0.008209         0.140190            0.059           0.953
# L9.OIL                 -0.016747         0.037773           -0.443           0.658
# L9.SP500                0.366967         0.173904            2.110           0.035
# L9.IR                 -16.892789         4.397013           -3.842           0.000
# L9.EPU                 -0.003284         0.004133           -0.795           0.427
# L9.transactions        -0.025148         0.019166           -1.312           0.189
# L9.VIX                  0.038645         0.025150            1.537           0.124
# L9.DOWJ                 0.044352         0.064129            0.692           0.489
# ==================================================================================
#
# Correlation matrix of residuals
#                  BTC_ret  GoogleTrend      GOLD       OIL     SP500        IR       EPU  transactions       VIX      DOWJ
# BTC_ret         1.000000     0.004644  0.159142  0.139170  0.365290  0.026942 -0.065806      0.134023 -0.330023  0.206523
# GoogleTrend     0.004644     1.000000 -0.016570 -0.086767 -0.077913  0.037882 -0.015695     -0.002171  0.064507 -0.043176
# GOLD            0.159142    -0.016570  1.000000  0.060733  0.128856  0.000324  0.108289     -0.066738 -0.070366 -0.020056
# OIL             0.139170    -0.086767  0.060733  1.000000  0.301956  0.031756 -0.056263      0.022835 -0.237701  0.239480
# SP500           0.365290    -0.077913  0.128856  0.301956  1.000000  0.074682  0.024602      0.060520 -0.748939  0.612637
# IR              0.026942     0.037882  0.000324  0.031756  0.074682  1.000000 -0.014702      0.008485 -0.050468  0.113771
# EPU            -0.065806    -0.015695  0.108289 -0.056263  0.024602 -0.014702  1.000000      0.025519 -0.021030 -0.000085
# transactions    0.134023    -0.002171 -0.066738  0.022835  0.060520  0.008485  0.025519      1.000000 -0.092102  0.083536
# VIX            -0.330023     0.064507 -0.070366 -0.237701 -0.748939 -0.050468 -0.021030     -0.092102  1.000000 -0.490829
# DOWJ            0.206523    -0.043176 -0.020056  0.239480  0.612637  0.113771 -0.000085      0.083536 -0.490829  1.000000

# %%
results = var.fit(1)
#We can check the summary of the model by.
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 20, Jan, 2022
# Time:                     16:51:44
# --------------------------------------------------------------------
# No. of Equations:         10.0000    BIC:                   -65.6030
# Nobs:                     479.000    HQIC:                  -66.1844
# Log likelihood:           9254.66    FPE:                1.23862e-29
# AIC:                     -66.5610    Det(Omega_mle):     9.87036e-30
# --------------------------------------------------------------------
# Results for equation BTC_ret
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.005316         0.002415            2.201           0.028
# L1.BTC_ret             -0.088635         0.050250           -1.764           0.078
# L1.GoogleTrend          0.000510         0.002059            0.248           0.804
# L1.GOLD                -0.053084         0.182900           -0.290           0.772
# L1.OIL                  0.008220         0.049933            0.165           0.869
# L1.SP500               -0.265153         0.209775           -1.264           0.206
# L1.IR                  -0.434452         0.511014           -0.850           0.395
# L1.EPU                 -0.003386         0.005175           -0.654           0.513
# L1.transactions         0.026667         0.021741            1.227           0.220
# L1.VIX                 -0.047009         0.034213           -1.374           0.169
# L1.DOWJ                 0.011213         0.083906            0.134           0.894
# ==================================================================================
#
# Results for equation GoogleTrend
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.015713         0.025356            0.620           0.535
# L1.BTC_ret              0.644958         0.527534            1.223           0.221
# L1.GoogleTrend          0.881982         0.021618           40.798           0.000
# L1.GOLD                 0.098068         1.920118            0.051           0.959
# L1.OIL                  0.205471         0.524202            0.392           0.695
# L1.SP500               -1.811345         2.202261           -0.822           0.411
# L1.IR                  -6.171632         5.364732           -1.150           0.250
# L1.EPU                 -0.000375         0.054328           -0.007           0.994
# L1.transactions        -0.522115         0.228241           -2.288           0.022
# L1.VIX                  0.236505         0.359172            0.658           0.510
# L1.DOWJ                 0.898487         0.880861            1.020           0.308
# ==================================================================================
#
# Results for equation GOLD
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.000574         0.000613            0.936           0.349
# L1.BTC_ret              0.021981         0.012750            1.724           0.085
# L1.GoogleTrend         -0.000866         0.000523           -1.657           0.098
# L1.GOLD                 0.012348         0.046408            0.266           0.790
# L1.OIL                  0.010500         0.012670            0.829           0.407
# L1.SP500               -0.193469         0.053227           -3.635           0.000
# L1.IR                  -0.069863         0.129662           -0.539           0.590
# L1.EPU                  0.000745         0.001313            0.567           0.571
# L1.transactions        -0.010727         0.005516           -1.944           0.052
# L1.VIX                 -0.024302         0.008681           -2.799           0.005
# L1.DOWJ                 0.032458         0.021290            1.525           0.127
# ==================================================================================
#
# Results for equation OIL
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.005010         0.002328            2.152           0.031
# L1.BTC_ret              0.039621         0.048444            0.818           0.413
# L1.GoogleTrend          0.000570         0.001985            0.287           0.774
# L1.GOLD                 0.003018         0.176325            0.017           0.986
# L1.OIL                  0.053292         0.048138            1.107           0.268
# L1.SP500               -0.604097         0.202234           -2.987           0.003
# L1.IR                  -1.231390         0.492645           -2.500           0.012
# L1.EPU                  0.001506         0.004989            0.302           0.763
# L1.transactions         0.000185         0.020959            0.009           0.993
# L1.VIX                 -0.068764         0.032983           -2.085           0.037
# L1.DOWJ                 0.045552         0.080890            0.563           0.573
# ==================================================================================
#
# Results for equation SP500
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.002600         0.000815            3.189           0.001
# L1.BTC_ret             -0.044660         0.016964           -2.633           0.008
# L1.GoogleTrend         -0.000124         0.000695           -0.178           0.859
# L1.GOLD                 0.159736         0.061745            2.587           0.010
# L1.OIL                  0.002106         0.016857            0.125           0.901
# L1.SP500               -0.466408         0.070817           -6.586           0.000
# L1.IR                  -0.517138         0.172512           -2.998           0.003
# L1.EPU                 -0.002383         0.001747           -1.364           0.172
# L1.transactions         0.009429         0.007339            1.285           0.199
# L1.VIX                 -0.028822         0.011550           -2.495           0.013
# L1.DOWJ                 0.055103         0.028326            1.945           0.052
# ==================================================================================
#
# Results for equation IR
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.000014         0.000023            0.619           0.536
# L1.BTC_ret             -0.000667         0.000479           -1.392           0.164
# L1.GoogleTrend         -0.000003         0.000020           -0.149           0.881
# L1.GOLD                 0.005139         0.001744            2.947           0.003
# L1.OIL                  0.000123         0.000476            0.259           0.795
# L1.SP500               -0.007057         0.002000           -3.529           0.000
# L1.IR                   0.983257         0.004871          201.844           0.000
# L1.EPU                 -0.000045         0.000049           -0.909           0.363
# L1.transactions         0.000459         0.000207            2.217           0.027
# L1.VIX                 -0.000144         0.000326           -0.441           0.659
# L1.DOWJ                 0.001301         0.000800            1.627           0.104
# ==================================================================================
#
# Results for equation EPU
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.003355         0.019629            0.171           0.864
# L1.BTC_ret             -0.140888         0.408389           -0.345           0.730
# L1.GoogleTrend          0.001982         0.016736            0.118           0.906
# L1.GOLD                -2.488159         1.486454           -1.674           0.094
# L1.OIL                 -0.275217         0.405809           -0.678           0.498
# L1.SP500               -2.313404         1.704875           -1.357           0.175
# L1.IR                   1.277345         4.153094            0.308           0.758
# L1.EPU                 -0.395614         0.042058           -9.406           0.000
# L1.transactions        -0.262128         0.176692           -1.484           0.138
# L1.VIX                 -0.380079         0.278052           -1.367           0.172
# L1.DOWJ                -0.064327         0.681916           -0.094           0.925
# ==================================================================================
#
# Results for equation transactions
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.001350         0.004301           -0.314           0.754
# L1.BTC_ret              0.353949         0.089477            3.956           0.000
# L1.GoogleTrend         -0.004013         0.003667           -1.094           0.274
# L1.GOLD                 0.020927         0.325677            0.064           0.949
# L1.OIL                  0.076582         0.088912            0.861           0.389
# L1.SP500               -0.427888         0.373533           -1.146           0.252
# L1.IR                  -0.250437         0.909930           -0.275           0.783
# L1.EPU                 -0.004783         0.009215           -0.519           0.604
# L1.transactions        -0.523590         0.038713          -13.525           0.000
# L1.VIX                  0.050496         0.060920            0.829           0.407
# L1.DOWJ                 0.024877         0.149406            0.167           0.868
# ==================================================================================
#
# Results for equation VIX
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.008293         0.004469           -1.856           0.063
# L1.BTC_ret              0.113235         0.092972            1.218           0.223
# L1.GoogleTrend         -0.000125         0.003810           -0.033           0.974
# L1.GOLD                -0.285091         0.338401           -0.842           0.400
# L1.OIL                 -0.009747         0.092385           -0.106           0.916
# L1.SP500                1.451808         0.388126            3.741           0.000
# L1.IR                   2.778733         0.945478            2.939           0.003
# L1.EPU                  0.006869         0.009575            0.717           0.473
# L1.transactions        -0.077854         0.040225           -1.935           0.053
# L1.VIX                  0.017699         0.063300            0.280           0.780
# L1.DOWJ                -0.286895         0.155243           -1.848           0.065
# ==================================================================================
#
# Results for equation DOWJ
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.002820         0.001733            1.627           0.104
# L1.BTC_ret             -0.024327         0.036058           -0.675           0.500
# L1.GoogleTrend          0.000229         0.001478            0.155           0.877
# L1.GOLD                 0.445001         0.131245            3.391           0.001
# L1.OIL                  0.000827         0.035830            0.023           0.982
# L1.SP500               -0.858321         0.150530           -5.702           0.000
# L1.IR                  -1.053767         0.366693           -2.874           0.004
# L1.EPU                 -0.003113         0.003713           -0.838           0.402
# L1.transactions         0.014049         0.015601            0.901           0.368
# L1.VIX                 -0.061336         0.024550           -2.498           0.012
# L1.DOWJ                 0.153827         0.060209            2.555           0.011
# ==================================================================================
#
# Correlation matrix of residuals
#                  BTC_ret  GoogleTrend      GOLD       OIL     SP500        IR       EPU  transactions       VIX      DOWJ
# BTC_ret         1.000000    -0.038241  0.162899  0.139592  0.349881  0.027415 -0.045594      0.049266 -0.351588  0.261191
# GoogleTrend    -0.038241     1.000000 -0.040814 -0.046420 -0.038026  0.049707  0.009276      0.005893  0.055407 -0.020340
# GOLD            0.162899    -0.040814  1.000000  0.071496  0.141428  0.052963  0.051706     -0.055968 -0.057424  0.014999
# OIL             0.139592    -0.046420  0.071496  1.000000  0.280076  0.062688 -0.030744      0.014383 -0.218396  0.241081
# SP500           0.349881    -0.038026  0.141428  0.280076  1.000000  0.163069  0.016106      0.036295 -0.672287  0.642351
# IR              0.027415     0.049707  0.052963  0.062688  0.163069  1.000000 -0.047179      0.047923 -0.051171  0.209639
# EPU            -0.045594     0.009276  0.051706 -0.030744  0.016106 -0.047179  1.000000     -0.038582 -0.020717  0.030355
# transactions    0.049266     0.005893 -0.055968  0.014383  0.036295  0.047923 -0.038582      1.000000 -0.065601  0.058356
# VIX            -0.351588     0.055407 -0.057424 -0.218396 -0.672287 -0.051171 -0.020717     -0.065601  1.000000 -0.483071
# DOWJ            0.261191    -0.020340  0.014999  0.241081  0.642351  0.209639  0.030355      0.058356 -0.483071  1.000000

# %% [markdown]
# #### If needed also ARDL

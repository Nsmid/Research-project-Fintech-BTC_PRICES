# %% [markdown]
# # Research Project

# %% [markdown]
# #### Finding data
# - BTC price from API? or from different sources
# - Oil, Gold, S&P 500 from Yahoo/Crsp/FactSet?
# - Google trend - we can find google trend also through api --> pytrends: https://pypi.org/project/pytrends/
# - Inflation, Interest rate in the US - CRSP or some other webpage with reliable info
# + Deciding whether we will use returns/ prices/ so on :)

# %%
#pip install pandas-datareader

# %%
import pandas_datareader.data as web
import pandas as pd
import datetime as dt
from datetime import datetime
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.formula.api import ols
from statsmodels.tsa.api import VAR
from statsmodels.tools.eval_measures import rmse, aic
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Factor 1, 2 + 3
# Gold, Oil, S&P500

# %%
#Import yahoo finance data: Gold, SP500, Oil
yahoofin_prices = web.DataReader(['GC=F', 'CL=F', '^GSPC'], 'yahoo', start='2019-12-31', end='2022-01-18')["Adj Close"]
yahoofin_prices.rename(columns={'GC=F': 'GOLD', 'CL=F': 'OIL', '^GSPC': 'SP500'}, inplace=True)

# %%
#Print Gold, Oil, SP500 prices
yahoofin_prices.head()
# Out:
# Symbols            GOLD        OIL        SP500
# Date
# 2019-12-31  1519.500000  61.060001  3230.780029
# 2020-01-02  1524.500000  61.180000  3257.850098
# 2020-01-03  1549.199951  63.049999  3234.850098
# 2020-01-06  1566.199951  63.270000  3246.280029
# 2020-01-07  1571.800049  62.700001  3237.179932

# %%
#Info of Gold, Oil, SP500 prices
yahoofin_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 518 entries, 2019-12-31 to 2022-01-18
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GOLD    518 non-null    float64
#  1   OIL     518 non-null    float64
#  2   SP500   517 non-null    float64
# dtypes: float64(3)
# memory usage: 16.2 KB

# %%
#Calculate the returns of the prices
yahoofin_returns = yahoofin_prices.copy()
for i in range(1,len(yahoofin_prices+1)):
    yahoofin_returns.iloc[i] = np.log(yahoofin_prices.iloc[i]/yahoofin_prices.iloc[i-1])
yahoofin_returns = yahoofin_returns[1:]
# Out:
# /Users/carlarunden/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#Print Gold, Oil, SP500 returns
yahoofin_returns.head()
# Out:
# Symbols         GOLD       OIL     SP500
# Date
# 2020-01-02  0.003285  0.001963  0.008344
# 2020-01-03  0.016072  0.030108 -0.007085
# 2020-01-06  0.010914  0.003483  0.003527
# 2020-01-07  0.003569 -0.009050 -0.002807
# 2020-01-08 -0.009204 -0.050538  0.004890

# %% [markdown]
# ### Factor 4
# Effective Federal Funds Rate

# %%
#Import Effective federal funds rate (https://fred.stlouisfed.org/series/EFFR) 
interestrate = web.DataReader(['EFFR'], 'fred', start='2020-01-01', end='2022-01-01')
interestrate.rename(columns={'EFFR': 'IR'}, inplace=True)
interestrate['IR']=interestrate['IR']

# %%
interestrate
# Out:
#               IR
# DATE
# 2020-01-01   NaN
# 2020-01-02  1.55
# 2020-01-03  1.55
# 2020-01-06  1.55
# 2020-01-07  1.55
# ...          ...
# 2021-12-27  0.08
# 2021-12-28  0.08
# 2021-12-29  0.08
# 2021-12-30  0.08
# 2021-12-31  0.07
#
# [523 rows x 1 columns]

# %%
#Take the change and ln
interestratechange_ln = interestrate.copy()
for i in range(1,len(interestrate+1)):
    interestratechange_ln.iloc[i] = np.log(interestrate.iloc[i]/interestrate.iloc[i-1])
interestratechange_ln = interestratechange_ln[1:]

# %%
interestratechange_ln.head()
# Out:
#              IR
# DATE
# 2020-01-02  NaN
# 2020-01-03  0.0
# 2020-01-06  0.0
# 2020-01-07  0.0
# 2020-01-08  0.0

# %%
#Merge first 4 factors
yahoofin_IR = yahoofin_prices.merge(interestrate, how= 'left', left_index = True, right_index = True)

# %%
#Print head
yahoofin_IR.head()
# Out:
#                    GOLD        OIL        SP500    IR
# Date
# 2019-12-31  1519.500000  61.060001  3230.780029   NaN
# 2020-01-02  1524.500000  61.180000  3257.850098  1.55
# 2020-01-03  1549.199951  63.049999  3234.850098  1.55
# 2020-01-06  1566.199951  63.270000  3246.280029  1.55
# 2020-01-07  1571.800049  62.700001  3237.179932  1.55

# %%
# df3 = web.DataReader(['CPIAUCSL'], 'fred', start='2019-11-30', end='2022-01-01')
# df3.rename(columns={'CPIAUCSL': 'INFL'}, inplace=True)

# %%
# infl = df3.copy()
# for i in range(1,len(df3+1)):
#     infl.iloc[i] = np.log(df3.iloc[i]/df3.iloc[i-1])
# infl = infl[1:]
# infl.head()

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Other possible factors

# %% [markdown]
# ### Factor 5 + 6
# US daily News Index + Bitcoin Transactions

# %%
# US Daily News Index (http://www.policyuncertainty.com/us_monthly.html)
daily_news = pd.read_csv('data/All_Daily_Policy_Data.csv')
daily_news['date'] = pd.to_datetime(dict(year=daily_news.year, month=daily_news.month, day=daily_news.day))
daily_news.set_index('date', inplace = True)
daily_news = pd.DataFrame(daily_news.daily_policy_index)
daily_news = daily_news.loc['2019-12-31':]
daily_news.rename(columns = {'daily_policy_index': 'EPU'}, inplace=True)

# %%
# The number of daily confirmed Bitcoin transactions (https://data.nasdaq.com/data/BCHAIN/NTRAN-bitcoin-number-of-transactions)
transactions = pd.read_csv('data/BCHAIN-NTRAN.csv')
transactions.sort_values(by=['Date'], ascending=True, inplace=True)
transactions['Date'] = pd.to_datetime(transactions['Date'])
transactions.set_index('Date', inplace = True)
transactions = transactions.loc['2019-12-31':]
transactions.rename(columns = {'Value': 'transactions'}, inplace=True)

# %%
#Merge the daily Index and the Bitcoin transactions
dailynews_transactions = daily_news.merge(transactions, left_index = True, right_index = True)

# %%
#Print the head
dailynews_transactions.head()
# Out:
#                EPU  transactions
# date
# 2019-12-31  105.75      293447.0
# 2020-01-01  186.06      251735.0
# 2020-01-02  139.13      295567.0
# 2020-01-03  108.10      316517.0
# 2020-01-04  212.82      287215.0

# %% [markdown]
# ### Factor 7
# VIX index

# %%
#The VIX Index is recognized as the world’s premier gauge of U.S. equity market volatility
# (https://www.cboe.com/tradable_products/vix/)
VIX = pd.read_csv('data/VIX_History.csv')
VIX['DATE'] = pd.to_datetime(VIX['DATE'])
VIX.set_index('DATE', inplace = True)
VIX = VIX.loc['2019-12-31':]
VIX.rename(columns = {'CLOSE': 'VIX'}, inplace=True)
VIX = pd.DataFrame(VIX.VIX)

# %%
#Merge the daily Index, the Bitcoin transactions and VIX
dn_trans_VIX = dailynews_transactions.merge(VIX, left_index = True, right_index = True)

# %%
#Print head
dn_trans_VIX.head()
# Out:
#                EPU  transactions    VIX
# 2019-12-31  105.75      293447.0  13.78
# 2020-01-02  139.13      295567.0  12.47
# 2020-01-03  108.10      316517.0  14.02
# 2020-01-06  147.96      299146.0  13.85
# 2020-01-07  103.98      344079.0  13.79

# %%
#Turn into Returns
dn_trans_VIX_returns = dn_trans_VIX.copy()
for i in range(1,len(dn_trans_VIX+1)):
    dn_trans_VIX_returns.iloc[i] = np.log(dn_trans_VIX.iloc[i]/dn_trans_VIX.iloc[i-1])
dn_trans_VIX_returns = dn_trans_VIX_returns[1:]

# %%
#Print return
dn_trans_VIX_returns.head()
# Out:
#                  EPU  transactions       VIX
# 2020-01-02  0.274331      0.007199 -0.099893
# 2020-01-03 -0.252352      0.068481  0.117159
# 2020-01-06  0.313885     -0.056445 -0.012200
# 2020-01-07 -0.352743      0.139940 -0.004342
# 2020-01-08 -0.131692     -0.078760 -0.024965

# %% [markdown]
# ### Factor 8 + 9
# D_infections_volatility_tracker + DOW JONES GLOBAL_DJUSCA

# %%
#Import D_infections_volatility_tracker
path = os.path.join('data','D_infections_volatility_tracker.xlsx')
df_InfVol = pd.read_excel(path)
df_EMV= df_InfVol.drop(columns=['day', 'month', 'year'])
df_emv= df_EMV.set_index('date')

# %%
df_emv.head()
# Out:
#             daily_infect_emv_index
# date
# 2020-01-01                    1.89
# 2020-01-02                    2.84
# 2020-01-03                    1.33
# 2020-01-04                    0.00
# 2020-01-05                    0.86

# %%
#Import DOW JONES GLOBAL_DJUSCA
path = os.path.join('data','DOW JONES GLOBAL_DJUSCA.csv')
df_DOWJ = pd.read_csv(path)
df_DOWJG= df_DOWJ[["Close", "Date"]]
df_DOWJG.rename(columns = {'Close': 'DOWJ'}, inplace=True)
df_DOWJG['Date'] = pd.to_datetime(df_DOWJG['Date'])
df_DOW=df_DOWJG.set_index('Date')
df_DOW.sort_values(by= 'Date', axis=0, ascending=True, inplace=True)
df_dow = pd.to_numeric(df_DOW['DOWJ'], errors='coerce')
# Out:
# /Users/carlarunden/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# <ipython-input-27-9316d9ac326a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_DOWJG['Date'] = pd.to_datetime(df_DOWJG['Date'])

# %%
df_dow.head()
# Out:
# Date
# 2020-01-02    935.13
# 2020-01-03    923.15
# 2020-01-06    922.07
# 2020-01-07    923.21
# 2020-01-08    931.08
# Name: DOWJ, dtype: float64

# %%
df303 = dn_trans_VIX.merge(df_dow, left_index = True, right_index = True)
df404 = df303.merge(df_emv, left_index = True, right_index = True)

# %%
df404.head()
# Out:
#                EPU  transactions    VIX    DOWJ  daily_infect_emv_index
# 2020-01-02  139.13      295567.0  12.47  935.13                    2.84
# 2020-01-03  108.10      316517.0  14.02  923.15                    1.33
# 2020-01-06  147.96      299146.0  13.85  922.07                    0.99
# 2020-01-07  103.98      344079.0  13.79  923.21                    0.00
# 2020-01-08   91.15      318019.0  13.45  931.08                    0.56

# %%
#Transform into returns
df_merge_returns = df303.copy()
for i in range(1,len(df303+1)):
    df_merge_returns.iloc[i] = np.log(df303.iloc[i]/df303.iloc[i-1])
df_merge_returns = df_merge_returns[1:]

# %%
df_all= df_merge_returns.merge(df_emv, left_index=True, right_index=True)

# %%
df_merge_returns.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# I think for the daily infectious diseasse tracker, we cant take log --> it will divide somethin with 0 and the result will be nan/-inf. So for that i thik its better to standardize, but for all others i think it is fine.

# %% [markdown]
# ### Factor 10-13
# Exchange rates

# %%
#Import Exchange rate Romania
romania = os.path.join('data','USD_RON_.csv')
df_romania = pd.read_csv(romania)
df_romania['Date'] = pd.to_datetime(df_romania['Date'])
df_romania=df_romania.set_index('Date')

#Delete the percentage sign
df_romania['Change %'] = list(map(lambda x: x[:-1], df_romania['Change %'].values))

#Rename
df_romania.rename(columns = {'Change %': 'USD_RON Change %'}, inplace=True)

# %%
df_romania.head()
# Out:
#            USD_RON Change %
# Date
# 2022-01-20           -0.13
# 2022-01-19           -0.14
# 2022-01-18            0.73
# 2022-01-17            0.07
# 2022-01-14            0.35

# %%
#Import Exchange rate India
india = os.path.join('data','USD_INR.csv')
df_india = pd.read_csv(india)
df_india['Date'] = pd.to_datetime(df_india['Date'])
df_india=df_india.set_index('Date')

#Delete the percentage sign
df_india['Change %'] = list(map(lambda x: x[:-1], df_india['Change %'].values))

#Rename
df_india.rename(columns = {'Change %': 'USD_INR Change %'}, inplace=True)

# %%
df_india.head()
# Out:
#            USD_INR Change %
# Date
# 2022-01-20           -0.07
# 2022-01-19           -0.18
# 2022-01-18            0.43
# 2022-01-17            0.12
# 2022-01-14            0.26

# %%
#Import Exchange rate kazakhstan
kazakhstan = os.path.join('data','USD_KZT_.csv')
df_kazakhstan = pd.read_csv(kazakhstan)
df_kazakhstan['Date'] = pd.to_datetime(df_kazakhstan['Date'])
df_kazakhstan=df_kazakhstan.set_index('Date')

#Delete the percentage sign
df_kazakhstan['Change %'] = list(map(lambda x: x[:-1], df_kazakhstan['Change %'].values))

#Rename
df_kazakhstan.rename(columns = {'Change %': 'USD_KZT Change %'}, inplace=True)

# %%
#Print head
df_kazakhstan.head()
# Out:
#            USD_KZT Change %
# Date
# 2022-01-20           -0.14
# 2022-01-19            0.16
# 2022-01-18            0.09
# 2022-01-17            0.03
# 2022-01-14            0.10

# %%
dfs_join= df_kazakhstan.merge(df_india,on='Date').merge(df_romania ,on='Date')
dfs_currency= dfs_join.astype(float)

# %% [markdown]
# ### Factor 14 CRIX

# %%
CRIX = os.path.join('data','PerformanceGraphExport.xls')
df_CRIX = pd.read_excel(CRIX)
df_CRIX.rename(columns = {'Effective date ': 'date', 'Royalton CRIX Crypto Index': 'CRIX'}, inplace=True)
df_CRIX.set_index('date', inplace=True)

# %%
df_CRIX.head()
# Out:
#               CRIX
# date
# 2020-01-01  530.40
# 2020-01-02  509.33
# 2020-01-03  538.09
# 2020-01-06  560.83
# 2020-01-07  599.78

# %%
#Turn into Returns
CRIX_returns = df_CRIX.copy()
for i in range(1,len(df_CRIX+1)):
    CRIX_returns.iloc[i] = np.log(df_CRIX.iloc[i]/df_CRIX.iloc[i-1])
CRIX_returns = CRIX_returns[1:]

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Factor 15-16
#
# BTC price + google trend for Bitcoin in US

# %%
pip install pytrends
# Out:
# Requirement already satisfied: pytrends in /Users/carlarunden/opt/anaconda3/lib/python3.8/site-packages (4.7.3)
# Requirement already satisfied: pandas>=0.25 in /Users/carlarunden/opt/anaconda3/lib/python3.8/site-packages (from pytrends) (1.2.4)
# Requirement already satisfied: requests in /Users/carlarunden/opt/anaconda3/lib/python3.8/site-packages (from pytrends) (2.25.1)
# Requirement already satisfied: lxml in /Users/carlarunden/opt/anaconda3/lib/python3.8/site-packages (from pytrends) (4.6.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/carlarunden/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25->pytrends) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/carlarunden/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25->pytrends) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/carlarunden/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25->pytrends) (1.20.1)
# Requirement already satisfied: six>=1.5 in /Users/carlarunden/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.25->pytrends) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/carlarunden/opt/anaconda3/lib/python3.8/site-packages (from requests->pytrends) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/carlarunden/opt/anaconda3/lib/python3.8/site-packages (from requests->pytrends) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/carlarunden/opt/anaconda3/lib/python3.8/site-packages (from requests->pytrends) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /Users/carlarunden/opt/anaconda3/lib/python3.8/site-packages (from requests->pytrends) (2.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pytrends.request import TrendReq
from pytrends import dailydata

Bitcoin_df = dailydata.get_daily_data('Bitcoin', 2020, 1, 2022, 1, geo = 'US')
# Out:
# Bitcoin:2020-01-01 2020-01-31
# Bitcoin:2020-02-01 2020-02-29
# Bitcoin:2020-03-01 2020-03-31
# Bitcoin:2020-04-01 2020-04-30
# Bitcoin:2020-05-01 2020-05-31
# Bitcoin:2020-06-01 2020-06-30
# Bitcoin:2020-07-01 2020-07-31
# Bitcoin:2020-08-01 2020-08-31
# Bitcoin:2020-09-01 2020-09-30
# Bitcoin:2020-10-01 2020-10-31
# Bitcoin:2020-11-01 2020-11-30
# Bitcoin:2020-12-01 2020-12-31
# Bitcoin:2021-01-01 2021-01-31
# Bitcoin:2021-02-01 2021-02-28
# Bitcoin:2021-03-01 2021-03-31
# Bitcoin:2021-04-01 2021-04-30
# Bitcoin:2021-05-01 2021-05-31
# Bitcoin:2021-06-01 2021-06-30
# Bitcoin:2021-07-01 2021-07-31
# Bitcoin:2021-08-01 2021-08-31
# Bitcoin:2021-09-01 2021-09-30
# Bitcoin:2021-10-01 2021-10-31
# Bitcoin:2021-11-01 2021-11-30
# Bitcoin:2021-12-01 2021-12-31
# Bitcoin:2022-01-01 2022-01-31

# %%
Bitcoin_df.head()
# Out:
#             Bitcoin_unscaled  Bitcoin_monthly isPartial  scale  Bitcoin
# date
# 2020-01-01                47              NaN       NaN    NaN      NaN
# 2020-01-02                63              NaN       NaN    NaN      NaN
# 2020-01-03                75              NaN       NaN    NaN      NaN
# 2020-01-04                70              NaN       NaN    NaN      NaN
# 2020-01-05                57             13.0     False   0.13     7.41

# %%
path = os.path.join('data','BTC-USD-2.csv')
df_data = pd.read_csv(path)
df_data.drop(columns=['Open', 'High', 'Low', 'Adj Close', 'Volume'], inplace=True)
df_data['Date']=pd.to_datetime(df_data['Date'])

# %%
df_btc=df_data.set_index('Date')

# %%
returns_btc = df_btc.copy()
for i in range(1,len(df_btc+1)):
    returns_btc.iloc[i] = np.log(df_btc.iloc[i]/df_btc.iloc[i-1])
returns_btc = returns_btc[1:]

# %%
returns_btc.head()
# Out:
#                Close
# Date
# 2020-01-02 -0.030273
# 2020-01-03  0.050172
# 2020-01-04  0.008915
# 2020-01-05  0.000089
# 2020-01-06  0.047161

# %% [markdown]
# ### Factor 17 - Bitcoin Tweets

# %%
csv_data_raw = '2014-04-08, 8193\n2014-04-09, 15039\n2014-04-10, 14907\n2014-04-11, 7582\n2014-04-12, 10674\n2014-04-13, 13266\n2014-04-14, 14835\n2014-04-15, 15790\n2014-04-16, 15215\n2014-04-17, 14028\n2014-04-18, 12337\n2014-04-19, 12139\n2014-04-20, 14244\n2014-04-21, 16098\n2014-04-22, 16232\n2014-04-23, 15471\n2014-04-24, 15255\n2014-04-25, 12283\n2014-04-26, 11667\n2014-04-27, 15969\n2014-04-28, 16706\n2014-04-29, 17588\n2014-04-30, 16988\n2014-05-01, 20057\n2014-05-02, 12910\n2014-05-03, 12716\n2014-05-04, 21273\n2014-05-05, 16806\n2014-05-06, 16970\n2014-05-07, 21518\n2014-05-08, 17442\n2014-05-09, 14225\n2014-05-10, 13469\n2014-05-11, 15910\n2014-05-12, 16935\n2014-05-13, 18167\n2014-05-14, 32817\n2014-05-15, 14474\n2014-05-16, 14587\n2014-05-17, 12892\n2014-05-18, 13595\n2014-05-19, 21515\n2014-05-20, 20254\n2014-05-21, 20217\n2014-05-22, 19485\n2014-05-23, 13630\n2014-05-24, 13823\n2014-05-25, 14792\n2014-05-26, 19718\n2014-05-27, 18545\n2014-05-28, 17571\n2014-05-29, 21731\n2014-05-30, 12882\n2014-05-31, 12849\n2014-06-01, 16427\n2014-06-02, 17858\n2014-06-03, 18010\n2014-06-04, 18707\n2014-06-05, 16611\n2014-06-06, 12557\n2014-06-07, 12134\n2014-06-08, 14497\n2014-06-09, 16631\n2014-06-10, 19356\n2014-06-11, 19092\n2014-06-12, 19128\n2014-06-13, 16078\n2014-06-14, 15810\n2014-06-15, 18430\n2014-06-16, 18560\n2014-06-17, 15957\n2014-06-18, 17605\n2014-06-19, 17459\n2014-06-20, 15113\n2014-06-21, 13838\n2014-06-22, 16325\n2014-06-23, 17005\n2014-06-24, 17683\n2014-06-25, 17534\n2014-06-26, 17587\n2014-06-27, 15236\n2014-06-28, 15482\n2014-06-29, 19860\n2014-06-30, 20443\n2014-07-01, 21375\n2014-07-02, 22046\n2014-07-03, 22659\n2014-07-04, 16997\n2014-07-05, 17331\n2014-07-06, 22248\n2014-07-07, 24425\n2014-07-08, 24542\n2014-07-09, 23242\n2014-07-10, 20939\n2014-07-11, 16719\n2014-07-12, 16133\n2014-07-13, 20287\n2014-07-14, 25031\n2014-07-15, 21984\n2014-07-16, 23305\n2014-07-17, 25897\n2014-07-18, 20261\n2014-07-19, 16827\n2014-07-20, 18501\n2014-07-21, 18386\n2014-07-22, 20612\n2014-07-23, 20448\n2014-07-24, 19971\n2014-07-25, 16000\n2014-07-26, 15621\n2014-07-27, 23384\n2014-07-28, 21797\n2014-07-29, 22092\n2014-07-30, 22160\n2014-07-31, 21585\n2014-08-01, 18531\n2014-08-02, 17187\n2014-08-03, 20609\n2014-08-04, 21073\n2014-08-05, 22471\n2014-08-06, 24516\n2014-08-07, 23126\n2014-08-08, 21820\n2014-08-09, 20814\n2014-08-10, 21388\n2014-08-11, 22551\n2014-08-12, 23725\n2014-08-13, 24887\n2014-08-14, 22725\n2014-08-15, 23487\n2014-08-16, 22608\n2014-08-17, 21867\n2014-08-18, 24106\n2014-08-19, 26924\n2014-08-20, 22176\n2014-08-21, 21222\n2014-08-22, 17389\n2014-08-23, 16318\n2014-08-24, 19062\n2014-08-25, 19596\n2014-08-26, 19625\n2014-08-27, 22229\n2014-08-28, 19838\n2014-08-29, 18905\n2014-08-30, 17226\n2014-08-31, 18661\n2014-09-01, 22901\n2014-09-02, 22113\n2014-09-03, 24968\n2014-09-04, 22368\n2014-09-05, 21053\n2014-09-06, 17730\n2014-09-07, 22751\n2014-09-08, 16169\n2014-09-09, 16616\n2014-09-10, 27367\n2014-09-11, 24097\n2014-09-12, 18209\n2014-09-13, 18671\n2014-09-14, 23392\n2014-09-15, 21176\n2014-09-16, 27946\n2014-09-17, 21135\n2014-09-18, 20775\n2014-09-19, 17607\n2014-09-20, 17026\n2014-09-21, 14984\n2014-09-22, 23489\n2014-09-23, 20675\n2014-09-24, 20757\n2014-09-25, 19512\n2014-09-26, 17202\n2014-09-27, 16636\n2014-09-28, 19660\n2014-09-29, 21073\n2014-09-30, 18636\n2014-10-01, 18380\n2014-10-02, 20207\n2014-10-03, 18214\n2014-10-04, 20031\n2014-10-05, 25065\n2014-10-06, 22543\n2014-10-07, 24408\n2014-10-08, 24075\n2014-10-09, 19090\n2014-10-10, 17107\n2014-10-11, 17072\n2014-10-12, 22018\n2014-10-13, 25804\n2014-10-14, 23992\n2014-10-15, 24445\n2014-10-16, 21491\n2014-10-17, 20572\n2014-10-18, 18259\n2014-10-19, 23312\n2014-10-20, 22499\n2014-10-21, 20348\n2014-10-22, 21036\n2014-10-23, 11147\n2014-10-24, 22449\n2014-10-25, 20090\n2014-10-26, 21632\n2014-10-27, 20173\n2014-10-28, 22081\n2014-10-29, 22855\n2014-10-30, 22906\n2014-10-31, 30263\n2014-11-01, 21408\n2014-11-02, 26060\n2014-11-03, 20992\n2014-11-04, 20871\n2014-11-05, 24348\n2014-11-06, 24244\n2014-11-07, 18964\n2014-11-08, 18949\n2014-11-09, 22516\n2014-11-10, 23156\n2014-11-11, 25601\n2014-11-12, 26798\n2014-11-13, 23449\n2014-11-14, 21104\n2014-11-15, 21652\n2014-11-16, 25728\n2014-11-17, 28238\n2014-11-18, 25117\n2014-11-19, 23707\n2014-11-20, 24577\n2014-11-21, 22344\n2014-11-22, 20544\n2014-11-23, 25545\n2014-11-24, 25985\n2014-11-25, 27929\n2014-11-26, 25790\n2014-11-27, 24830\n2014-11-28, 26555\n2014-11-29, 20117\n2014-11-30, 26508\n2014-12-01, 32744\n2014-12-02, 24990\n2014-12-03, 26370\n2014-12-04, 25043\n2014-12-05, 21503\n2014-12-06, 21983\n2014-12-07, 24899\n2014-12-08, 27224\n2014-12-09, 25421\n2014-12-10, 32162\n2014-12-11, 25383\n2014-12-12, 26584\n2014-12-13, 23579\n2014-12-14, 26094\n2014-12-15, 27622\n2014-12-16, 28350\n2014-12-17, 26969\n2014-12-18, 23574\n2014-12-19, 23524\n2014-12-20, 21411\n2014-12-21, 23172\n2014-12-22, 25504\n2014-12-23, 24192\n2014-12-24, 21216\n2014-12-25, 21728\n2014-12-26, 21543\n2014-12-27, 18427\n2014-12-28, 19605\n2014-12-29, 19477\n2014-12-30, 20017\n2014-12-31, 18681\n2015-01-01, 9385\n2015-01-02, null\n2015-01-03, 7300\n2015-01-04, 23092\n2015-01-05, 25041\n2015-01-06, 26987\n2015-01-07, 22546\n2015-01-08, 30439\n2015-01-09, 22162\n2015-01-10, 20760\n2015-01-11, 24861\n2015-01-12, 30086\n2015-01-13, 35414\n2015-01-14, 26417\n2015-01-15, 26448\n2015-01-16, 19187\n2015-01-17, 24812\n2015-01-18, 27548\n2015-01-19, 26982\n2015-01-20, 24660\n2015-01-21, 25882\n2015-01-22, 24058\n2015-01-23, 32718\n2015-01-24, 21312\n2015-01-25, 33929\n2015-01-26, 26135\n2015-01-27, 27422\n2015-01-28, 25184\n2015-01-29, 22919\n2015-01-30, 18146\n2015-01-31, 19445\n2015-02-01, 24761\n2015-02-02, 33419\n2015-02-03, 22995\n2015-02-04, 28935\n2015-02-05, 23289\n2015-02-06, 19540\n2015-02-07, 20792\n2015-02-08, 24642\n2015-02-09, 24331\n2015-02-10, 39339\n2015-02-11, 25742\n2015-02-12, 27697\n2015-02-13, 19041\n2015-02-14, 21846\n2015-02-15, 24782\n2015-02-16, 24354\n2015-02-17, 22628\n2015-02-18, 24979\n2015-02-19, 29514\n2015-02-20, 20543\n2015-02-21, 20579\n2015-02-22, 23428\n2015-02-23, 24385\n2015-02-24, 24137\n2015-02-25, 26283\n2015-02-26, 30545\n2015-02-27, 20811\n2015-02-28, 18895\n2015-03-01, 23297\n2015-03-02, 25764\n2015-03-03, 25007\n2015-03-04, 24174\n2015-03-05, 22774\n2015-03-06, 19322\n2015-03-07, 19396\n2015-03-08, 23937\n2015-03-09, 28378\n2015-03-10, 25733\n2015-03-11, 24527\n2015-03-12, 25574\n2015-03-13, 21952\n2015-03-14, 24161\n2015-03-15, 24071\n2015-03-16, 36584\n2015-03-17, 24807\n2015-03-18, 31393\n2015-03-19, 26773\n2015-03-20, 23297\n2015-03-21, 27846\n2015-03-22, 34762\n2015-03-23, 31576\n2015-03-24, 35297\n2015-03-25, 37079\n2015-03-26, 36691\n2015-03-27, 31697\n2015-03-28, 31897\n2015-03-29, 38669\n2015-03-30, 35388\n2015-03-31, 34237\n2015-04-01, 29264\n2015-04-02, 30317\n2015-04-03, 27885\n2015-04-04, 29227\n2015-04-05, 29046\n2015-04-06, 29994\n2015-04-07, 37076\n2015-04-08, 37353\n2015-04-09, 28657\n2015-04-10, 27225\n2015-04-11, 25877\n2015-04-12, 29205\n2015-04-13, 30124\n2015-04-14, 28598\n2015-04-15, 34517\n2015-04-16, 28275\n2015-04-17, 25659\n2015-04-18, 26993\n2015-04-19, 28470\n2015-04-20, 32701\n2015-04-21, 30895\n2015-04-22, 30202\n2015-04-23, 35266\n2015-04-24, 25715\n2015-04-25, 36471\n2015-04-26, 39066\n2015-04-27, 31957\n2015-04-28, 30639\n2015-04-29, 29720\n2015-04-30, 27237\n2015-05-01, 25012\n2015-05-02, 27042\n2015-05-03, 29448\n2015-05-04, 27820\n2015-05-05, 29624\n2015-05-06, 27526\n2015-05-07, 25655\n2015-05-08, 23791\n2015-05-09, 31503\n2015-05-10, 32317\n2015-05-11, 30635\n2015-05-12, 30934\n2015-05-13, 31708\n2015-05-14, 42997\n2015-05-15, 32407\n2015-05-16, 32810\n2015-05-17, 34624\n2015-05-18, 34750\n2015-05-19, 30108\n2015-05-20, 27578\n2015-05-21, 29926\n2015-05-22, 27166\n2015-05-23, 27968\n2015-05-24, 30637\n2015-05-25, 34578\n2015-05-26, 29218\n2015-05-27, 23591\n2015-05-28, 24045\n2015-05-29, 23844\n2015-05-30, 24048\n2015-05-31, 27087\n2015-06-01, 28566\n2015-06-02, 34732\n2015-06-03, 76661\n2015-06-04, 28700\n2015-06-05, 27936\n2015-06-06, 26086\n2015-06-07, 46002\n2015-06-08, 43106\n2015-06-09, 26645\n2015-06-10, 52355\n2015-06-11, 36988\n2015-06-12, 21875\n2015-06-13, 46935\n2015-06-14, 28128\n2015-06-15, 84152\n2015-06-16, 35914\n2015-06-17, 38557\n2015-06-18, 28107\n2015-06-19, 25438\n2015-06-20, 23500\n2015-06-21, 27394\n2015-06-22, 28352\n2015-06-23, 36725\n2015-06-24, 26008\n2015-06-25, 23984\n2015-06-26, 23636\n2015-06-27, 25663\n2015-06-28, 40197\n2015-06-29, 33375\n2015-06-30, 29052\n2015-07-01, 27119\n2015-07-02, 25771\n2015-07-03, 23847\n2015-07-04, 24976\n2015-07-05, 36903\n2015-07-06, 29915\n2015-07-07, 36474\n2015-07-08, 30281\n2015-07-09, 29616\n2015-07-10, 24645\n2015-07-11, 26775\n2015-07-12, 42326\n2015-07-13, 50267\n2015-07-14, 38595\n2015-07-15, 35125\n2015-07-16, 29831\n2015-07-17, 25985\n2015-07-18, 25071\n2015-07-19, 36888\n2015-07-20, 30095\n2015-07-21, 44651\n2015-07-22, 33408\n2015-07-23, 28664\n2015-07-24, 21076\n2015-07-25, 15592\n2015-07-26, 30972\n2015-07-27, 33519\n2015-07-28, 37726\n2015-07-29, 33018\n2015-07-30, 27789\n2015-07-31, 26960\n2015-08-01, 24294\n2015-08-02, 35036\n2015-08-03, 34486\n2015-08-04, 31470\n2015-08-05, 35658\n2015-08-06, 47467\n2015-08-07, 29031\n2015-08-08, 27132\n2015-08-09, 27744\n2015-08-10, 26653\n2015-08-11, 29241\n2015-08-12, 31087\n2015-08-13, 30737\n2015-08-14, 28722\n2015-08-15, 24050\n2015-08-16, 37040\n2015-08-17, 28767\n2015-08-18, 28539\n2015-08-19, 36462\n2015-08-20, 39012\n2015-08-21, 34967\n2015-08-22, 27692\n2015-08-23, 34342\n2015-08-24, 37941\n2015-08-25, 33987\n2015-08-26, 34558\n2015-08-27, 39945\n2015-08-28, 14768\n2015-08-29, 32134\n2015-08-30, 35949\n2015-08-31, 37021\n2015-09-01, 39013\n2015-09-02, 42474\n2015-09-03, 36321\n2015-09-04, 29023\n2015-09-05, 35583\n2015-09-06, 38792\n2015-09-07, 46889\n2015-09-08, 16909\n2015-09-09, 37882\n2015-09-10, 38518\n2015-09-11, 32205\n2015-09-12, 40350\n2015-09-13, 16262\n2015-09-14, 20470\n2015-09-15, 45085\n2015-09-16, 33180\n2015-09-17, 31747\n2015-09-18, 39778\n2015-09-19, 65535\n2015-09-20, 59563\n2015-09-21, 82378\n2015-09-22, 42946\n2015-09-23, 46527\n2015-09-24, 41322\n2015-09-25, 41039\n2015-09-26, 30532\n2015-09-27, 35355\n2015-09-28, 40135\n2015-09-29, 43080\n2015-09-30, 41189\n2015-10-01, 35561\n2015-10-02, 49494\n2015-10-03, 33909\n2015-10-04, 32712\n2015-10-05, 39541\n2015-10-06, 38773\n2015-10-07, 35461\n2015-10-08, 30426\n2015-10-09, 29433\n2015-10-10, 27940\n2015-10-11, 34146\n2015-10-12, 31813\n2015-10-13, 28030\n2015-10-14, 37296\n2015-10-15, 36070\n2015-10-16, 31701\n2015-10-17, 25220\n2015-10-18, 35703\n2015-10-19, 42914\n2015-10-20, 38896\n2015-10-21, 44027\n2015-10-22, 37326\n2015-10-23, 36013\n2015-10-24, 30139\n2015-10-25, 37096\n2015-10-26, 50484\n2015-10-27, 45782\n2015-10-28, 45960\n2015-10-29, 32577\n2015-10-30, 35257\n2015-10-31, 31402\n2015-11-01, 35962\n2015-11-02, 42652\n2015-11-03, 54768\n2015-11-04, 51405\n2015-11-05, 43351\n2015-11-06, 36433\n2015-11-07, 39567\n2015-11-08, 45103\n2015-11-09, 43853\n2015-11-10, 34774\n2015-11-11, 38371\n2015-11-12, 35364\n2015-11-13, 30226\n2015-11-14, 32216\n2015-11-15, 35757\n2015-11-16, 36957\n2015-11-17, 40387\n2015-11-18, 32915\n2015-11-19, 33652\n2015-11-20, 25295\n2015-11-21, 17983\n2015-11-22, 21268\n2015-11-23, 20427\n2015-11-24, 27288\n2015-11-25, 24681\n2015-11-26, 25861\n2015-11-27, 25749\n2015-11-28, 24219\n2015-11-29, 26261\n2015-11-30, 25143\n2015-12-01, 23887\n2015-12-02, 23460\n2015-12-03, 22066\n2015-12-04, 22531\n2015-12-05, 22728\n2015-12-06, 25413\n2015-12-07, 24716\n2015-12-08, 33862\n2015-12-09, 25232\n2015-12-10, 26210\n2015-12-11, 23062\n2015-12-12, 21459\n2015-12-13, 32070\n2015-12-14, 28842\n2015-12-15, 27652\n2015-12-16, 23729\n2015-12-17, 24189\n2015-12-18, 21372\n2015-12-19, 19855\n2015-12-20, 24803\n2015-12-21, 25707\n2015-12-22, 26011\n2015-12-23, 23679\n2015-12-24, 21240\n2015-12-25, 21795\n2015-12-26, 32284\n2015-12-27, 31890\n2015-12-28, 24417\n2015-12-29, 26654\n2015-12-30, 24012\n2015-12-31, 20122\n2016-01-01, 19715\n2016-01-02, 19638\n2016-01-03, 23308\n2016-01-04, 27207\n2016-01-05, 24615\n2016-01-06, 24700\n2016-01-07, 26040\n2016-01-08, 20585\n2016-01-09, 20755\n2016-01-10, 23867\n2016-01-11, 27110\n2016-01-12, 27094\n2016-01-13, 25568\n2016-01-14, 31035\n2016-01-15, 28097\n2016-01-16, 25408\n2016-01-17, 29308\n2016-01-18, 24617\n2016-01-19, 29720\n2016-01-20, 29595\n2016-01-21, 27533\n2016-01-22, 23029\n2016-01-23, 22635\n2016-01-24, 25172\n2016-01-25, 26057\n2016-01-26, 28379\n2016-01-27, 26070\n2016-01-28, 29331\n2016-01-29, 25049\n2016-01-30, 27728\n2016-01-31, 29309\n2016-02-01, 26458\n2016-02-02, 27023\n2016-02-03, 26103\n2016-02-04, 26621\n2016-02-05, 23929\n2016-02-06, 24021\n2016-02-07, 27363\n2016-02-08, 25751\n2016-02-09, 28230\n2016-02-10, 29630\n2016-02-11, 28064\n2016-02-12, 25543\n2016-02-13, 25283\n2016-02-14, 27181\n2016-02-15, 27923\n2016-02-16, 29153\n2016-02-17, 24986\n2016-02-18, 27889\n2016-02-19, 23050\n2016-02-20, 25424\n2016-02-21, 25239\n2016-02-22, 28499\n2016-02-23, 27169\n2016-02-24, 28753\n2016-02-25, 30726\n2016-02-26, 24902\n2016-02-27, 28161\n2016-02-28, 28270\n2016-02-29, 25668\n2016-03-01, 27957\n2016-03-02, 31442\n2016-03-03, 30294\n2016-03-04, 28045\n2016-03-05, 24747\n2016-03-06, 29486\n2016-03-07, 27850\n2016-03-08, 28142\n2016-03-09, 30719\n2016-03-10, 29704\n2016-03-11, 28068\n2016-03-12, 28299\n2016-03-13, 28751\n2016-03-14, 30661\n2016-03-15, 33113\n2016-03-16, 30033\n2016-03-17, 25976\n2016-03-18, 27011\n2016-03-19, 22064\n2016-03-20, 25353\n2016-03-21, 25184\n2016-03-22, 23845\n2016-03-23, 22710\n2016-03-24, 22593\n2016-03-25, 20187\n2016-03-26, 19044\n2016-03-27, 23045\n2016-03-28, 31699\n2016-03-29, 35672\n2016-03-30, 24191\n2016-03-31, 24472\n2016-04-01, 21507\n2016-04-02, 21378\n2016-04-03, 24516\n2016-04-04, 26914\n2016-04-05, 23270\n2016-04-06, 23407\n2016-04-07, 24554\n2016-04-08, 19399\n2016-04-09, 19193\n2016-04-10, 23919\n2016-04-11, 23252\n2016-04-12, 23243\n2016-04-13, 24938\n2016-04-14, 27593\n2016-04-15, 20857\n2016-04-16, 19395\n2016-04-17, 21989\n2016-04-18, 22642\n2016-04-19, 22973\n2016-04-20, 23282\n2016-04-21, 24241\n2016-04-22, 25236\n2016-04-23, 30727\n2016-04-24, 28861\n2016-04-25, 26206\n2016-04-26, 28009\n2016-04-27, 26142\n2016-04-28, 26067\n2016-04-29, 22785\n2016-04-30, 22113\n2016-05-01, 44092\n2016-05-02, 34902\n2016-05-03, 28567\n2016-05-04, 27508\n2016-05-05, 24738\n2016-05-06, 21334\n2016-05-07, 20478\n2016-05-08, 23092\n2016-05-09, 23402\n2016-05-10, 21597\n2016-05-11, 22343\n2016-05-12, 23638\n2016-05-13, 19355\n2016-05-14, 19527\n2016-05-15, 21419\n2016-05-16, 21242\n2016-05-17, 21130\n2016-05-18, 21055\n2016-05-19, 21015\n2016-05-20, 18208\n2016-05-21, 20846\n2016-05-22, 25025\n2016-05-23, 25558\n2016-05-24, 25514\n2016-05-25, 25096\n2016-05-26, 22418\n2016-05-27, 20785\n2016-05-28, 21179\n2016-05-29, 23116\n2016-05-30, 22168\n2016-05-31, 24322\n2016-06-01, 25664\n2016-06-02, 25989\n2016-06-03, 22507\n2016-06-04, 24256\n2016-06-05, 25168\n2016-06-06, 25479\n2016-06-07, 25213\n2016-06-08, 23455\n2016-06-09, 23436\n2016-06-10, 20546\n2016-06-11, 25917\n2016-06-12, 27242\n2016-06-13, 23970\n2016-06-14, 24561\n2016-06-15, 26795\n2016-06-16, 26724\n2016-06-17, 20862\n2016-06-18, 20799\n2016-06-19, 27198\n2016-06-20, 27064\n2016-06-21, 25119\n2016-06-22, 24183\n2016-06-23, 26403\n2016-06-24, 20205\n2016-06-25, 20500\n2016-06-26, 23913\n2016-06-27, 23816\n2016-06-28, 23872\n2016-06-29, 23132\n2016-06-30, 23027\n2016-07-01, 23595\n2016-07-02, 20287\n2016-07-03, 21181\n2016-07-04, 22046\n2016-07-05, 23770\n2016-07-06, 23909\n2016-07-07, 23469\n2016-07-08, 25041\n2016-07-09, 20364\n2016-07-10, 22699\n2016-07-11, 22223\n2016-07-12, 22998\n2016-07-13, 21544\n2016-07-14, 20434\n2016-07-15, 18987\n2016-07-16, 19456\n2016-07-17, 21330\n2016-07-18, 23226\n2016-07-19, 22621\n2016-07-20, 20837\n2016-07-21, 20712\n2016-07-22, 18351\n2016-07-23, 18766\n2016-07-24, 22664\n2016-07-25, 23499\n2016-07-26, 21902\n2016-07-27, 23727\n2016-07-28, 20354\n2016-07-29, 17310\n2016-07-30, 17590\n2016-07-31, 22021\n2016-08-01, 27947\n2016-08-02, 33437\n2016-08-03, 25150\n2016-08-04, 25115\n2016-08-05, 20484\n2016-08-06, 20769\n2016-08-07, 24232\n2016-08-08, 24435\n2016-08-09, 30224\n2016-08-10, 23497\n2016-08-11, 25008\n2016-08-12, 21026\n2016-08-13, 24566\n2016-08-14, 25180\n2016-08-15, 23549\n2016-08-16, 22643\n2016-08-17, 20849\n2016-08-18, 18562\n2016-08-19, 14687\n2016-08-20, 14412\n2016-08-21, 18821\n2016-08-22, 18812\n2016-08-23, 19302\n2016-08-24, 20127\n2016-08-25, 19606\n2016-08-26, 15956\n2016-08-27, 17112\n2016-08-28, 22110\n2016-08-29, 18322\n2016-08-30, 17456\n2016-08-31, 18373\n2016-09-01, 20605\n2016-09-02, 16664\n2016-09-03, 16972\n2016-09-04, 23183\n2016-09-05, 35065\n2016-09-06, 23060\n2016-09-07, 19731\n2016-09-08, 19091\n2016-09-09, 18701\n2016-09-10, 16124\n2016-09-11, 18821\n2016-09-12, 20868\n2016-09-13, 20554\n2016-09-14, 21820\n2016-09-15, 20588\n2016-09-16, 17201\n2016-09-17, 13717\n2016-09-18, 13913\n2016-09-19, 26427\n2016-09-20, 18606\n2016-09-21, 18260\n2016-09-22, 19726\n2016-09-23, 17748\n2016-09-24, 17984\n2016-09-25, 20210\n2016-09-26, 20912\n2016-09-27, 19750\n2016-09-28, 21230\n2016-09-29, 17676\n2016-09-30, 17285\n2016-10-01, 16869\n2016-10-02, 22770\n2016-10-03, 20191\n2016-10-04, 19102\n2016-10-05, 19174\n2016-10-06, 21247\n2016-10-07, 18265\n2016-10-08, 17597\n2016-10-09, 19079\n2016-10-10, 20605\n2016-10-11, 19254\n2016-10-12, 17289\n2016-10-13, 17479\n2016-10-14, 20593\n2016-10-15, 18498\n2016-10-16, 18689\n2016-10-17, 17940\n2016-10-18, 20522\n2016-10-19, 17281\n2016-10-20, 15145\n2016-10-21, 13770\n2016-10-22, 14832\n2016-10-23, 18801\n2016-10-24, 15756\n2016-10-25, 17995\n2016-10-26, 19247\n2016-10-27, 19798\n2016-10-28, 18463\n2016-10-29, 19812\n2016-10-30, 23052\n2016-10-31, 21499\n2016-11-01, 20959\n2016-11-02, 20253\n2016-11-03, 18517\n2016-11-04, 17653\n2016-11-05, 20121\n2016-11-06, 22734\n2016-11-07, 22954\n2016-11-08, 24370\n2016-11-09, 20972\n2016-11-10, 19923\n2016-11-11, 17540\n2016-11-12, 19573\n2016-11-13, 22700\n2016-11-14, 23129\n2016-11-15, 23016\n2016-11-16, 22943\n2016-11-17, 22105\n2016-11-18, 20995\n2016-11-19, 17894\n2016-11-20, 22770\n2016-11-21, 22500\n2016-11-22, 21827\n2016-11-23, 21061\n2016-11-24, 20433\n2016-11-25, 19734\n2016-11-26, 19864\n2016-11-27, 22289\n2016-11-28, 21602\n2016-11-29, 21457\n2016-11-30, 21117\n2016-12-01, 20335\n2016-12-02, 16186\n2016-12-03, 16345\n2016-12-04, 18558\n2016-12-05, 20236\n2016-12-06, 21592\n2016-12-07, 21302\n2016-12-08, 19749\n2016-12-09, 18331\n2016-12-10, 16070\n2016-12-11, 18775\n2016-12-12, 20749\n2016-12-13, 21101\n2016-12-14, 19341\n2016-12-15, 19242\n2016-12-16, 18364\n2016-12-17, 18930\n2016-12-18, 25718\n2016-12-19, 22945\n2016-12-20, 25531\n2016-12-21, 27288\n2016-12-22, 29448\n2016-12-23, 22045\n2016-12-24, 17925\n2016-12-25, 19894\n2016-12-26, 22525\n2016-12-27, 24151\n2016-12-28, 22502\n2016-12-29, 18971\n2016-12-30, 18483\n2016-12-31, 21071\n2017-01-01, 26461\n2017-01-02, 27269\n2017-01-03, 31611\n2017-01-04, 33407\n2017-01-05, 29065\n2017-01-06, 22717\n2017-01-07, 19595\n2017-01-08, 23277\n2017-01-09, 22918\n2017-01-10, 29228\n2017-01-11, 30387\n2017-01-12, 28785\n2017-01-13, 22367\n2017-01-14, 22232\n2017-01-15, 24103\n2017-01-16, 25648\n2017-01-17, 26491\n2017-01-18, 27848\n2017-01-19, 23365\n2017-01-20, 20833\n2017-01-21, 20816\n2017-01-22, 24809\n2017-01-23, 28304\n2017-01-24, 27278\n2017-01-25, 24366\n2017-01-26, 23178\n2017-01-27, 21300\n2017-01-28, 20789\n2017-01-29, 27170\n2017-01-30, 23711\n2017-01-31, 22600\n2017-02-01, 23547\n2017-02-02, 26694\n2017-02-03, 27112\n2017-02-04, 23530\n2017-02-05, 29026\n2017-02-06, 30138\n2017-02-07, 26445\n2017-02-08, 27886\n2017-02-09, 26096\n2017-02-10, 26759\n2017-02-11, 27211\n2017-02-12, 24621\n2017-02-13, 27568\n2017-02-14, 26945\n2017-02-15, 24357\n2017-02-16, 26355\n2017-02-17, 21344\n2017-02-18, 19946\n2017-02-19, 26113\n2017-02-20, 25187\n2017-02-21, 26751\n2017-02-22, 27929\n2017-02-23, 37286\n2017-02-24, 24005\n2017-02-25, 27326\n2017-02-26, 24703\n2017-02-27, 23501\n2017-02-28, 25248\n2017-03-01, 28277\n2017-03-02, 31848\n2017-03-03, 24535\n2017-03-04, 22507\n2017-03-05, 29476\n2017-03-06, 31214\n2017-03-07, 28463\n2017-03-08, 29362\n2017-03-09, 36952\n2017-03-10, 30193\n2017-03-11, 26226\n2017-03-12, 27414\n2017-03-13, 27110\n2017-03-14, 25560\n2017-03-15, 26412\n2017-03-16, 28612\n2017-03-17, 25964\n2017-03-18, 26859\n2017-03-19, 30480\n2017-03-20, 29659\n2017-03-21, 32507\n2017-03-22, 39969\n2017-03-23, 30279\n2017-03-24, 29728\n2017-03-25, 23985\n2017-03-26, 25216\n2017-03-27, 26462\n2017-03-28, 24593\n2017-03-29, 25723\n2017-03-30, 24542\n2017-03-31, 21680\n2017-04-01, 21011\n2017-04-02, 25315\n2017-04-03, 26979\n2017-04-04, 28967\n2017-04-05, 28251\n2017-04-06, 29445\n2017-04-07, 23272\n2017-04-08, 22661\n2017-04-09, 26562\n2017-04-10, 28441\n2017-04-11, 29250\n2017-04-12, 27278\n2017-04-13, 25953\n2017-04-14, 22135\n2017-04-15, 23562\n2017-04-16, 28015\n2017-04-17, 28770\n2017-04-18, 26629\n2017-04-19, 29974\n2017-04-20, 28206\n2017-04-21, 27203\n2017-04-22, 25203\n2017-04-23, 29644\n2017-04-24, 33008\n2017-04-25, 29463\n2017-04-26, 32051\n2017-04-27, 28213\n2017-04-28, 25838\n2017-04-29, 27459\n2017-04-30, 34936\n2017-05-01, 35501\n2017-05-02, 31179\n2017-05-03, 34255\n2017-05-04, 29857\n2017-05-05, 25032\n2017-05-06, 26713\n2017-05-07, 29244\n2017-05-08, 44121\n2017-05-09, 40934\n2017-05-10, 35505\n2017-05-11, 35985\n2017-05-12, 33174\n2017-05-13, 40474\n2017-05-14, 32997\n2017-05-15, 35688\n2017-05-16, 33543\n2017-05-17, 33534\n2017-05-18, 34239\n2017-05-19, 32852\n2017-05-20, 34900\n2017-05-21, 44720\n2017-05-22, 48940\n2017-05-23, 47492\n2017-05-24, 51057\n2017-05-25, 49914\n2017-05-26, 39077\n2017-05-27, 33992\n2017-05-28, 41046\n2017-05-29, 41624\n2017-05-30, 47749\n2017-05-31, 39409\n2017-06-01, 35997\n2017-06-02, 30857\n2017-06-03, 38571\n2017-06-04, 38632\n2017-06-05, 51736\n2017-06-06, 43821\n2017-06-07, 37910\n2017-06-08, 38824\n2017-06-09, 34849\n2017-06-10, 36404\n2017-06-11, 42206\n2017-06-12, 43501\n2017-06-13, 41045\n2017-06-14, 45335\n2017-06-15, 41470\n2017-06-16, 35393\n2017-06-17, 33617\n2017-06-18, 38427\n2017-06-19, 41414\n2017-06-20, 40215\n2017-06-21, 37617\n2017-06-22, 42760\n2017-06-23, null\n2017-06-24, null\n2017-06-25, null\n2017-06-26, null\n2017-06-27, null\n2017-06-28, null\n2017-06-29, null\n2017-06-30, null\n2017-07-01, null\n2017-07-02, null\n2017-07-03, null\n2017-07-04, null\n2017-07-05, null\n2017-07-06, null\n2017-07-07, null\n2017-07-08, null\n2017-07-09, null\n2017-07-10, null\n2017-07-11, 41059\n2017-07-12, 37788\n2017-07-13, 36999\n2017-07-14, 35882\n2017-07-15, 35044\n2017-07-16, 42841\n2017-07-17, 38869\n2017-07-18, 40774\n2017-07-19, 42878\n2017-07-20, 41888\n2017-07-21, 36424\n2017-07-22, 36108\n2017-07-23, 44080\n2017-07-24, 44885\n2017-07-25, 47880\n2017-07-26, 49367\n2017-07-27, 46138\n2017-07-28, 35823\n2017-07-29, 37073\n2017-07-30, 45510\n2017-07-31, 52376\n2017-08-01, 50050\n2017-08-02, 47758\n2017-08-03, 47503\n2017-08-04, 48992\n2017-08-05, 36187\n2017-08-06, 46630\n2017-08-07, 53994\n2017-08-08, 48611\n2017-08-09, 45181\n2017-08-10, 49242\n2017-08-11, 44387\n2017-08-12, 47827\n2017-08-13, 57531\n2017-08-14, 65447\n2017-08-15, 53779\n2017-08-16, 71870\n2017-08-17, 61067\n2017-08-18, 51709\n2017-08-19, 58268\n2017-08-20, 53402\n2017-08-21, 59244\n2017-08-22, 59293\n2017-08-23, 63067\n2017-08-24, 58723\n2017-08-25, 50258\n2017-08-26, 47358\n2017-08-27, 53173\n2017-08-28, 60452\n2017-08-29, 57072\n2017-08-30, 58244\n2017-08-31, 67953\n2017-09-01, 53177\n2017-09-02, 49077\n2017-09-03, 77422\n2017-09-04, 61290\n2017-09-05, 57051\n2017-09-06, 51603\n2017-09-07, 57797\n2017-09-08, 54796\n2017-09-09, 52629\n2017-09-10, 61659\n2017-09-11, 64321\n2017-09-12, 73211\n2017-09-13, 81128\n2017-09-14, 78373\n2017-09-15, 64396\n2017-09-16, 52831\n2017-09-17, 73426\n2017-09-18, 71751\n2017-09-19, 59979\n2017-09-20, 61443\n2017-09-21, 63652\n2017-09-22, 56876\n2017-09-23, 55081\n2017-09-24, 72699\n2017-09-25, 61973\n2017-09-26, 65959\n2017-09-27, 70657\n2017-09-28, 76874\n2017-09-29, 56280\n2017-09-30, 58917\n2017-10-01, 66945\n2017-10-02, 70772\n2017-10-03, 76296\n2017-10-04, 61290\n2017-10-05, 68406\n2017-10-06, 76111\n2017-10-07, 63113\n2017-10-08, 73002\n2017-10-09, 79373\n2017-10-10, 68320\n2017-10-11, 106779\n2017-10-12, 99372\n2017-10-13, 83670\n2017-10-14, 93320\n2017-10-15, 77238\n2017-10-16, 80151\n2017-10-17, 71392\n2017-10-18, 85571\n2017-10-19, 94627\n2017-10-20, 66998\n2017-10-21, 74513\n2017-10-22, 86442\n2017-10-23, 74472\n2017-10-24, 72426\n2017-10-25, 67679\n2017-10-26, 69197\n2017-10-27, 59449\n2017-10-28, 64396\n2017-10-29, 73018\n2017-10-30, 86043\n2017-10-31, 89885\n2017-11-01, 92923\n2017-11-02, 77953\n2017-11-03, 73373\n2017-11-04, 67196\n2017-11-05, 72577\n2017-11-06, 64461\n2017-11-07, 81551\n2017-11-08, 81241\n2017-11-09, 80481\n2017-11-10, 68892\n2017-11-11, 71176\n2017-11-12, 73373\n2017-11-13, 71630\n2017-11-14, 79934\n2017-11-15, 87538\n2017-11-16, 83410\n2017-11-17, 68192\n2017-11-18, 72762\n2017-11-19, 102144\n2017-11-20, 87110\n2017-11-21, 78405\n2017-11-22, 75047\n2017-11-23, 69886\n2017-11-24, 71625\n2017-11-25, 80943\n2017-11-26, 98413\n2017-11-27, 106360\n2017-11-28, 128781\n2017-11-29, 103190\n2017-11-30, 105017\n2017-12-01, 88292\n2017-12-02, 83022\n2017-12-03, 97945\n2017-12-04, 103919\n2017-12-05, 116856\n2017-12-06, 155600\n2017-12-07, 124260\n2017-12-08, 114109\n2017-12-09, 100455\n2017-12-10, 128425\n2017-12-11, 113215\n2017-12-12, 98863\n2017-12-13, 109628\n2017-12-14, 105711\n2017-12-15, 82782\n2017-12-16, 84441\n2017-12-17, 97245\n2017-12-18, 83423\n2017-12-19, 101169\n2017-12-20, 105591\n2017-12-21, 124670\n2017-12-22, 100098\n2017-12-23, 70864\n2017-12-24, 64029\n2017-12-25, 77648\n2017-12-26, 78968\n2017-12-27, 79968\n2017-12-28, 77151\n2017-12-29, 71377\n2017-12-30, 64989\n2017-12-31, 62044\n2018-01-01, 77723\n2018-01-02, 79086\n2018-01-03, 74534\n2018-01-04, 76404\n2018-01-05, 62977\n2018-01-06, 67259\n2018-01-07, 30585\n2018-01-08, 80932\n2018-01-09, 82357\n2018-01-10, 100333\n2018-01-11, 80737\n2018-01-12, 63396\n2018-01-13, 65657\n2018-01-14, 76852\n2018-01-15, 102135\n2018-01-16, 111394\n2018-01-17, 100366\n2018-01-18, 57244\n2018-01-19, 75149\n2018-01-20, 76295\n2018-01-21, 93708\n2018-01-22, 81995\n2018-01-23, 78855\n2018-01-24, 79509\n2018-01-25, 73227\n2018-01-26, 63956\n2018-01-27, 66645\n2018-01-28, 82322\n2018-01-29, 84246\n2018-01-30, 81651\n2018-01-31, 93008\n2018-02-01, 102640\n2018-02-02, 76444\n2018-02-03, 78202\n2018-02-04, 99959\n2018-02-05, 109734\n2018-02-06, 95072\n2018-02-07, 101569\n2018-02-08, 89542\n2018-02-09, 77570\n2018-02-10, 75335\n2018-02-11, 83783\n2018-02-12, 73084\n2018-02-13, 72888\n2018-02-14, 74208\n2018-02-15, 74964\n2018-02-16, 69716\n2018-02-17, 62968\n2018-02-18, 69225\n2018-02-19, 75215\n2018-02-20, 69562\n2018-02-21, 66124\n2018-02-22, 62576\n2018-02-23, 56616\n2018-02-24, 63393\n2018-02-25, 66533\n2018-02-26, 64827\n2018-02-27, 68823\n2018-02-28, 61852\n2018-03-01, 61317\n2018-03-02, null\n2018-03-03, null\n2018-03-04, null\n2018-03-05, null\n2018-03-06, null\n2018-03-07, null\n2018-03-08, null\n2018-03-09, null\n2018-03-10, null\n2018-03-11, null\n2018-03-12, null\n2018-03-13, null\n2018-03-14, null\n2018-03-15, null\n2018-03-16, null\n2018-03-17, null\n2018-03-18, null\n2018-03-19, null\n2018-03-20, null\n2018-03-21, null\n2018-03-22, null\n2018-03-23, null\n2018-03-24, null\n2018-03-25, null\n2018-03-26, null\n2018-03-27, null\n2018-03-28, null\n2018-03-29, null\n2018-03-30, null\n2018-03-31, null\n2018-04-01, null\n2018-04-02, null\n2018-04-03, null\n2018-04-04, null\n2018-04-05, null\n2018-04-06, 52476\n2018-04-07, 52796\n2018-04-08, 59029\n2018-04-09, 59044\n2018-04-10, 61072\n2018-04-11, 68886\n2018-04-12, 64178\n2018-04-13, 50026\n2018-04-14, 52494\n2018-04-15, 56538\n2018-04-16, 56111\n2018-04-17, 56720\n2018-04-18, 57013\n2018-04-19, 57190\n2018-04-20, 56176\n2018-04-21, 59404\n2018-04-22, 59885\n2018-04-23, 67323\n2018-04-24, 65523\n2018-04-25, 64330\n2018-04-26, 55754\n2018-04-27, 49473\n2018-04-28, 46959\n2018-04-29, 49151\n2018-04-30, 49777\n2018-05-01, 48137\n2018-05-02, 50882\n2018-05-03, 57751\n2018-05-04, 50536\n2018-05-05, 47589\n2018-05-06, 53424\n2018-05-07, 52302\n2018-05-08, 54594\n2018-05-09, 53621\n2018-05-10, 55128\n2018-05-11, 48718\n2018-05-12, 46131\n2018-05-13, 52460\n2018-05-14, 50376\n2018-05-15, 49167\n2018-05-16, 47708\n2018-05-17, 46685\n2018-05-18, 40643\n2018-05-19, 41628\n2018-05-20, 44301\n2018-05-21, 44097\n2018-05-22, 49303\n2018-05-23, 46043\n2018-05-24, 42093\n2018-05-25, 38020\n2018-05-26, 43809\n2018-05-27, 44801\n2018-05-28, 46903\n2018-05-29, 51863\n2018-05-30, 47154\n2018-05-31, 45316\n2018-06-01, 41760\n2018-06-02, 41999\n2018-06-03, 46104\n2018-06-04, 46860\n2018-06-05, 45323\n2018-06-06, 48259\n2018-06-07, 46310\n2018-06-08, 38889\n2018-06-09, 40585\n2018-06-10, 45487\n2018-06-11, 46551\n2018-06-12, 51652\n2018-06-13, 47079\n2018-06-14, 39786\n2018-06-15, 36471\n2018-06-16, 37164\n2018-06-17, 46282\n2018-06-18, 45018\n2018-06-19, 41009\n2018-06-20, 38835\n2018-06-21, 41721\n2018-06-22, 36776\n2018-06-23, 36953\n2018-06-24, 42286\n2018-06-25, 43429\n2018-06-26, 40206\n2018-06-27, 41574\n2018-06-28, 41392\n2018-06-29, 35882\n2018-06-30, 32183\n2018-07-01, 40449\n2018-07-02, 43042\n2018-07-03, 40065\n2018-07-04, 38128\n2018-07-05, 38468\n2018-07-06, 32273\n2018-07-07, 31005\n2018-07-08, 37804\n2018-07-09, 39826\n2018-07-10, 39901\n2018-07-11, 39007\n2018-07-12, 37794\n2018-07-13, 30839\n2018-07-14, 32485\n2018-07-15, 41799\n2018-07-16, 45432\n2018-07-17, 42923\n2018-07-18, 39629\n2018-07-19, 38529\n2018-07-20, 33267\n2018-07-21, 32189\n2018-07-22, 39877\n2018-07-23, 48202\n2018-07-24, 41673\n2018-07-25, 39978\n2018-07-26, 37373\n2018-07-27, 31763\n2018-07-28, 32179\n2018-07-29, 37855\n2018-07-30, 38962\n2018-07-31, 39603\n2018-08-01, 37572\n2018-08-02, 39186\n2018-08-03, 33342\n2018-08-04, 30523\n2018-08-05, 35064\n2018-08-06, 34996\n2018-08-07, 36169\n2018-08-08, 34503\n2018-08-09, 34108\n2018-08-10, 29578\n2018-08-11, 28188\n2018-08-12, 31628\n2018-08-13, 36996\n2018-08-14, 35084\n2018-08-15, 33037\n2018-08-16, 32168\n2018-08-17, 27953\n2018-08-18, 26854\n2018-08-19, 33467\n2018-08-20, 33425\n2018-08-21, 32026\n2018-08-22, 33815\n2018-08-23, 29804\n2018-08-24, 26122\n2018-08-25, 23840\n2018-08-26, 28754\n2018-08-27, 33359\n2018-08-28, 31756\n2018-08-29, 31447\n2018-08-30, 32099\n2018-08-31, 30166\n2018-09-01, 29111\n2018-09-02, 34835\n2018-09-03, 35005\n2018-09-04, 35456\n2018-09-05, 37078\n2018-09-06, 33033\n2018-09-07, 28446\n2018-09-08, 30519\n2018-09-09, 33868\n2018-09-10, 32809\n2018-09-11, 29716\n2018-09-12, 32269\n2018-09-13, 31041\n2018-09-14, 27319\n2018-09-15, 26995\n2018-09-16, 31037\n2018-09-17, 30885\n2018-09-18, 31000\n2018-09-19, 32268\n2018-09-20, 34302\n2018-09-21, 27695\n2018-09-22, 29057\n2018-09-23, 32186\n2018-09-24, 33771\n2018-09-25, 32810\n2018-09-26, 31898\n2018-09-27, 29550\n2018-09-28, 28728\n2018-09-29, 27646\n2018-09-30, 31878\n2018-10-01, 31648\n2018-10-02, 31711\n2018-10-03, 34224\n2018-10-04, 34221\n2018-10-05, 29246\n2018-10-06, 28503\n2018-10-07, 37692\n2018-10-08, 35538\n2018-10-09, 33842\n2018-10-10, 32278\n2018-10-11, 28937\n2018-10-12, 27760\n2018-10-13, 28150\n2018-10-14, 35275\n2018-10-15, 35006\n2018-10-16, 33145\n2018-10-17, 30155\n2018-10-18, 28097\n2018-10-19, 23204\n2018-10-20, 22298\n2018-10-21, 30300\n2018-10-22, 30702\n2018-10-23, 29969\n2018-10-24, 25693\n2018-10-25, 25493\n2018-10-26, 20631\n2018-10-27, 20711\n2018-10-28, 26541\n2018-10-29, 25290\n2018-10-30, 33944\n2018-10-31, 31618\n2018-11-01, 22288\n2018-11-02, 18645\n2018-11-03, 24207\n2018-11-04, 23158\n2018-11-05, 25550\n2018-11-06, 24951\n2018-11-07, 24614\n2018-11-08, 25018\n2018-11-09, 20709\n2018-11-10, 18630\n2018-11-11, 23212\n2018-11-12, 25340\n2018-11-13, 34169\n2018-11-14, 30694\n2018-11-15, 28077\n2018-11-16, 23964\n2018-11-17, 21832\n2018-11-18, 39010\n2018-11-19, 36659\n2018-11-20, 30984\n2018-11-21, 27754\n2018-11-22, 26345\n2018-11-23, 22902\n2018-11-24, 26859\n2018-11-25, 29115\n2018-11-26, 29976\n2018-11-27, 29142\n2018-11-28, 28709\n2018-11-29, 25626\n2018-11-30, 26347\n2018-12-01, 21596\n2018-12-02, 27894\n2018-12-03, 25332\n2018-12-04, 27357\n2018-12-05, null\n2018-12-06, 28638\n2018-12-07, 22270\n2018-12-08, 23363\n2018-12-09, 22818\n2018-12-10, 22603\n2018-12-11, 21876\n2018-12-12, 21792\n2018-12-13, 24445\n2018-12-14, 18577\n2018-12-15, 19526\n2018-12-16, 24940\n2018-12-17, 25600\n2018-12-18, 26446\n2018-12-19, 24630\n2018-12-20, 22143\n2018-12-21, 17737\n2018-12-22, 17701\n2018-12-23, 21198\n2018-12-24, 18394\n2018-12-25, 19107\n2018-12-26, 19522\n2018-12-27, 20589\n2018-12-28, 19252\n2018-12-29, 18295\n2018-12-30, 18611\n2018-12-31, 17069\n2019-01-01, 18830\n2019-01-02, 26754\n2019-01-03, 21139\n2019-01-04, 20096\n2019-01-05, 18883\n2019-01-06, 20476\n2019-01-07, 19387\n2019-01-08, 21237\n2019-01-09, 20948\n2019-01-10, 19317\n2019-01-11, 16138\n2019-01-12, 16041\n2019-01-13, 19018\n2019-01-14, 18363\n2019-01-15, 18790\n2019-01-16, 21544\n2019-01-17, 19125\n2019-01-18, 16923\n2019-01-19, 17285\n2019-01-20, 18571\n2019-01-21, 18601\n2019-01-22, 19434\n2019-01-23, 19994\n2019-01-24, 17787\n2019-01-25, 16307\n2019-01-26, 14794\n2019-01-27, 19069\n2019-01-28, 19242\n2019-01-29, 19785\n2019-01-30, 20616\n2019-01-31, 14658\n2019-02-01, 15728\n2019-02-02, 15208\n2019-02-03, 18658\n2019-02-04, 19792\n2019-02-05, 20673\n2019-02-06, 18834\n2019-02-07, 20304\n2019-02-08, 18400\n2019-02-09, 15294\n2019-02-10, 17137\n2019-02-11, 18536\n2019-02-12, 19037\n2019-02-13, 20146\n2019-02-14, 17973\n2019-02-15, 14503\n2019-02-16, 15013\n2019-02-17, 20088\n2019-02-18, 20657\n2019-02-19, 19783\n2019-02-20, 18673\n2019-02-21, 18990\n2019-02-22, 17467\n2019-02-23, 19043\n2019-02-24, 18557\n2019-02-25, 18337\n2019-02-26, 17989\n2019-02-27, 17668\n2019-02-28, 16498\n2019-03-01, 14475\n2019-03-02, 14176\n2019-03-03, 17545\n2019-03-04, 18838\n2019-03-05, 18028\n2019-03-06, 18488\n2019-03-07, 17183\n2019-03-08, 17366\n2019-03-09, 15841\n2019-03-10, 18186\n2019-03-11, 19917\n2019-03-12, 18492\n2019-03-13, 20023\n2019-03-14, 20206\n2019-03-15, 17435\n2019-03-16, 15347\n2019-03-17, 18737\n2019-03-18, 18727\n2019-03-19, 19248\n2019-03-20, 19423\n2019-03-21, 16970\n2019-03-22, 15265\n2019-03-23, 13501\n2019-03-24, 17740\n2019-03-25, 17060\n2019-03-26, 18796\n2019-03-27, 19331\n2019-03-28, 19794\n2019-03-29, 16862\n2019-03-30, 13999\n2019-03-31, 19381\n2019-04-01, 31271\n2019-04-02, 27604\n2019-04-03, 19138\n2019-04-04, 21242\n2019-04-05, 18512\n2019-04-06, 18379\n2019-04-07, 21850\n2019-04-08, 21506\n2019-04-09, 20630\n2019-04-10, 19646\n2019-04-11, 19211\n2019-04-12, 14753\n2019-04-13, 15018\n2019-04-14, 21915\n2019-04-15, 20162\n2019-04-16, 18090\n2019-04-17, 17682\n2019-04-18, 18120\n2019-04-19, 17709\n2019-04-20, 17222\n2019-04-21, 17408\n2019-04-22, 22296\n2019-04-23, 19743\n2019-04-24, 19506\n2019-04-25, 21070\n2019-04-26, 16710\n2019-04-27, 17580\n2019-04-28, 20448\n2019-04-29, 21581\n2019-04-30, 20851\n2019-05-01, 22445\n2019-05-02, 24485\n2019-05-03, 17068\n2019-05-04, 16535\n2019-05-05, 17404\n2019-05-06, 23358\n2019-05-07, 21963\n2019-05-08, 23754\n2019-05-09, 26998\n2019-05-10, 28634\n2019-05-11, 24282\n2019-05-12, 30708\n2019-05-13, 30481\n2019-05-14, 26417\n2019-05-15, 25357\n2019-05-16, 24758\n2019-05-17, 21030\n2019-05-18, 23521\n2019-05-19, 26986\n2019-05-20, 26690\n2019-05-21, 28228\n2019-05-22, 23030\n2019-05-23, 24832\n2019-05-24, 21858\n2019-05-25, 24478\n2019-05-26, 28581\n2019-05-27, 26446\n2019-05-28, 25021\n2019-05-29, 27798\n2019-05-30, 23693\n2019-05-31, 18033\n2019-06-01, 17800\n2019-06-02, 21639\n2019-06-03, 22663\n2019-06-04, 20976\n2019-06-05, 18986\n2019-06-06, 18556\n2019-06-07, 16193\n2019-06-08, 14067\n2019-06-09, 16525\n2019-06-10, 16251\n2019-06-11, 16268\n2019-06-12, 17035\n2019-06-13, 18696\n2019-06-14, 16573\n2019-06-15, 22492\n2019-06-16, 20646\n2019-06-17, 21527\n2019-06-18, 18490\n2019-06-19, 22820\n2019-06-20, 27828\n2019-06-21, 39374\n2019-06-22, 24127\n2019-06-23, 25892\n2019-06-24, 27019\n2019-06-25, 41687\n2019-06-26, 30175\n2019-06-27, 27588\n2019-06-28, 21149\n2019-06-29, 17663\n2019-06-30, 23124\n2019-07-01, 23546\n2019-07-02, 22563\n2019-07-03, 19546\n2019-07-04, 19656\n2019-07-05, 16184\n2019-07-06, 15820\n2019-07-07, 21434\n2019-07-08, 22180\n2019-07-09, 23834\n2019-07-10, 20230\n2019-07-11, 31450\n2019-07-12, 21442\n2019-07-13, 19451\n2019-07-14, 22735\n2019-07-15, 22784\n2019-07-16, 24278\n2019-07-17, 24597\n2019-07-18, 25759\n2019-07-19, 21566\n2019-07-20, 20697\n2019-07-21, 23274\n2019-07-22, 21610\n2019-07-23, 22926\n2019-07-24, 19361\n2019-07-25, 17954\n2019-07-26, 16400\n2019-07-27, 14762\n2019-07-28, 17179\n2019-07-29, 18294\n2019-07-30, 19647\n2019-07-31, 19930\n2019-08-01, 19806\n2019-08-02, 15856\n2019-08-03, 15514\n2019-08-04, 24014\n2019-08-05, 21526\n2019-08-06, 19684\n2019-08-07, 17352\n2019-08-08, 17787\n2019-08-09, 15781\n2019-08-10, 14407\n2019-08-11, 18156\n2019-08-12, 18208\n2019-08-13, 19072\n2019-08-14, 19697\n2019-08-15, 19352\n2019-08-16, 15703\n2019-08-17, 14246\n2019-08-18, 16770\n2019-08-19, 16596\n2019-08-20, 18179\n2019-08-21, 17858\n2019-08-22, 17668\n2019-08-23, 14618\n2019-08-24, 14278\n2019-08-25, 16826\n2019-08-26, 20448\n2019-08-27, 19033\n2019-08-28, 17137\n2019-08-29, 16339\n2019-08-30, 13453\n2019-08-31, 14620\n2019-09-01, 17337\n2019-09-02, 20903\n2019-09-03, 18177\n2019-09-04, 16187\n2019-09-05, 18376\n2019-09-06, 14526\n2019-09-07, 14593\n2019-09-08, 17004\n2019-09-09, 18300\n2019-09-10, 17080\n2019-09-11, 16904\n2019-09-12, 15885\n2019-09-13, 13360\n2019-09-14, 13380\n2019-09-15, 16491\n2019-09-16, 17082\n2019-09-17, 18477\n2019-09-18, 18387\n2019-09-19, 16907\n2019-09-20, 13899\n2019-09-21, 14650\n2019-09-22, 18065\n2019-09-23, 21250\n2019-09-24, 21772\n2019-09-25, 19619\n2019-09-26, 19119\n2019-09-27, 15414\n2019-09-28, 14229\n2019-09-29, 17758\n2019-09-30, 17754\n2019-10-01, 15544\n2019-10-02, 15626\n2019-10-03, 14904\n2019-10-04, 13536\n2019-10-05, 14729\n2019-10-06, 16843\n2019-10-07, 16662\n2019-10-08, 17990\n2019-10-09, 17144\n2019-10-10, 16759\n2019-10-11, 14136\n2019-10-12, 14172\n2019-10-13, 17307\n2019-10-14, 17552\n2019-10-15, 17713\n2019-10-16, 16806\n2019-10-17, 17011\n2019-10-18, 15757\n2019-10-19, 13294\n2019-10-20, 16282\n2019-10-21, 19420\n2019-10-22, 20329\n2019-10-23, 17486\n2019-10-24, 20601\n2019-10-25, 25470\n2019-10-26, 17460\n2019-10-27, 18462\n2019-10-28, 17199\n2019-10-29, 17972\n2019-10-30, 20869\n2019-10-31, 17370\n2019-11-01, 14470\n2019-11-02, 14022\n2019-11-03, 17953\n2019-11-04, 18119\n2019-11-05, 17193\n2019-11-06, 16147\n2019-11-07, 16463\n2019-11-08, 13608\n2019-11-09, 13655\n2019-11-10, 17451\n2019-11-11, 16739\n2019-11-12, 17058\n2019-11-13, 18144\n2019-11-14, 17028\n2019-11-15, 15041\n2019-11-16, 14539\n2019-11-17, 16505\n2019-11-18, 16874\n2019-11-19, 18338\n2019-11-20, 21597\n2019-11-21, 24404\n2019-11-22, 16543\n2019-11-23, 17253\n2019-11-24, 22633\n2019-11-25, 25824\n2019-11-26, 22517\n2019-11-27, 16332\n2019-11-28, 16670\n2019-11-29, 16174\n2019-11-30, 15964\n2019-12-01, 16129\n2019-12-02, 16469\n2019-12-03, 16817\n2019-12-04, 17127\n2019-12-05, 15697\n2019-12-06, 13437\n2019-12-07, 14176\n2019-12-08, 16592\n2019-12-09, 15197\n2019-12-10, 14324\n2019-12-11, 16412\n2019-12-12, 16588\n2019-12-13, 14114\n2019-12-14, 14381\n2019-12-15, 18724\n2019-12-16, 19303\n2019-12-17, 22374\n2019-12-18, 21588\n2019-12-19, 18959\n2019-12-20, 16562\n2019-12-21, 15978\n2019-12-22, 16906\n2019-12-23, 15959\n2019-12-24, 14984\n2019-12-25, 15205\n2019-12-26, 14711\n2019-12-27, 14765\n2019-12-28, 13684\n2019-12-29, 15568\n2019-12-30, 13500\n2019-12-31, 13987\n2020-01-01, 15920\n2020-01-02, 19730\n2020-01-03, 16357\n2020-01-04, 16533\n2020-01-05, 16540\n2020-01-06, 20950\n2020-01-07, 20820\n2020-01-08, 20500\n2020-01-09, 18266\n2020-01-10, 15900\n2020-01-11, 14383\n2020-01-12, 15305\n2020-01-13, 20772\n2020-01-14, 18142\n2020-01-15, 18513\n2020-01-16, 17272\n2020-01-17, 17651\n2020-01-18, 20557\n2020-01-19, 18586\n2020-01-20, 19285\n2020-01-21, 19401\n2020-01-22, 18546\n2020-01-23, 16643\n2020-01-24, 13919\n2020-01-25, 14485\n2020-01-26, 18223\n2020-01-27, 20422\n2020-01-28, 22062\n2020-01-29, 18452\n2020-01-30, 17685\n2020-01-31, 15818\n2020-02-01, 75543\n2020-02-02, 32917\n2020-02-03, 28537\n2020-02-04, 34975\n2020-02-05, 30260\n2020-02-06, 25577\n2020-02-07, 22495\n2020-02-08, 38674\n2020-02-09, 27170\n2020-02-10, 28117\n2020-02-11, 28341\n2020-02-12, 26869\n2020-02-13, 25754\n2020-02-14, 23918\n2020-02-15, 23996\n2020-02-16, 25279\n2020-02-17, 29623\n2020-02-18, 31627\n2020-02-19, 26789\n2020-02-20, 23685\n2020-02-21, 24088\n2020-02-22, 25803\n2020-02-23, 28829\n2020-02-24, 27251\n2020-02-25, 27388\n2020-02-26, 25882\n2020-02-27, 25289\n2020-02-28, 22884\n2020-02-29, 22847\n2020-03-01, 25876\n2020-03-02, 25782\n2020-03-03, 27221\n2020-03-04, 26232\n2020-03-05, 22285\n2020-03-06, 19205\n2020-03-07, 19627\n2020-03-08, 31167\n2020-03-09, 24544\n2020-03-10, 23550\n2020-03-11, 44735\n2020-03-12, 43020\n2020-03-13, 22922\n2020-03-14, 22102\n2020-03-15, 27432\n2020-03-16, 26159\n2020-03-17, 26644\n2020-03-18, 29033\n2020-03-19, 28150\n2020-03-20, 25403\n2020-03-21, 27844\n2020-03-22, 28657\n2020-03-23, 31076\n2020-03-24, 26878\n2020-03-25, 24772\n2020-03-26, 24128\n2020-03-27, 20983\n2020-03-28, 22187\n2020-03-29, 24425\n2020-03-30, 24944\n2020-03-31, 27700\n2020-04-01, 29947\n2020-04-02, 33185\n2020-04-03, 28502\n2020-04-04, 25533\n2020-04-05, 32118\n2020-04-06, 32171\n2020-04-07, 30033\n2020-04-08, 29133\n2020-04-09, 28128\n2020-04-10, 22432\n2020-04-11, 23749\n2020-04-12, 26814\n2020-04-13, 31671\n2020-04-14, 28889\n2020-04-15, 30583\n2020-04-16, 28790\n2020-04-17, 25279\n2020-04-18, 25819\n2020-04-19, 34822\n2020-04-20, 32492\n2020-04-21, 30981\n2020-04-22, 35498\n2020-04-23, 32567\n2020-04-24, 33355\n2020-04-25, 33495\n2020-04-26, 39379\n2020-04-27, 41546\n2020-04-28, 48269\n2020-04-29, 50532\n2020-04-30, 40443\n2020-05-01, 42783\n2020-05-02, 43879\n2020-05-03, 43373\n2020-05-04, 50889\n2020-05-05, 55866\n2020-05-06, 59654\n2020-05-07, 53749\n2020-05-08, 42273\n2020-05-09, 41923\n2020-05-10, 82838\n2020-05-11, 60453\n2020-05-12, 46507\n2020-05-13, 48588\n2020-05-14, 38102\n2020-05-15, 40293\n2020-05-16, 33797\n2020-05-17, 38987\n2020-05-18, 31927\n2020-05-19, 33468\n2020-05-20, 36198\n2020-05-21, 46283\n2020-05-22, 27771\n2020-05-23, 30235\n2020-05-24, 34450\n2020-05-25, 30190\n2020-05-26, 34046\n2020-05-27, 38537\n2020-05-28, 34052\n2020-05-29, 29372\n2020-05-30, 28806\n2020-05-31, 34801\n2020-06-01, 48257\n2020-06-02, 32772\n2020-06-03, 33808\n2020-06-04, 31415\n2020-06-05, 26066\n2020-06-06, 26035\n2020-06-07, 30802\n2020-06-08, 33586\n2020-06-09, 35740\n2020-06-10, 34444\n2020-06-11, 34530\n2020-06-12, 30524\n2020-06-13, 24592\n2020-06-14, 28560\n2020-06-15, 28992\n2020-06-16, 23559\n2020-06-17, 23904\n2020-06-18, 29522\n2020-06-19, 26154\n2020-06-20, 26333\n2020-06-21, 33399\n2020-06-22, 34373\n2020-06-23, 32446\n2020-06-24, 31154\n2020-06-25, 30758\n2020-06-26, 28444\n2020-06-27, 28965\n2020-06-28, 32380\n2020-06-29, 28895\n2020-06-30, 26910\n2020-07-01, 26683\n2020-07-02, 25726\n2020-07-03, 24368\n2020-07-04, 20039\n2020-07-05, 27694\n2020-07-06, 22547\n2020-07-07, 22723\n2020-07-08, 24645\n2020-07-09, 24965\n2020-07-10, 22288\n2020-07-11, 19664\n2020-07-12, 25309\n2020-07-13, 35940\n2020-07-14, 54174\n2020-07-15, 56131\n2020-07-16, 24865\n2020-07-17, null\n2020-07-18, 18893\n2020-07-19, 24912\n2020-07-20, 27374\n2020-07-21, 25069\n2020-07-22, 27632\n2020-07-23, 27407\n2020-07-24, 27808\n2020-07-25, 30432\n2020-07-26, 51139\n2020-07-27, 45495\n2020-07-28, 33785\n2020-07-29, 32625\n2020-07-30, 30055\n2020-07-31, 39913\n2020-08-01, 33109\n2020-08-02, 29874\n2020-08-03, 29318\n2020-08-04, 38033\n2020-08-05, 38775\n2020-08-06, 37514\n2020-08-07, 29019\n2020-08-08, 25986\n2020-08-09, 35606\n2020-08-10, 33567\n2020-08-11, 35237\n2020-08-12, 30485\n2020-08-13, 38124\n2020-08-14, 39156\n2020-08-15, 29007\n2020-08-16, 40655\n2020-08-17, 38262\n2020-08-18, 36164\n2020-08-19, 33256\n2020-08-20, 34177\n2020-08-21, 27846\n2020-08-22, 28557\n2020-08-23, 32820\n2020-08-24, 36405\n2020-08-25, 31857\n2020-08-26, 32432\n2020-08-27, 34517\n2020-08-28, 26986\n2020-08-29, 27893\n2020-08-30, 29068\n2020-08-31, 35393\n2020-09-01, 32608\n2020-09-02, 37151\n2020-09-03, 34973\n2020-09-04, 28115\n2020-09-05, 23088\n2020-09-06, 30832\n2020-09-07, 28540\n2020-09-08, 30051\n2020-09-09, 29885\n2020-09-10, 30008\n2020-09-11, 27451\n2020-09-12, 27955\n2020-09-13, 29947\n2020-09-14, 34641\n2020-09-15, 35407\n2020-09-16, 33417\n2020-09-17, 31357\n2020-09-18, 29151\n2020-09-19, 26571\n2020-09-20, 32418\n2020-09-21, 38132\n2020-09-22, 47367\n2020-09-23, 37643\n2020-09-24, 38495\n2020-09-25, 25955\n2020-09-26, 37113\n2020-09-27, 34219\n2020-09-28, 32020\n2020-09-29, 33290\n2020-09-30, 35755\n2020-10-01, 32092\n2020-10-02, 29374\n2020-10-03, 31026\n2020-10-04, 29324\n2020-10-05, 30843\n2020-10-06, 34215\n2020-10-07, 42037\n2020-10-08, 41653\n2020-10-09, 37385\n2020-10-10, 33070\n2020-10-11, 32811\n2020-10-12, 33789\n2020-10-13, 87570\n2020-10-14, 63222\n2020-10-15, 36596\n2020-10-16, 29771\n2020-10-17, 26901\n2020-10-18, 31375\n2020-10-19, 37581\n2020-10-20, 64870\n2020-10-21, 43790\n2020-10-22, 35777\n2020-10-23, 32175\n2020-10-24, 28445\n2020-10-25, 36554\n2020-10-26, 44889\n2020-10-27, 36385\n2020-10-28, 36808\n2020-10-29, 32806\n2020-10-30, 49308\n2020-10-31, 40439\n2020-11-01, 32602\n2020-11-02, 36459\n2020-11-03, 47315\n2020-11-04, 60368\n2020-11-05, 47823\n2020-11-06, 33705\n2020-11-07, 30699\n2020-11-08, 35977\n2020-11-09, 35104\n2020-11-10, 39657\n2020-11-11, 44220\n2020-11-12, 48337\n2020-11-13, 37293\n2020-11-14, 33836\n2020-11-15, 47177\n2020-11-16, 74813\n2020-11-17, 70679\n2020-11-18, 43267\n2020-11-19, 47903\n2020-11-20, 45874\n2020-11-21, 43581\n2020-11-22, 47594\n2020-11-23, 78971\n2020-11-24, 46379\n2020-11-25, 53237\n2020-11-26, 44777\n2020-11-27, 37071\n2020-11-28, 33292\n2020-11-29, 66042\n2020-11-30, 60008\n2020-12-01, 48309\n2020-12-02, 44375\n2020-12-03, 46085\n2020-12-04, 39802\n2020-12-05, 39953\n2020-12-06, 45372\n2020-12-07, 46222\n2020-12-08, 42250\n2020-12-09, 37279\n2020-12-10, 35891\n2020-12-11, 38898\n2020-12-12, 39491\n2020-12-13, 38737\n2020-12-14, 43739\n2020-12-15, 127155\n2020-12-16, 120169\n2020-12-17, 67616\n2020-12-18, 56872\n2020-12-19, 62679\n2020-12-20, 61296\n2020-12-21, 45927\n2020-12-22, 43942\n2020-12-23, 42618\n2020-12-24, 49739\n2020-12-25, 72172\n2020-12-26, 88788\n2020-12-27, 59779\n2020-12-28, 56236\n2020-12-29, 80886\n2020-12-30, 68822\n2020-12-31, 55480\n2021-01-01, 145059\n2021-01-02, 141596\n2021-01-03, 82412\n2021-01-04, 68133\n2021-01-05, 86631\n2021-01-06, 125036\n2021-01-07, 113560\n2021-01-08, 84725\n2021-01-09, 74964\n2021-01-10, 109316\n2021-01-11, 83880\n2021-01-12, 91811\n2021-01-13, 106170\n2021-01-14, 70388\n2021-01-15, 62189\n2021-01-16, 59161\n2021-01-17, 69189\n2021-01-18, 70173\n2021-01-19, 61204\n2021-01-20, 79347\n2021-01-21, 79570\n2021-01-22, 52802\n2021-01-23, 50983\n2021-01-24, 63766\n2021-01-25, 55828\n2021-01-26, 60652\n2021-01-27, 84933\n2021-01-28, 200783\n2021-01-29, 93578\n2021-01-30, 68163\n2021-01-31, 91439\n2021-02-01, 80624\n2021-02-02, 87809\n2021-02-03, 76348\n2021-02-04, 97415\n2021-02-05, 107331\n2021-02-06, 77886\n2021-02-07, 212923\n2021-02-08, 159207\n2021-02-09, 124292\n2021-02-10, 115390\n2021-02-11, 122503\n2021-02-12, 93740\n2021-02-13, 99797\n2021-02-14, 101777\n2021-02-15, 147792\n2021-02-16, 147890\n2021-02-17, 116096\n2021-02-18, 150898\n2021-02-19, 118093\n2021-02-20, 111638\n2021-02-21, 110348\n2021-02-22, 131691\n2021-02-23, 103733\n2021-02-24, 82520\n2021-02-25, 81742\n2021-02-26, 66315\n2021-02-27, 73439\n2021-02-28, 89756\n2021-03-01, 103342\n2021-03-02, 94227\n2021-03-03, 81460\n2021-03-04, 70950\n2021-03-05, 40281\n2021-03-06, 68935\n2021-03-07, 81828\n2021-03-08, 85849\n2021-03-09, 81908\n2021-03-10, 95858\n2021-03-11, 104787\n2021-03-12, 154790\n2021-03-13, 102059\n2021-03-14, 116563\n2021-03-15, 99951\n2021-03-16, 106258\n2021-03-17, 106755\n2021-03-18, 106380\n2021-03-19, 92396\n2021-03-20, 80437\n2021-03-21, 103950\n2021-03-22, 94277\n2021-03-23, 130216\n2021-03-24, 137938\n2021-03-25, 137602\n2021-03-26, 106231\n2021-03-27, 86361\n2021-03-28, 104638\n2021-03-29, 111290\n2021-03-30, 108145\n2021-03-31, 69301\n2021-04-01, 30540\n2021-04-02, 75450\n2021-04-03, 87528\n2021-04-04, 44761\n2021-04-05, 32289\n2021-04-06, 86985\n2021-04-07, 104094\n2021-04-08, 102638\n2021-04-09, 110849\n2021-04-10, 94714\n2021-04-11, 132176\n2021-04-12, 171108\n2021-04-13, 161204\n2021-04-14, 110223\n2021-04-15, 113640\n2021-04-16, 100583\n2021-04-17, 178464\n2021-04-18, 122950\n2021-04-19, 112302\n2021-04-20, 96848\n2021-04-21, 108961\n2021-04-22, 132963\n2021-04-23, 86049\n2021-04-24, 81258\n2021-04-25, 110552\n2021-04-26, 102971\n2021-04-27, 97333\n2021-04-28, 96503\n2021-04-29, 92350\n2021-04-30, 99595\n2021-05-01, 78756\n2021-05-02, 89710\n2021-05-03, 87287\n2021-05-04, 93866\n2021-05-05, 84935\n2021-05-06, 103515\n2021-05-07, 82542\n2021-05-08, 62002\n2021-05-09, 74446\n2021-05-10, 72974\n2021-05-11, 104572\n2021-05-12, 249599\n2021-05-13, 120644\n2021-05-14, 95522\n2021-05-15, 148557\n2021-05-16, 184558\n2021-05-17, 120021\n2021-05-18, 363566\n2021-05-19, 173415\n2021-05-20, 185009\n2021-05-21, 174133\n2021-05-22, 160368\n2021-05-23, 151342\n2021-05-24, 107640\n2021-05-25, 114558\n2021-05-26, 100263\n2021-05-27, 104815\n2021-05-28, 98843\n2021-05-29, 109381\n2021-05-30, 101203\n2021-05-31, 105694\n2021-06-01, 92542\n2021-06-02, 88708\n2021-06-03, 184618\n2021-06-04, 174730\n2021-06-05, 211698\n2021-06-06, 172116\n2021-06-07, 187281\n2021-06-08, 297825\n2021-06-09, 192780\n2021-06-10, 145724\n2021-06-11, 133446\n2021-06-12, 149747\n2021-06-13, 173293\n2021-06-14, 139190\n2021-06-15, 116771\n2021-06-16, 122733\n2021-06-17, 125163\n2021-06-18, 98521\n2021-06-19, 100940\n2021-06-20, 153833\n2021-06-21, 153834\n2021-06-22, 125027\n2021-06-23, 105656\n2021-06-24, 154086\n2021-06-25, 105096\n2021-06-26, 122259\n2021-06-27, 128407\n2021-06-28, 120506\n2021-06-29, 110739\n2021-06-30, 110932\n2021-07-01, 101685\n2021-07-02, 92900\n2021-07-03, 85810\n2021-07-04, 88486\n2021-07-05, 95429\n2021-07-06, 111493\n2021-07-07, 108695\n2021-07-08, 98121\n2021-07-09, 85014\n2021-07-10, 70863\n2021-07-11, 98470\n2021-07-12, 141201\n2021-07-13, 98812\n2021-07-14, 92346\n2021-07-15, 86926\n2021-07-16, 73357\n2021-07-17, 75089\n2021-07-18, 83081\n2021-07-19, 102358\n2021-07-20, 150305\n2021-07-21, 106901\n2021-07-22, 87678\n2021-07-23, 97003\n2021-07-24, 83272\n2021-07-25, 184548\n2021-07-26, 128220\n2021-07-27, 133752\n2021-07-28, 106512\n2021-07-29, 93955\n2021-07-30, 88543\n2021-07-31, 103030\n2021-08-01, 118549\n2021-08-02, 103494\n2021-08-03, 97689\n2021-08-04, 95549\n2021-08-05, 104769\n2021-08-06, 110473\n2021-08-07, 97178\n2021-08-08, 121767\n2021-08-09, 113397\n2021-08-10, 99731\n2021-08-11, 98097\n2021-08-12, 98133\n2021-08-13, 81771\n2021-08-14, 77118\n2021-08-15, 99378\n2021-08-16, 98097\n2021-08-17, 96506\n2021-08-18, 102697\n2021-08-19, 113364\n2021-08-20, 83918\n2021-08-21, 79512\n2021-08-22, 139656\n2021-08-23, 119165\n2021-08-24, 98782\n2021-08-25, 87815\n2021-08-26, 97836\n2021-08-27, 79411\n2021-08-28, 83476\n2021-08-29, 100326\n2021-08-30, 85170\n2021-08-31, 103531\n2021-09-01, 124469\n2021-09-02, 113030\n2021-09-03, 94327\n2021-09-04, 91052\n2021-09-05, 137763\n2021-09-06, 240284\n2021-09-07, 154503\n2021-09-08, 104725\n2021-09-09, 100785\n2021-09-10, 78525\n2021-09-11, 77722\n2021-09-12, 103761\n2021-09-13, 91267\n2021-09-14, 109407\n2021-09-15, 90855\n2021-09-16, 101046\n2021-09-17, 82649\n2021-09-18, 74123\n2021-09-19, 131996\n2021-09-20, 101636\n2021-09-21, 98217\n2021-09-22, 117001\n2021-09-23, 161656\n2021-09-24, 97401\n2021-09-25, 85595\n2021-09-26, 103126\n2021-09-27, 99868\n2021-09-28, 110555\n2021-09-29, 109580\n2021-09-30, 149724\n2021-10-01, 89506\n2021-10-02, 97975\n2021-10-03, 132624\n2021-10-04, 153503\n2021-10-05, 195155\n2021-10-06, 129606\n2021-10-07, 107673\n2021-10-08, 92850\n2021-10-09, 91018\n2021-10-10, 142028\n2021-10-11, 114161\n2021-10-12, 113945\n2021-10-13, 130212\n2021-10-14, 232707\n2021-10-15, 141705\n2021-10-16, 111977\n2021-10-17, 140381\n2021-10-18, 176844\n2021-10-19, 290630\n2021-10-20, 186417\n2021-10-21, 147588\n2021-10-22, 114275\n2021-10-23, 106803\n2021-10-24, 134501\n2021-10-25, 125247\n2021-10-26, 126449\n2021-10-27, 125041\n2021-10-28, 112918\n2021-10-29, 91063\n2021-10-30, 105589\n2021-10-31, 112167\n2021-11-01, 137644\n2021-11-02, 127439\n2021-11-03, 119426\n2021-11-04, 115671\n2021-11-05, 97179\n2021-11-06, 103642\n2021-11-07, 168461\n2021-11-08, 189677\n2021-11-09, 154746\n2021-11-10, 131369\n2021-11-11, 121364\n2021-11-12, 120378\n2021-11-13, 125767\n2021-11-14, 137226\n2021-11-15, 141774\n2021-11-16, 128054\n2021-11-17, 134465\n2021-11-18, 150357\n2021-11-19, 128237\n2021-11-20, 140192\n2021-11-21, 132390\n2021-11-22, 128649\n2021-11-23, 116024\n2021-11-24, 114979\n2021-11-25, 146605\n2021-11-26, 120878\n2021-11-27, 118553\n2021-11-28, 142628\n2021-11-29, 116550\n2021-11-30, 138996\n2021-12-01, 121726\n2021-12-02, 125774\n2021-12-03, 196868\n2021-12-04, 124214\n2021-12-05, 153780\n2021-12-06, 161163\n2021-12-07, 152439\n2021-12-08, 135187\n2021-12-09, 131883\n2021-12-10, 127315\n2021-12-11, 140184\n2021-12-12, 144296\n2021-12-13, 141026\n2021-12-14, 146865\n2021-12-15, 123918\n2021-12-16, 116145\n2021-12-17, 116620\n2021-12-18, 113612\n2021-12-19, 124159\n2021-12-20, 137590\n2021-12-21, 120983\n2021-12-22, 133215\n2021-12-23, 122898\n2021-12-24, 110526\n2021-12-25, 91493\n2021-12-26, 105198\n2021-12-27, 118350\n2021-12-28, 111906\n2021-12-29, 126646\n2021-12-30, 116434\n2021-12-31, 93876\n2022-01-01, 114214\n2022-01-02, 157281\n2022-01-03, 152831\n2022-01-04, 149229\n2022-01-05, 174937\n2022-01-06, 179285\n2022-01-07, 146927\n2022-01-08, 139164\n2022-01-09, 163362\n2022-01-10, 151517\n2022-01-11, 163623\n2022-01-12, 155209\n2022-01-13, 139135\n2022-01-14, 119554\n2022-01-15, 124308\n2022-01-16, 137749\n2022-01-17, 154438\n2022-01-18, 154193\n2022-01-19, 147865'

# %%
twitter = []
for row in csv_data_raw.split("\n"):
    raw_date, tweet_value = row.split(", ")
    
    dt = datetime.strptime(raw_date, "%Y-%m-%d").date()
    twitter.append((dt, tweet_value))

# %%
twitter = pd.DataFrame(twitter, columns=['date', 'tweets'])

# %%
twitter["date"]= pd.to_datetime(twitter["date"])
twitter.set_index('date', inplace = True)
twitter['tweets'] = twitter['tweets'].shift(periods=1)
twitter = twitter.loc['2019-12-31':]
twitter['tweets'] = pd.to_numeric(twitter['tweets'],errors = 'coerce')
twitter.dropna(inplace=True)
twitter['tweets'] = twitter['tweets'] * 1000

# %%
twitter['tweets'].isna().sum()
# twitter.tweets[twitter.isna().any(axis=1)]
# Out:
# 0

# %%
# create a scaler object
std_scaler = StandardScaler()
std_scaler
# Out:
# StandardScaler()

# %%
#standardizing the number of tweets per day
twitter_st = pd.DataFrame(std_scaler.fit_transform(twitter), columns=twitter.columns)

# %%
twitter_st.index=twitter.index

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Standardising Bitcoin data (changed from unscaled to Bitcoin)

# %%
df_x = Bitcoin_df[["Bitcoin"]]

# %%
df_x.dropna(inplace=True)
# Out:
# <ipython-input-67-99f8a002d145>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_x.dropna(inplace=True)

# %%
df_x
# Out:
#             Bitcoin
# date
# 2020-01-05     7.41
# 2020-01-06     9.23
# 2020-01-07    13.00
# 2020-01-08    11.44
# 2020-01-09    10.27
# ...             ...
# 2022-01-18    17.16
# 2022-01-19    15.60
# 2022-01-20    16.77
# 2022-01-21    36.66
# 2022-01-22    39.00
#
# [749 rows x 1 columns]

# %%
# create a scaler object
std_scaler = StandardScaler()
std_scaler
# fit and transform the data
df_data_st = pd.DataFrame(std_scaler.fit_transform(df_x), columns=df_x.columns)

df_data_st
# Out:
#       Bitcoin
# 0   -0.849183
# 1   -0.732194
# 2   -0.489860
# 3   -0.590136
# 4   -0.665343
# ..        ...
# 744 -0.222456
# 745 -0.322733
# 746 -0.247525
# 747  1.030996
# 748  1.181410
#
# [749 rows x 1 columns]

# %%
df_data_st.index=df_x.index

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Merging all transformed data (missing IR, daily infectious diseasse traker)

# %%
btc_merged=returns_btc.join(df_data_st)
btc_df= btc_merged.merge(yahoofin_returns, left_index=True, right_index=True)
btc_1 = btc_df.merge(df_merge_returns, left_index=True, right_index=True)
btc_2 = btc_1.merge(dfs_currency, left_index=True, right_index=True)
btc_3 = btc_2.merge(CRIX_returns, left_index=True, right_index=True)
btc_4 = btc_3.merge(interestratechange_ln, left_index=True, right_index=True)
btc_data = btc_4.merge(twitter_st, left_index=True, right_index=True)

# %%
data_btc=btc_data.dropna()

# %%
data_btc.rename(columns={"Bitcoin": "GoogleTrend", "Close": "BTC_ret"}, inplace=True)
# Out:
# /Users/carlarunden/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
data_btc.head()
# Out:
#              BTC_ret  GoogleTrend      GOLD       OIL     SP500       EPU  \
# 2020-01-06  0.047161    -0.732194  0.010914  0.003483  0.003527  0.313885
# 2020-01-07  0.049527    -0.489860  0.003569 -0.009050 -0.002807 -0.352743
# 2020-01-08 -0.010322    -0.590136 -0.009204 -0.050538  0.004890 -0.131692
# 2020-01-09 -0.025165    -0.665343 -0.003667 -0.000839  0.006633 -0.236952
# 2020-01-10  0.035837    -0.707125  0.003731 -0.008769 -0.002859  0.036318
#
#             transactions       VIX      DOWJ  USD_KZT Change %  \
# 2020-01-06     -0.056445 -0.012200 -0.001171             -0.57
# 2020-01-07      0.139940 -0.004342  0.001236              0.02
# 2020-01-08     -0.078760 -0.024965  0.008488             -0.70
# 2020-01-09      0.012617 -0.070056  0.004725             -0.44
# 2020-01-10      0.026586  0.001594 -0.006101              0.35
#
#             USD_INR Change %  USD_RON Change %      CRIX        IR    tweets
# 2020-01-06              0.14             -0.24  0.041392  0.000000 -1.199177
# 2020-01-07             -0.03              0.45  0.067145  0.000000 -1.110570
# 2020-01-08             -0.46              0.39 -0.023380  0.000000 -1.113182
# 2020-01-09             -0.43              0.05 -0.028021  0.000000 -1.119611
# 2020-01-10             -0.35             -0.14  0.041178 -0.006473 -1.164497

# %% [markdown]
# #### Merging all the raw data together (containing all 16 factors)

# %%
df505= dfs_currency.merge(df404, left_index=True, 
                          right_index=True).merge(df_CRIX, left_index=True, right_index=True).merge(yahoofin_IR,
                                                                                                   left_index=True, right_index=True)
df505.head()
# Out:
#             USD_KZT Change %  USD_INR Change %  USD_RON Change %     EPU  \
# 2020-01-02              0.00              0.16              0.13  139.13
# 2020-01-03              0.00              0.59             -0.07  108.10
# 2020-01-06             -0.57              0.14             -0.24  147.96
# 2020-01-07              0.02             -0.03              0.45  103.98
# 2020-01-08             -0.70             -0.46              0.39   91.15
#
#             transactions    VIX    DOWJ  daily_infect_emv_index    CRIX  \
# 2020-01-02      295567.0  12.47  935.13                    2.84  509.33
# 2020-01-03      316517.0  14.02  923.15                    1.33  538.09
# 2020-01-06      299146.0  13.85  922.07                    0.99  560.83
# 2020-01-07      344079.0  13.79  923.21                    0.00  599.78
# 2020-01-08      318019.0  13.45  931.08                    0.56  585.92
#
#                    GOLD        OIL        SP500    IR
# 2020-01-02  1524.500000  61.180000  3257.850098  1.55
# 2020-01-03  1549.199951  63.049999  3234.850098  1.55
# 2020-01-06  1566.199951  63.270000  3246.280029  1.55
# 2020-01-07  1571.800049  62.700001  3237.179932  1.55
# 2020-01-08  1557.400024  59.610001  3253.050049  1.55

# %%
df606=df505.merge(df_data_st, left_index=True, 
                           right_index=True).merge(df_btc, left_index=True, right_index=True)
df_raw_merged = df606.merge(twitter, left_index=True, right_index=True)
df_raw= df_raw_merged.dropna()

df_raw.head() #not rally sure why raw data has 4 less observations than the data_btc
# Out:
#             USD_KZT Change %  USD_INR Change %  USD_RON Change %     EPU  \
# 2020-01-06             -0.57              0.14             -0.24  147.96
# 2020-01-07              0.02             -0.03              0.45  103.98
# 2020-01-08             -0.70             -0.46              0.39   91.15
# 2020-01-09             -0.44             -0.43              0.05   71.92
# 2020-01-10              0.35             -0.35             -0.14   74.58
#
#             transactions    VIX    DOWJ  daily_infect_emv_index    CRIX  \
# 2020-01-06      299146.0  13.85  922.07                    0.99  560.83
# 2020-01-07      344079.0  13.79  923.21                    0.00  599.78
# 2020-01-08      318019.0  13.45  931.08                    0.56  585.92
# 2020-01-09      322057.0  12.54  935.49                    1.16  569.73
# 2020-01-10      330734.0  12.56  929.80                    0.00  593.68
#
#                    GOLD        OIL        SP500    IR   Bitcoin        Close  \
# 2020-01-06  1566.199951  63.270000  3246.280029  1.55 -0.732194  7769.219238
# 2020-01-07  1571.800049  62.700001  3237.179932  1.55 -0.489860  8163.692383
# 2020-01-08  1557.400024  59.610001  3253.050049  1.55 -0.590136  8079.862793
# 2020-01-09  1551.699951  59.560001  3274.699951  1.55 -0.665343  7879.071289
# 2020-01-10  1557.500000  59.040001  3265.350098  1.54 -0.707125  8166.554199
#
#                 tweets
# 2020-01-06  16540000.0
# 2020-01-07  20950000.0
# 2020-01-08  20820000.0
# 2020-01-09  20500000.0
# 2020-01-10  18266000.0

# %% [markdown]
# ### Descriptives - get to know the data

# %%
data_btc.hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'BTC_ret'}>,
#         <AxesSubplot:title={'center':'GoogleTrend'}>,
#         <AxesSubplot:title={'center':'GOLD'}>,
#         <AxesSubplot:title={'center':'OIL'}>],
#        [<AxesSubplot:title={'center':'SP500'}>,
#         <AxesSubplot:title={'center':'EPU'}>,
#         <AxesSubplot:title={'center':'transactions'}>,
#         <AxesSubplot:title={'center':'VIX'}>],
#        [<AxesSubplot:title={'center':'DOWJ'}>,
#         <AxesSubplot:title={'center':'USD_KZT Change %'}>,
#         <AxesSubplot:title={'center':'USD_INR Change %'}>,
#         <AxesSubplot:title={'center':'USD_RON Change %'}>],
#        [<AxesSubplot:title={'center':'CRIX'}>,
#         <AxesSubplot:title={'center':'IR'}>,
#         <AxesSubplot:title={'center':'tweets'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
data_btc.describe()
# Out:
#           BTC_ret  GoogleTrend        GOLD         OIL       SP500  \
# count  441.000000   441.000000  441.000000  441.000000  441.000000
# mean     0.003702     0.023461   -0.000042    0.001770    0.000801
# std      0.046379     1.042672    0.011303    0.046122    0.016539
# min     -0.464730    -1.132656   -0.051069   -0.282206   -0.127652
# 25%     -0.015422    -0.698768   -0.004443   -0.012006   -0.004369
# 50%      0.002544    -0.338160    0.000528    0.002476    0.001678
# 75%      0.025681     0.352203    0.006072    0.016807    0.007797
# max      0.171821     5.102467    0.041633    0.319634    0.088808
#
#               EPU  transactions         VIX        DOWJ  USD_KZT Change %  \
# count  441.000000    441.000000  441.000000  441.000000        441.000000
# mean    -0.003790     -0.001380   -0.001609   -0.000765          0.016463
# std      0.413528      0.096072    0.088673    0.034360          0.523176
# min     -1.426062     -0.492266   -0.266228   -0.268934         -1.980000
# 25%     -0.257217     -0.056527   -0.048673   -0.017589         -0.190000
# 50%     -0.004318     -0.001451   -0.011931   -0.001268          0.000000
# 75%      0.244524      0.046400    0.034239    0.015600          0.170000
# max      1.448161      0.389788    0.480214    0.115166          6.970000
#
#        USD_INR Change %  USD_RON Change %        CRIX          IR      tweets
# count        441.000000        441.000000  441.000000  441.000000  441.000000
# mean           0.000680          0.007914    0.004209   -0.006946    0.039713
# std            0.341742          0.426533    0.045961    0.099201    1.053676
# min           -1.930000         -1.350000   -0.272552   -1.481605   -1.223991
# 25%           -0.170000         -0.260000   -0.017888    0.000000   -0.872073
# 50%            0.000000          0.000000    0.006435    0.000000   -0.250296
# 75%            0.170000          0.250000    0.031070    0.000000    0.750183
# max            1.630000          1.910000    0.185811    0.510826    5.773389

# %% [markdown]
# ### Should we standardized/winsorized ? When doing histograms i did not see any outliers maybe not necessary ?

# %%
sns.pairplot(data_btc)

# %% [markdown]
# ### Dickey-Fuller test (if needed)
#
# https://www.statsmodels.org/dev/generated/statsmodels.tsa.stattools.adfuller.html
# https://www.statology.org/dickey-fuller-test-python/
# https://www.hackdeploy.com/augmented-dickey-fuller-test-in-python/

# %%
#Def function for ADF, i found it on the internet :) --> same link as for the VAR
def adfuller_test(series, signif=0.05, name='', verbose=False):
    """Perform ADFuller to test for Stationarity of given series and print report"""
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    # Print Summary
    print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")

# %%
# ADF Test on each column in the RAW dataframe
for name, column in df_raw.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "USD_KZT Change %"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -8.6768
#  No. Lags Chosen       = 2
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "USD_INR Change %"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -22.7804
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "USD_RON Change %"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -13.5232
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "EPU"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.3898
#  No. Lags Chosen       = 4
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.1446. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "transactions"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.6412
#  No. Lags Chosen       = 14
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.4616. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "VIX"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.1925
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0204. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "DOWJ"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.4352
#  No. Lags Chosen       = 9
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.132. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "daily_infect_emv_index"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.2806
#  No. Lags Chosen       = 6
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0158. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "CRIX"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -0.9511
#  No. Lags Chosen       = 4
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.7707. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "GOLD"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.6937
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0751. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "OIL"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -0.7134
#  No. Lags Chosen       = 4
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.8433. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "SP500"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -0.199
#  No. Lags Chosen       = 9
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.9386. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "IR"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.8791
#  No. Lags Chosen       = 16
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0022. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Bitcoin"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.0335
#  No. Lags Chosen       = 17
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.2721. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Close"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.0952
#  No. Lags Chosen       = 7
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.717. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "tweets"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.0875
#  No. Lags Chosen       = 17
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.72. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.

# %%
# ADF Test on each column in the transformed dataframe
for name, column in data_btc.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "BTC_ret"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.3617
#  No. Lags Chosen       = 7
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "GoogleTrend"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.6996
#  No. Lags Chosen       = 18
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.4313. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "GOLD"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -11.8265
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "OIL"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.3141
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0004. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "SP500"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.12
#  No. Lags Chosen       = 11
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "EPU"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -18.0367
#  No. Lags Chosen       = 2
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "transactions"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -14.0723
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "VIX"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -23.5828
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "DOWJ"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.1328
#  No. Lags Chosen       = 8
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "USD_KZT Change %"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.5766
#  No. Lags Chosen       = 6
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "USD_INR Change %"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.5049
#  No. Lags Chosen       = 5
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "USD_RON Change %"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -19.7198
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "CRIX"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.2216
#  No. Lags Chosen       = 7
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "IR"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.1165
#  No. Lags Chosen       = 9
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0009. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "tweets"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.3883
#  No. Lags Chosen       = 12
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.5879. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.

# %% [markdown]
# ##### Google trend + tweets = non-stationary data

# %% [markdown]
# ### Correlation matirx

# %%
data_btc.corr()

# Plotting the seaborn heatmap 
fig = plt.figure(figsize=[20,20])
sns.heatmap(data_btc.corr(), annot=True, cmap="Greens")
plt.show()

# %%
df_raw.corr()

# Plotting the seaborn heatmap 
fig = plt.figure(figsize=[20,20])
sns.heatmap(df_raw.corr(), annot=True, cmap="Greens")
plt.show()

# %%
data_btc.corr()
# Out:
#                    BTC_ret  GoogleTrend      GOLD       OIL     SP500  \
# BTC_ret           1.000000    -0.003269  0.128860  0.150051  0.379529
# GoogleTrend      -0.003269     1.000000 -0.062764  0.026648  0.008607
# GOLD              0.128860    -0.062764  1.000000  0.098553  0.135972
# OIL               0.150051     0.026648  0.098553  1.000000  0.309552
# SP500             0.379529     0.008607  0.135972  0.309552  1.000000
# EPU              -0.014122     0.015783  0.041765 -0.019541  0.047545
# transactions      0.004417    -0.009979 -0.021079  0.032322 -0.017338
# VIX              -0.366834    -0.008599 -0.063591 -0.242778 -0.728029
# DOWJ              0.287700     0.032090  0.032916  0.274844  0.680433
# USD_KZT Change % -0.038383    -0.002496 -0.182777 -0.138402 -0.280816
# USD_INR Change % -0.172391    -0.002009 -0.231085 -0.196401 -0.327523
# USD_RON Change % -0.087682     0.016155 -0.280483  0.054913 -0.030662
# CRIX              0.773916    -0.065821  0.167735  0.232789  0.308045
# IR                0.010625     0.029898 -0.010183  0.112304  0.292746
# tweets           -0.005067     0.659845 -0.010273  0.038604  0.038605
#
#                        EPU  transactions       VIX      DOWJ  \
# BTC_ret          -0.014122      0.004417 -0.366834  0.287700
# GoogleTrend       0.015783     -0.009979 -0.008599  0.032090
# GOLD              0.041765     -0.021079 -0.063591  0.032916
# OIL              -0.019541      0.032322 -0.242778  0.274844
# SP500             0.047545     -0.017338 -0.728029  0.680433
# EPU               1.000000      0.000660 -0.028577  0.045022
# transactions      0.000660      1.000000 -0.007651  0.044259
# VIX              -0.028577     -0.007651  1.000000 -0.527069
# DOWJ              0.045022      0.044259 -0.527069  1.000000
# USD_KZT Change %  0.012543     -0.064559  0.160895 -0.314287
# USD_INR Change % -0.022248     -0.044712  0.207527 -0.232517
# USD_RON Change % -0.053907     -0.012179  0.054703 -0.065108
# CRIX             -0.073971      0.060386 -0.283739  0.249941
# IR               -0.091319     -0.074026 -0.132089  0.232688
# tweets           -0.015962      0.010202 -0.061881  0.006112
#
#                   USD_KZT Change %  USD_INR Change %  USD_RON Change %  \
# BTC_ret                  -0.038383         -0.172391         -0.087682
# GoogleTrend              -0.002496         -0.002009          0.016155
# GOLD                     -0.182777         -0.231085         -0.280483
# OIL                      -0.138402         -0.196401          0.054913
# SP500                    -0.280816         -0.327523         -0.030662
# EPU                       0.012543         -0.022248         -0.053907
# transactions             -0.064559         -0.044712         -0.012179
# VIX                       0.160895          0.207527          0.054703
# DOWJ                     -0.314287         -0.232517         -0.065108
# USD_KZT Change %          1.000000          0.139726          0.148978
# USD_INR Change %          0.139726          1.000000          0.308991
# USD_RON Change %          0.148978          0.308991          1.000000
# CRIX                     -0.066609         -0.167365         -0.116453
# IR                       -0.454264         -0.003705         -0.037213
# tweets                   -0.032476         -0.002444          0.029450
#
#                       CRIX        IR    tweets
# BTC_ret           0.773916  0.010625 -0.005067
# GoogleTrend      -0.065821  0.029898  0.659845
# GOLD              0.167735 -0.010183 -0.010273
# OIL               0.232789  0.112304  0.038604
# SP500             0.308045  0.292746  0.038605
# EPU              -0.073971 -0.091319 -0.015962
# transactions      0.060386 -0.074026  0.010202
# VIX              -0.283739 -0.132089 -0.061881
# DOWJ              0.249941  0.232688  0.006112
# USD_KZT Change % -0.066609 -0.454264 -0.032476
# USD_INR Change % -0.167365 -0.003705 -0.002444
# USD_RON Change % -0.116453 -0.037213  0.029450
# CRIX              1.000000  0.059535 -0.037879
# IR                0.059535  1.000000  0.066418
# tweets           -0.037879  0.066418  1.000000

# %% [markdown]
# ### Classic OLS model
# https://www.statsmodels.org/dev/examples/notebooks/generated/ols.html

# %%
x=data_btc.drop(columns=['BTC_ret'])

# %%
y=data_btc.BTC_ret

# %%
#Model without the constant - just the variables also considering IR but we can replace it later
results = sm.OLS(y, x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                BTC_ret   R-squared (uncentered):                   0.643
# Model:                            OLS   Adj. R-squared (uncentered):              0.632
# Method:                 Least Squares   F-statistic:                              55.05
# Date:                Tue, 25 Jan 2022   Prob (F-statistic):                    2.45e-86
# Time:                        15:50:04   Log-Likelihood:                          955.03
# No. Observations:                 441   AIC:                                     -1882.
# Df Residuals:                     427   BIC:                                     -1825.
# Df Model:                          14
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# GoogleTrend          0.0025      0.002      1.460      0.145      -0.001       0.006
# GOLD                -0.0254      0.131     -0.194      0.846      -0.282       0.231
# OIL                 -0.0762      0.032     -2.405      0.017      -0.138      -0.014
# SP500                0.3440      0.149      2.306      0.022       0.051       0.637
# EPU                  0.0026      0.003      0.776      0.438      -0.004       0.009
# transactions        -0.0196      0.014     -1.376      0.170      -0.047       0.008
# VIX                 -0.0478      0.023     -2.112      0.035      -0.092      -0.003
# DOWJ                 0.0154      0.055      0.278      0.781      -0.093       0.124
# USD_KZT Change %     0.0015      0.003      0.503      0.615      -0.004       0.008
# USD_INR Change %    -0.0013      0.005     -0.298      0.766      -0.010       0.008
# USD_RON Change %     0.0009      0.004      0.260      0.795      -0.006       0.008
# CRIX                 0.7447      0.032     23.331      0.000       0.682       0.807
# IR                  -0.0322      0.016     -2.010      0.045      -0.064      -0.001
# tweets              -0.0007      0.002     -0.424      0.672      -0.004       0.003
# ==============================================================================
# Omnibus:                      101.197   Durbin-Watson:                   2.660
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1602.945
# Skew:                          -0.476   Prob(JB):                         0.00
# Kurtosis:                      12.291   Cond. No.                         156.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = ols("BTC_ret ~ OIL + GOLD + SP500 + GoogleTrend", data_btc)
fit = model.fit()
print(fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                BTC_ret   R-squared:                       0.151
# Model:                            OLS   Adj. R-squared:                  0.143
# Method:                 Least Squares   F-statistic:                     19.39
# Date:                Tue, 25 Jan 2022   Prob (F-statistic):           1.08e-14
# Time:                        15:50:04   Log-Likelihood:                 765.12
# No. Observations:                 441   AIC:                            -1520.
# Df Residuals:                     436   BIC:                            -1500.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0029      0.002      1.394      0.164      -0.001       0.007
# OIL             0.0315      0.047      0.673      0.501      -0.060       0.123
# GOLD            0.3149      0.183      1.716      0.087      -0.046       0.676
# SP500           1.0079      0.131      7.697      0.000       0.751       1.265
# GoogleTrend    -0.0001      0.002     -0.054      0.957      -0.004       0.004
# ==============================================================================
# Omnibus:                      169.118   Durbin-Watson:                   2.137
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2453.840
# Skew:                          -1.228   Prob(JB):                         0.00
# Kurtosis:                      14.292   Cond. No.                         94.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## VAR model
# https://www.machinelearningplus.com/time-series/vector-autoregression-examples-python/
# https://analyticsindiamag.com/hands-on-tutorial-on-vector-autoregressionvar-for-time-series-modeling/

# %%
data_btc.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Granger's causality test - should we do that also ?
# By using granger’s causality test, we can find the relationship between the variables before building the model because it is known that if there is no relationship between the variables, we can drop the variables and separately do the modeling. If there is a relationship between them, we need to consider the variable in the modeling part.
#
# In mathematics, the test provides the p-value between the variables, and if the p-value is higher than 0.05 then we will be required to accept the null hypothesis, and if the p-value is lesser than 0.05 we are required to reject the null hypothesis.
#
# Statsmodel also provides a module to perform the test, so using the statsmodel next, I am performing the granger’s causality test.

# %%
from statsmodels.tsa.stattools import grangercausalitytests
maxlag=15
test = 'ssr_chi2test'

def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
   
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

grangers_causation_matrix(data_btc, variables = data_btc.columns)
# Out:
#                     BTC_ret_x  GoogleTrend_x  GOLD_x   OIL_x  SP500_x   EPU_x  \
# BTC_ret_y              1.0000         0.0233  0.0039  0.0078   0.1096  0.5710
# GoogleTrend_y          0.1132         1.0000  0.7823  0.6333   0.4750  0.4724
# GOLD_y                 0.1229         0.3592  1.0000  0.0012   0.0003  0.0418
# OIL_y                  0.0000         0.5054  0.0001  1.0000   0.0000  0.7844
# SP500_y                0.0000         0.5344  0.0229  0.0232   1.0000  0.6283
# EPU_y                  0.1104         0.4102  0.0100  0.0757   0.0088  1.0000
# transactions_y         0.0001         0.0109  0.0944  0.4039   0.0326  0.2006
# VIX_y                  0.0009         0.5486  0.0449  0.2448   0.0006  0.6136
# DOWJ_y                 0.0000         0.3321  0.0797  0.0304   0.0000  0.4341
# USD_KZT Change %_y     0.0000         0.7511  0.0000  0.0000   0.0000  0.2277
# USD_INR Change %_y     0.0514         0.1938  0.3677  0.0227   0.0000  0.6601
# USD_RON Change %_y     0.0017         0.1924  0.0533  0.0033   0.0000  0.4556
# CRIX_y                 0.0002         0.0182  0.0103  0.1272   0.0702  0.1663
# IR_y                   0.0000         0.6804  0.0000  0.0000   0.0000  0.6462
# tweets_y               0.0111         0.0000  0.5957  0.6958   0.8352  0.0885
#
#                     transactions_x   VIX_x  DOWJ_x  USD_KZT Change %_x  \
# BTC_ret_y                   0.1619  0.0224  0.2876              0.0211
# GoogleTrend_y               0.2062  0.2521  0.5501              0.2883
# GOLD_y                      0.0344  0.0002  0.0397              0.0015
# OIL_y                       0.0205  0.0000  0.0000              0.0000
# SP500_y                     0.0203  0.0000  0.0001              0.0000
# EPU_y                       0.1180  0.0301  0.2843              0.0060
# transactions_y              1.0000  0.1955  0.0552              0.0002
# VIX_y                       0.0215  1.0000  0.1083              0.0693
# DOWJ_y                      0.1907  0.0006  1.0000              0.0000
# USD_KZT Change %_y          0.0238  0.0000  0.0000              1.0000
# USD_INR Change %_y          0.1102  0.0004  0.0001              0.0000
# USD_RON Change %_y          0.1167  0.0000  0.0000              0.0000
# CRIX_y                      0.0645  0.0080  0.2665              0.0322
# IR_y                        0.0019  0.0000  0.0000              0.0000
# tweets_y                    0.4021  0.2951  0.6733              0.4565
#
#                     USD_INR Change %_x  USD_RON Change %_x  CRIX_x    IR_x  \
# BTC_ret_y                       0.0019              0.0045  0.0413  0.0090
# GoogleTrend_y                   0.1812              0.1994  0.0267  0.4391
# GOLD_y                          0.0001              0.0365  0.3562  0.0026
# OIL_y                           0.0000              0.0000  0.0072  0.0000
# SP500_y                         0.0000              0.0000  0.0025  0.0000
# EPU_y                           0.1929              0.4695  0.0199  0.2521
# transactions_y                  0.5392              0.0079  0.0009  0.0095
# VIX_y                           0.0060              0.0003  0.0154  0.1383
# DOWJ_y                          0.0007              0.0060  0.0000  0.0000
# USD_KZT Change %_y              0.0003              0.0000  0.0000  0.0000
# USD_INR Change %_y              1.0000              0.1558  0.0129  0.0000
# USD_RON Change %_y              0.0222              1.0000  0.0045  0.0001
# CRIX_y                          0.1097              0.0880  1.0000  0.0010
# IR_y                            0.0001              0.0003  0.0000  1.0000
# tweets_y                        0.3981              0.3614  0.0536  0.6581
#
#                     tweets_x
# BTC_ret_y             0.0039
# GoogleTrend_y         0.0345
# GOLD_y                0.6217
# OIL_y                 0.4209
# SP500_y               0.2023
# EPU_y                 0.0530
# transactions_y        0.1325
# VIX_y                 0.1324
# DOWJ_y                0.6556
# USD_KZT Change %_y    0.5277
# USD_INR Change %_y    0.7782
# USD_RON Change %_y    0.1533
# CRIX_y                0.0002
# IR_y                  0.2419
# tweets_y              1.0000

# %% [markdown]
# ### Cointegration test-  should we do that also ?
#
# Cointegration helps to find out the statistical connection between two or more time series. When two or more time series are cointegrated, they have a long run, statistically significant relationship.

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

# %% [markdown]
# ### VAR

# %%
var = VAR(data_btc)
# Out:
# /Users/carlarunden/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'

# %%
x= var.select_order()
x.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
results = var.fit(3)
#We can check the summary of the model by.
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 25, Jan, 2022
# Time:                     15:50:11
# --------------------------------------------------------------------
# No. of Equations:         15.0000    BIC:                   -65.0734
# Nobs:                     438.000    HQIC:                  -68.9668
# Log likelihood:           7027.01    FPE:                8.93638e-32
# AIC:                     -71.5043    Det(Omega_mle):     1.99799e-32
# --------------------------------------------------------------------
# Results for equation BTC_ret
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.002323         0.002241            1.037           0.300
# L1.BTC_ret                 -0.103109         0.087313           -1.181           0.238
# L1.GoogleTrend              0.005024         0.006272            0.801           0.423
# L1.GOLD                    -0.012469         0.224923           -0.055           0.956
# L1.OIL                      0.077336         0.054595            1.417           0.157
# L1.SP500                    0.037300         0.277678            0.134           0.893
# L1.EPU                     -0.000417         0.005911           -0.071           0.944
# L1.transactions             0.020534         0.027916            0.736           0.462
# L1.VIX                     -0.029011         0.038961           -0.745           0.457
# L1.DOWJ                     0.021488         0.095153            0.226           0.821
# L1.USD_KZT Change %        -0.007518         0.006097           -1.233           0.218
# L1.USD_INR Change %         0.019681         0.007527            2.615           0.009
# L1.USD_RON Change %        -0.008355         0.006255           -1.336           0.182
# L1.CRIX                     0.017204         0.089073            0.193           0.847
# L1.IR                      -0.057937         0.028278           -2.049           0.040
# L1.tweets                  -0.000303         0.005501           -0.055           0.956
# L2.BTC_ret                 -0.084852         0.094398           -0.899           0.369
# L2.GoogleTrend             -0.003400         0.008197           -0.415           0.678
# L2.GOLD                    -0.053346         0.229490           -0.232           0.816
# L2.OIL                     -0.165842         0.056960           -2.912           0.004
# L2.SP500                    0.182299         0.286813            0.636           0.525
# L2.EPU                      0.004042         0.006399            0.632           0.528
# L2.transactions             0.007318         0.032376            0.226           0.821
# L2.VIX                      0.011370         0.039332            0.289           0.773
# L2.DOWJ                    -0.062203         0.094366           -0.659           0.510
# L2.USD_KZT Change %        -0.009120         0.006115           -1.491           0.136
# L2.USD_INR Change %        -0.011197         0.007852           -1.426           0.154
# L2.USD_RON Change %        -0.007737         0.006336           -1.221           0.222
# L2.CRIX                     0.134782         0.093820            1.437           0.151
# L2.IR                      -0.028902         0.028879           -1.001           0.317
# L2.tweets                  -0.009157         0.006086           -1.505           0.132
# L3.BTC_ret                 -0.156698         0.092540           -1.693           0.090
# L3.GoogleTrend              0.000492         0.006076            0.081           0.935
# L3.GOLD                    -0.501692         0.220200           -2.278           0.023
# L3.OIL                      0.121316         0.058594            2.070           0.038
# L3.SP500                    0.517786         0.272592            1.899           0.058
# L3.EPU                      0.001988         0.005826            0.341           0.733
# L3.transactions            -0.016389         0.028468           -0.576           0.565
# L3.VIX                      0.037148         0.038249            0.971           0.331
# L3.DOWJ                    -0.149790         0.095453           -1.569           0.117
# L3.USD_KZT Change %         0.006026         0.005378            1.120           0.263
# L3.USD_INR Change %         0.003507         0.007675            0.457           0.648
# L3.USD_RON Change %         0.005140         0.005984            0.859           0.390
# L3.CRIX                     0.079341         0.087016            0.912           0.362
# L3.IR                      -0.075606         0.028190           -2.682           0.007
# L3.tweets                   0.007223         0.005247            1.377           0.169
# ======================================================================================
#
# Results for equation GoogleTrend
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.004222         0.024639           -0.171           0.864
# L1.BTC_ret                 -2.177383         0.960074           -2.268           0.023
# L1.GoogleTrend              0.841641         0.068960           12.205           0.000
# L1.GOLD                    -1.866523         2.473206           -0.755           0.450
# L1.OIL                     -0.068681         0.600318           -0.114           0.909
# L1.SP500                   -3.130096         3.053281           -1.025           0.305
# L1.EPU                      0.015369         0.064994            0.236           0.813
# L1.transactions            -0.560214         0.306962           -1.825           0.068
# L1.VIX                      0.040493         0.428411            0.095           0.925
# L1.DOWJ                     0.460541         1.046278            0.440           0.660
# L1.USD_KZT Change %        -0.114133         0.067036           -1.703           0.089
# L1.USD_INR Change %        -0.120867         0.082770           -1.460           0.144
# L1.USD_RON Change %        -0.028709         0.068777           -0.417           0.676
# L1.CRIX                     3.349632         0.979422            3.420           0.001
# L1.IR                      -0.247784         0.310940           -0.797           0.426
# L1.tweets                  -0.028185         0.060483           -0.466           0.641
# L2.BTC_ret                 -1.247775         1.037977           -1.202           0.229
# L2.GoogleTrend              0.062548         0.090134            0.694           0.488
# L2.GOLD                    -2.139850         2.523415           -0.848           0.396
# L2.OIL                     -0.303935         0.626314           -0.485           0.627
# L2.SP500                    1.666389         3.153731            0.528           0.597
# L2.EPU                     -0.024501         0.070363           -0.348           0.728
# L2.transactions            -0.294910         0.356002           -0.828           0.407
# L2.VIX                      0.305296         0.432481            0.706           0.480
# L2.DOWJ                    -0.156162         1.037633           -0.150           0.880
# L2.USD_KZT Change %         0.026510         0.067242            0.394           0.693
# L2.USD_INR Change %         0.064147         0.086340            0.743           0.458
# L2.USD_RON Change %        -0.003872         0.069665           -0.056           0.956
# L2.CRIX                     1.001833         1.031620            0.971           0.331
# L2.IR                       0.289806         0.317548            0.913           0.361
# L2.tweets                   0.038541         0.066923            0.576           0.565
# L3.BTC_ret                 -0.977638         1.017549           -0.961           0.337
# L3.GoogleTrend             -0.009605         0.066805           -0.144           0.886
# L3.GOLD                    -0.050137         2.421267           -0.021           0.983
# L3.OIL                      0.272741         0.644283            0.423           0.672
# L3.SP500                    2.200127         2.997365            0.734           0.463
# L3.EPU                     -0.067488         0.064059           -1.054           0.292
# L3.transactions             0.329297         0.313026            1.052           0.293
# L3.VIX                     -0.567822         0.420578           -1.350           0.177
# L3.DOWJ                    -1.660996         1.049585           -1.583           0.114
# L3.USD_KZT Change %         0.052342         0.059139            0.885           0.376
# L3.USD_INR Change %        -0.015644         0.084391           -0.185           0.853
# L3.USD_RON Change %         0.022478         0.065804            0.342           0.733
# L3.CRIX                     0.958855         0.956803            1.002           0.316
# L3.IR                       0.257030         0.309968            0.829           0.407
# L3.tweets                   0.004452         0.057692            0.077           0.938
# ======================================================================================
#
# Results for equation GOLD
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.000699         0.000538           -1.299           0.194
# L1.BTC_ret                  0.041496         0.020975            1.978           0.048
# L1.GoogleTrend             -0.001643         0.001507           -1.090           0.276
# L1.GOLD                    -0.028190         0.054034           -0.522           0.602
# L1.OIL                      0.030639         0.013116            2.336           0.019
# L1.SP500                    0.123425         0.066707            1.850           0.064
# L1.EPU                      0.000628         0.001420            0.443           0.658
# L1.transactions            -0.010510         0.006706           -1.567           0.117
# L1.VIX                     -0.005334         0.009360           -0.570           0.569
# L1.DOWJ                    -0.015872         0.022859           -0.694           0.487
# L1.USD_KZT Change %         0.000475         0.001465            0.325           0.746
# L1.USD_INR Change %         0.006189         0.001808            3.422           0.001
# L1.USD_RON Change %        -0.003275         0.001503           -2.179           0.029
# L1.CRIX                    -0.051377         0.021398           -2.401           0.016
# L1.IR                      -0.019238         0.006793           -2.832           0.005
# L1.tweets                   0.001095         0.001321            0.829           0.407
# L2.BTC_ret                  0.034141         0.022677            1.506           0.132
# L2.GoogleTrend              0.003066         0.001969            1.557           0.119
# L2.GOLD                    -0.020893         0.055131           -0.379           0.705
# L2.OIL                      0.002782         0.013684            0.203           0.839
# L2.SP500                    0.142234         0.068902            2.064           0.039
# L2.EPU                     -0.000911         0.001537           -0.593           0.553
# L2.transactions             0.004418         0.007778            0.568           0.570
# L2.VIX                      0.019712         0.009449            2.086           0.037
# L2.DOWJ                     0.017884         0.022670            0.789           0.430
# L2.USD_KZT Change %        -0.001049         0.001469           -0.714           0.475
# L2.USD_INR Change %         0.001590         0.001886            0.843           0.399
# L2.USD_RON Change %         0.001105         0.001522            0.726           0.468
# L2.CRIX                    -0.013547         0.022539           -0.601           0.548
# L2.IR                      -0.000137         0.006938           -0.020           0.984
# L2.tweets                  -0.002108         0.001462           -1.442           0.149
# L3.BTC_ret                  0.005616         0.022231            0.253           0.801
# L3.GoogleTrend             -0.002377         0.001460           -1.628           0.103
# L3.GOLD                     0.021649         0.052899            0.409           0.682
# L3.OIL                     -0.000347         0.014076           -0.025           0.980
# L3.SP500                    0.156773         0.065486            2.394           0.017
# L3.EPU                     -0.003319         0.001400           -2.372           0.018
# L3.transactions            -0.000626         0.006839           -0.092           0.927
# L3.VIX                      0.026071         0.009189            2.837           0.005
# L3.DOWJ                     0.000378         0.022931            0.016           0.987
# L3.USD_KZT Change %        -0.000322         0.001292           -0.249           0.803
# L3.USD_INR Change %         0.005310         0.001844            2.880           0.004
# L3.USD_RON Change %         0.000647         0.001438            0.450           0.653
# L3.CRIX                     0.010165         0.020904            0.486           0.627
# L3.IR                      -0.014941         0.006772           -2.206           0.027
# L3.tweets                   0.001413         0.001260            1.121           0.262
# ======================================================================================
#
# Results for equation OIL
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.002440         0.002139            1.141           0.254
# L1.BTC_ret                  0.106663         0.083335            1.280           0.201
# L1.GoogleTrend             -0.000308         0.005986           -0.051           0.959
# L1.GOLD                    -0.191913         0.214675           -0.894           0.371
# L1.OIL                      0.072117         0.052108            1.384           0.166
# L1.SP500                   -0.249640         0.265026           -0.942           0.346
# L1.EPU                     -0.002063         0.005642           -0.366           0.715
# L1.transactions            -0.047981         0.026644           -1.801           0.072
# L1.VIX                     -0.030011         0.037186           -0.807           0.420
# L1.DOWJ                    -0.021019         0.090817           -0.231           0.817
# L1.USD_KZT Change %        -0.014356         0.005819           -2.467           0.014
# L1.USD_INR Change %        -0.007132         0.007184           -0.993           0.321
# L1.USD_RON Change %         0.005262         0.005970            0.881           0.378
# L1.CRIX                    -0.045873         0.085014           -0.540           0.589
# L1.IR                      -0.005794         0.026990           -0.215           0.830
# L1.tweets                   0.001398         0.005250            0.266           0.790
# L2.BTC_ret                  0.087067         0.090097            0.966           0.334
# L2.GoogleTrend              0.001937         0.007824            0.248           0.804
# L2.GOLD                    -0.332769         0.219034           -1.519           0.129
# L2.OIL                     -0.223222         0.054364           -4.106           0.000
# L2.SP500                    0.234386         0.273745            0.856           0.392
# L2.EPU                     -0.002069         0.006108           -0.339           0.735
# L2.transactions            -0.079793         0.030901           -2.582           0.010
# L2.VIX                      0.007818         0.037540            0.208           0.835
# L2.DOWJ                     0.066518         0.090067            0.739           0.460
# L2.USD_KZT Change %        -0.021906         0.005837           -3.753           0.000
# L2.USD_INR Change %         0.002632         0.007494            0.351           0.725
# L2.USD_RON Change %        -0.005068         0.006047           -0.838           0.402
# L2.CRIX                     0.036726         0.089545            0.410           0.682
# L2.IR                       0.075316         0.027563            2.732           0.006
# L2.tweets                  -0.000531         0.005809           -0.091           0.927
# L3.BTC_ret                  0.116989         0.088324            1.325           0.185
# L3.GoogleTrend             -0.002800         0.005799           -0.483           0.629
# L3.GOLD                    -0.855707         0.210167           -4.072           0.000
# L3.OIL                     -0.086850         0.055924           -1.553           0.120
# L3.SP500                   -0.277372         0.260173           -1.066           0.286
# L3.EPU                     -0.002248         0.005560           -0.404           0.686
# L3.transactions            -0.034264         0.027171           -1.261           0.207
# L3.VIX                     -0.019025         0.036506           -0.521           0.602
# L3.DOWJ                    -0.124234         0.091104           -1.364           0.173
# L3.USD_KZT Change %         0.012843         0.005133            2.502           0.012
# L3.USD_INR Change %        -0.017531         0.007325           -2.393           0.017
# L3.USD_RON Change %        -0.005642         0.005712           -0.988           0.323
# L3.CRIX                    -0.078538         0.083051           -0.946           0.344
# L3.IR                       0.021851         0.026905            0.812           0.417
# L3.tweets                   0.000749         0.005008            0.150           0.881
# ======================================================================================
#
# Results for equation SP500
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.001089         0.000698            1.561           0.119
# L1.BTC_ret                 -0.038276         0.027188           -1.408           0.159
# L1.GoogleTrend             -0.002682         0.001953           -1.374           0.170
# L1.GOLD                     0.079597         0.070038            1.136           0.256
# L1.OIL                     -0.003262         0.017000           -0.192           0.848
# L1.SP500                   -0.508387         0.086465           -5.880           0.000
# L1.EPU                     -0.000086         0.001841           -0.047           0.963
# L1.transactions             0.007705         0.008693            0.886           0.375
# L1.VIX                     -0.045282         0.012132           -3.732           0.000
# L1.DOWJ                     0.058139         0.029629            1.962           0.050
# L1.USD_KZT Change %        -0.004127         0.001898           -2.174           0.030
# L1.USD_INR Change %         0.007023         0.002344            2.996           0.003
# L1.USD_RON Change %         0.000492         0.001948            0.253           0.801
# L1.CRIX                     0.009965         0.027736            0.359           0.719
# L1.IR                      -0.004788         0.008805           -0.544           0.587
# L1.tweets                   0.002217         0.001713            1.295           0.195
# L2.BTC_ret                 -0.003066         0.029394           -0.104           0.917
# L2.GoogleTrend              0.003477         0.002552            1.362           0.173
# L2.GOLD                     0.005659         0.071460            0.079           0.937
# L2.OIL                      0.007770         0.017736            0.438           0.661
# L2.SP500                    0.059188         0.089310            0.663           0.508
# L2.EPU                      0.000406         0.001993            0.204           0.839
# L2.transactions            -0.001110         0.010082           -0.110           0.912
# L2.VIX                      0.010305         0.012247            0.841           0.400
# L2.DOWJ                     0.061044         0.029384            2.077           0.038
# L2.USD_KZT Change %        -0.001687         0.001904           -0.886           0.376
# L2.USD_INR Change %        -0.000776         0.002445           -0.318           0.751
# L2.USD_RON Change %        -0.002974         0.001973           -1.507           0.132
# L2.CRIX                     0.048229         0.029214            1.651           0.099
# L2.IR                      -0.000151         0.008993           -0.017           0.987
# L2.tweets                  -0.001852         0.001895           -0.977           0.328
# L3.BTC_ret                 -0.097636         0.028816           -3.388           0.001
# L3.GoogleTrend             -0.000762         0.001892           -0.403           0.687
# L3.GOLD                    -0.092962         0.068567           -1.356           0.175
# L3.OIL                      0.024908         0.018245            1.365           0.172
# L3.SP500                    0.046519         0.084881            0.548           0.584
# L3.EPU                     -0.000422         0.001814           -0.233           0.816
# L3.transactions            -0.005603         0.008864           -0.632           0.527
# L3.VIX                      0.001838         0.011910            0.154           0.877
# L3.DOWJ                     0.044665         0.029723            1.503           0.133
# L3.USD_KZT Change %         0.003798         0.001675            2.268           0.023
# L3.USD_INR Change %         0.002939         0.002390            1.230           0.219
# L3.USD_RON Change %         0.004375         0.001863            2.348           0.019
# L3.CRIX                     0.078046         0.027095            2.880           0.004
# L3.IR                       0.006474         0.008778            0.738           0.461
# L3.tweets                   0.000114         0.001634            0.070           0.944
# ======================================================================================
#
# Results for equation EPU
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.001368         0.018745           -0.073           0.942
# L1.BTC_ret                  1.219997         0.730421            1.670           0.095
# L1.GoogleTrend             -0.036586         0.052465           -0.697           0.486
# L1.GOLD                    -0.782267         1.881607           -0.416           0.678
# L1.OIL                     -0.284827         0.456720           -0.624           0.533
# L1.SP500                   -3.429996         2.322925           -1.477           0.140
# L1.EPU                     -0.483565         0.049447           -9.779           0.000
# L1.transactions             0.093397         0.233536            0.400           0.689
# L1.VIX                     -0.187681         0.325933           -0.576           0.565
# L1.DOWJ                     0.592273         0.796005            0.744           0.457
# L1.USD_KZT Change %         0.070244         0.051001            1.377           0.168
# L1.USD_INR Change %         0.005645         0.062971            0.090           0.929
# L1.USD_RON Change %        -0.033182         0.052326           -0.634           0.526
# L1.CRIX                    -1.533456         0.745141           -2.058           0.040
# L1.IR                       0.431494         0.236562            1.824           0.068
# L1.tweets                   0.005621         0.046015            0.122           0.903
# L2.BTC_ret                  0.081612         0.789689            0.103           0.918
# L2.GoogleTrend              0.052846         0.068574            0.771           0.441
# L2.GOLD                    -2.833446         1.919805           -1.476           0.140
# L2.OIL                      0.443298         0.476498            0.930           0.352
# L2.SP500                   -1.683696         2.399347           -0.702           0.483
# L2.EPU                     -0.242497         0.053532           -4.530           0.000
# L2.transactions             0.192009         0.270845            0.709           0.478
# L2.VIX                      0.051893         0.329030            0.158           0.875
# L2.DOWJ                    -0.027023         0.789427           -0.034           0.973
# L2.USD_KZT Change %         0.028014         0.051158            0.548           0.584
# L2.USD_INR Change %        -0.004208         0.065687           -0.064           0.949
# L2.USD_RON Change %         0.006103         0.053001            0.115           0.908
# L2.CRIX                     0.047567         0.784853            0.061           0.952
# L2.IR                       0.040179         0.241589            0.166           0.868
# L2.tweets                  -0.047735         0.050915           -0.938           0.348
# L3.BTC_ret                 -0.026923         0.774148           -0.035           0.972
# L3.GoogleTrend              0.013386         0.050825            0.263           0.792
# L3.GOLD                    -2.359573         1.842092           -1.281           0.200
# L3.OIL                     -0.292594         0.490168           -0.597           0.551
# L3.SP500                    1.451997         2.280384            0.637           0.524
# L3.EPU                     -0.229132         0.048736           -4.701           0.000
# L3.transactions             0.162543         0.238149            0.683           0.495
# L3.VIX                     -0.062224         0.319974           -0.194           0.846
# L3.DOWJ                     0.417493         0.798521            0.523           0.601
# L3.USD_KZT Change %         0.081636         0.044993            1.814           0.070
# L3.USD_INR Change %         0.064776         0.064205            1.009           0.313
# L3.USD_RON Change %        -0.037376         0.050063           -0.747           0.455
# L3.CRIX                     0.032391         0.727932            0.044           0.965
# L3.IR                      -0.020150         0.235822           -0.085           0.932
# L3.tweets                   0.005432         0.043892            0.124           0.902
# ======================================================================================
#
# Results for equation transactions
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.004047         0.004100           -0.987           0.324
# L1.BTC_ret                  0.397284         0.159763            2.487           0.013
# L1.GoogleTrend             -0.009067         0.011475           -0.790           0.429
# L1.GOLD                    -0.036893         0.411559           -0.090           0.929
# L1.OIL                      0.027353         0.099897            0.274           0.784
# L1.SP500                   -0.507076         0.508088           -0.998           0.318
# L1.EPU                      0.004904         0.010816            0.453           0.650
# L1.transactions            -0.629531         0.051081          -12.324           0.000
# L1.VIX                     -0.018469         0.071291           -0.259           0.796
# L1.DOWJ                     0.226747         0.174108            1.302           0.193
# L1.USD_KZT Change %        -0.033802         0.011155           -3.030           0.002
# L1.USD_INR Change %         0.003104         0.013773            0.225           0.822
# L1.USD_RON Change %        -0.004768         0.011445           -0.417           0.677
# L1.CRIX                    -0.109395         0.162983           -0.671           0.502
# L1.IR                      -0.102785         0.051743           -1.986           0.047
# L1.tweets                   0.008540         0.010065            0.848           0.396
# L2.BTC_ret                  0.124805         0.172727            0.723           0.470
# L2.GoogleTrend             -0.010131         0.014999           -0.675           0.499
# L2.GOLD                     0.416977         0.419914            0.993           0.321
# L2.OIL                     -0.097980         0.104223           -0.940           0.347
# L2.SP500                    0.616597         0.524803            1.175           0.240
# L2.EPU                      0.018565         0.011709            1.586           0.113
# L2.transactions            -0.286224         0.059241           -4.832           0.000
# L2.VIX                      0.067234         0.071968            0.934           0.350
# L2.DOWJ                    -0.054878         0.172669           -0.318           0.751
# L2.USD_KZT Change %         0.006014         0.011190            0.537           0.591
# L2.USD_INR Change %         0.004791         0.014368            0.333           0.739
# L2.USD_RON Change %         0.007443         0.011593            0.642           0.521
# L2.CRIX                    -0.014582         0.171669           -0.085           0.932
# L2.IR                      -0.022169         0.052842           -0.420           0.675
# L2.tweets                   0.009828         0.011136            0.882           0.378
# L3.BTC_ret                 -0.226604         0.169327           -1.338           0.181
# L3.GoogleTrend              0.014810         0.011117            1.332           0.183
# L3.GOLD                     0.990961         0.402916            2.459           0.014
# L3.OIL                     -0.003465         0.107213           -0.032           0.974
# L3.SP500                   -0.449222         0.498783           -0.901           0.368
# L3.EPU                      0.020714         0.010660            1.943           0.052
# L3.transactions            -0.016522         0.052090           -0.317           0.751
# L3.VIX                     -0.062354         0.069987           -0.891           0.373
# L3.DOWJ                     0.045937         0.174658            0.263           0.793
# L3.USD_KZT Change %         0.007967         0.009841            0.810           0.418
# L3.USD_INR Change %        -0.008854         0.014043           -0.631           0.528
# L3.USD_RON Change %         0.027313         0.010950            2.494           0.013
# L3.CRIX                     0.164682         0.159219            1.034           0.301
# L3.IR                      -0.003457         0.051581           -0.067           0.947
# L3.tweets                  -0.016261         0.009600           -1.694           0.090
# ======================================================================================
#
# Results for equation VIX
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.002080         0.004313           -0.482           0.630
# L1.BTC_ret                 -0.015440         0.168065           -0.092           0.927
# L1.GoogleTrend              0.010773         0.012072            0.892           0.372
# L1.GOLD                    -0.370030         0.432945           -0.855           0.393
# L1.OIL                     -0.090800         0.105088           -0.864           0.388
# L1.SP500                    1.698703         0.534490            3.178           0.001
# L1.EPU                      0.004169         0.011378            0.366           0.714
# L1.transactions            -0.041718         0.053735           -0.776           0.438
# L1.VIX                      0.041950         0.074995            0.559           0.576
# L1.DOWJ                    -0.384143         0.183155           -2.097           0.036
# L1.USD_KZT Change %         0.024810         0.011735            2.114           0.035
# L1.USD_INR Change %        -0.016397         0.014489           -1.132           0.258
# L1.USD_RON Change %        -0.015292         0.012040           -1.270           0.204
# L1.CRIX                     0.059858         0.171452            0.349           0.727
# L1.IR                       0.013656         0.054431            0.251           0.802
# L1.tweets                  -0.013247         0.010588           -1.251           0.211
# L2.BTC_ret                 -0.086181         0.181702           -0.474           0.635
# L2.GoogleTrend             -0.008599         0.015778           -0.545           0.586
# L2.GOLD                     0.808596         0.441734            1.831           0.067
# L2.OIL                      0.052160         0.109639            0.476           0.634
# L2.SP500                    0.000145         0.552074            0.000           1.000
# L2.EPU                      0.003388         0.012317            0.275           0.783
# L2.transactions             0.031793         0.062320            0.510           0.610
# L2.VIX                     -0.075872         0.075708           -1.002           0.316
# L2.DOWJ                    -0.292322         0.181642           -1.609           0.108
# L2.USD_KZT Change %        -0.004883         0.011771           -0.415           0.678
# L2.USD_INR Change %        -0.004200         0.015114           -0.278           0.781
# L2.USD_RON Change %         0.025167         0.012195            2.064           0.039
# L2.CRIX                    -0.080405         0.180589           -0.445           0.656
# L2.IR                      -0.017602         0.055588           -0.317           0.752
# L2.tweets                   0.005231         0.011715            0.446           0.655
# L3.BTC_ret                  0.290814         0.178126            1.633           0.103
# L3.GoogleTrend              0.001502         0.011695            0.128           0.898
# L3.GOLD                     0.733977         0.423853            1.732           0.083
# L3.OIL                     -0.204043         0.112784           -1.809           0.070
# L3.SP500                   -0.564410         0.524701           -1.076           0.282
# L3.EPU                     -0.008797         0.011214           -0.784           0.433
# L3.transactions             0.019247         0.054797            0.351           0.725
# L3.VIX                     -0.036868         0.073624           -0.501           0.617
# L3.DOWJ                     0.000760         0.183734            0.004           0.997
# L3.USD_KZT Change %        -0.021078         0.010353           -2.036           0.042
# L3.USD_INR Change %        -0.014199         0.014773           -0.961           0.336
# L3.USD_RON Change %        -0.012604         0.011519           -1.094           0.274
# L3.CRIX                    -0.154063         0.167492           -0.920           0.358
# L3.IR                       0.035594         0.054261            0.656           0.512
# L3.tweets                   0.000921         0.010099            0.091           0.927
# ======================================================================================
#
# Results for equation DOWJ
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.000959         0.001520           -0.631           0.528
# L1.BTC_ret                 -0.012274         0.059221           -0.207           0.836
# L1.GoogleTrend              0.002097         0.004254            0.493           0.622
# L1.GOLD                     0.374636         0.152558            2.456           0.014
# L1.OIL                      0.011036         0.037030            0.298           0.766
# L1.SP500                   -0.852947         0.188339           -4.529           0.000
# L1.EPU                     -0.000073         0.004009           -0.018           0.986
# L1.transactions            -0.005736         0.018935           -0.303           0.762
# L1.VIX                     -0.091855         0.026426           -3.476           0.001
# L1.DOWJ                     0.073885         0.064539            1.145           0.252
# L1.USD_KZT Change %        -0.008382         0.004135           -2.027           0.043
# L1.USD_INR Change %         0.004995         0.005106            0.978           0.328
# L1.USD_RON Change %         0.010637         0.004242            2.507           0.012
# L1.CRIX                     0.049241         0.060415            0.815           0.415
# L1.IR                       0.040315         0.019180            2.102           0.036
# L1.tweets                  -0.001449         0.003731           -0.388           0.698
# L2.BTC_ret                  0.028918         0.064027            0.452           0.652
# L2.GoogleTrend              0.003153         0.005560            0.567           0.571
# L2.GOLD                    -0.059508         0.155655           -0.382           0.702
# L2.OIL                     -0.098812         0.038634           -2.558           0.011
# L2.SP500                    0.455819         0.194536            2.343           0.019
# L2.EPU                     -0.000127         0.004340           -0.029           0.977
# L2.transactions            -0.018973         0.021960           -0.864           0.388
# L2.VIX                      0.021789         0.026677            0.817           0.414
# L2.DOWJ                     0.040569         0.064006            0.634           0.526
# L2.USD_KZT Change %        -0.004493         0.004148           -1.083           0.279
# L2.USD_INR Change %        -0.003414         0.005326           -0.641           0.522
# L2.USD_RON Change %        -0.000981         0.004297           -0.228           0.819
# L2.CRIX                     0.112956         0.063635            1.775           0.076
# L2.IR                       0.044533         0.019588            2.274           0.023
# L2.tweets                  -0.002256         0.004128           -0.547           0.585
# L3.BTC_ret                 -0.154651         0.062767           -2.464           0.014
# L3.GoogleTrend             -0.001995         0.004121           -0.484           0.628
# L3.GOLD                     0.201635         0.149354            1.350           0.177
# L3.OIL                      0.097530         0.039742            2.454           0.014
# L3.SP500                    0.340023         0.184890            1.839           0.066
# L3.EPU                     -0.000789         0.003951           -0.200           0.842
# L3.transactions            -0.016911         0.019309           -0.876           0.381
# L3.VIX                      0.020931         0.025943            0.807           0.420
# L3.DOWJ                    -0.024829         0.064743           -0.384           0.701
# L3.USD_KZT Change %         0.010158         0.003648            2.785           0.005
# L3.USD_INR Change %         0.002485         0.005206            0.477           0.633
# L3.USD_RON Change %         0.007716         0.004059            1.901           0.057
# L3.CRIX                     0.129594         0.059020            2.196           0.028
# L3.IR                       0.004993         0.019120            0.261           0.794
# L3.tweets                   0.001056         0.003559            0.297           0.767
# ======================================================================================
#
# Results for equation USD_KZT Change %
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.049246         0.019756            2.493           0.013
# L1.BTC_ret                 -0.120142         0.769818           -0.156           0.876
# L1.GoogleTrend              0.070169         0.055294            1.269           0.204
# L1.GOLD                    -6.858131         1.983096           -3.458           0.001
# L1.OIL                     -3.241220         0.481354           -6.734           0.000
# L1.SP500                    4.631690         2.448218            1.892           0.059
# L1.EPU                      0.006554         0.052115            0.126           0.900
# L1.transactions             0.169143         0.246132            0.687           0.492
# L1.VIX                      0.568992         0.343514            1.656           0.098
# L1.DOWJ                    -2.366163         0.838939           -2.820           0.005
# L1.USD_KZT Change %         0.025197         0.053752            0.469           0.639
# L1.USD_INR Change %        -0.254130         0.066368           -3.829           0.000
# L1.USD_RON Change %        -0.016481         0.055148           -0.299           0.765
# L1.CRIX                    -1.180218         0.785332           -1.503           0.133
# L1.IR                       0.587908         0.249321            2.358           0.018
# L1.tweets                  -0.037821         0.048497           -0.780           0.435
# L2.BTC_ret                 -3.740097         0.832283           -4.494           0.000
# L2.GoogleTrend             -0.042925         0.072273           -0.594           0.553
# L2.GOLD                    -2.548817         2.023355           -1.260           0.208
# L2.OIL                      0.845783         0.502199            1.684           0.092
# L2.SP500                   -5.128478         2.528762           -2.028           0.043
# L2.EPU                     -0.046470         0.056419           -0.824           0.410
# L2.transactions             0.578389         0.285454            2.026           0.043
# L2.VIX                     -0.619229         0.346777           -1.786           0.074
# L2.DOWJ                    -1.910944         0.832007           -2.297           0.022
# L2.USD_KZT Change %         0.112123         0.053917            2.080           0.038
# L2.USD_INR Change %         0.011131         0.069230            0.161           0.872
# L2.USD_RON Change %        -0.110123         0.055859           -1.971           0.049
# L2.CRIX                     0.507185         0.827186            0.613           0.540
# L2.IR                       0.327304         0.254620            1.285           0.199
# L2.tweets                   0.016998         0.053661            0.317           0.751
# L3.BTC_ret                 -1.029927         0.815903           -1.262           0.207
# L3.GoogleTrend              0.003923         0.053566            0.073           0.942
# L3.GOLD                    -3.523605         1.941450           -1.815           0.070
# L3.OIL                     -0.117115         0.516606           -0.227           0.821
# L3.SP500                   -8.658823         2.403383           -3.603           0.000
# L3.EPU                     -0.023917         0.051365           -0.466           0.641
# L3.transactions             0.132252         0.250995            0.527           0.598
# L3.VIX                     -1.323657         0.337233           -3.925           0.000
# L3.DOWJ                    -2.067172         0.841591           -2.456           0.014
# L3.USD_KZT Change %         0.096209         0.047420            2.029           0.042
# L3.USD_INR Change %        -0.010465         0.067668           -0.155           0.877
# L3.USD_RON Change %        -0.097678         0.052763           -1.851           0.064
# L3.CRIX                     0.108942         0.767195            0.142           0.887
# L3.IR                       0.027325         0.248542            0.110           0.912
# L3.tweets                  -0.017326         0.046260           -0.375           0.708
# ======================================================================================
#
# Results for equation USD_INR Change %
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.004458         0.016974           -0.263           0.793
# L1.BTC_ret                 -0.291645         0.661410           -0.441           0.659
# L1.GoogleTrend             -0.060884         0.047508           -1.282           0.200
# L1.GOLD                    -3.620084         1.703831           -2.125           0.034
# L1.OIL                      0.226626         0.413569            0.548           0.584
# L1.SP500                    3.621544         2.103453            1.722           0.085
# L1.EPU                      0.015447         0.044776            0.345           0.730
# L1.transactions            -0.022444         0.211471           -0.106           0.915
# L1.VIX                      0.854681         0.295139            2.896           0.004
# L1.DOWJ                    -0.612444         0.720797           -0.850           0.396
# L1.USD_KZT Change %         0.040245         0.046182            0.871           0.384
# L1.USD_INR Change %         0.009669         0.057021            0.170           0.865
# L1.USD_RON Change %        -0.087412         0.047382           -1.845           0.065
# L1.CRIX                     1.026416         0.674739            1.521           0.128
# L1.IR                       0.074270         0.214211            0.347           0.729
# L1.tweets                   0.021752         0.041668            0.522           0.602
# L2.BTC_ret                 -0.021701         0.715078           -0.030           0.976
# L2.GoogleTrend             -0.029973         0.062095           -0.483           0.629
# L2.GOLD                     0.934777         1.738421            0.538           0.591
# L2.OIL                      0.201834         0.431478            0.468           0.640
# L2.SP500                    2.860047         2.172655            1.316           0.188
# L2.EPU                      0.005994         0.048474            0.124           0.902
# L2.transactions            -0.049908         0.245255           -0.203           0.839
# L2.VIX                     -0.149433         0.297943           -0.502           0.616
# L2.DOWJ                    -1.618223         0.714842           -2.264           0.024
# L2.USD_KZT Change %        -0.027853         0.046324           -0.601           0.548
# L2.USD_INR Change %         0.018044         0.059481            0.303           0.762
# L2.USD_RON Change %        -0.034170         0.047993           -0.712           0.476
# L2.CRIX                    -0.503402         0.710699           -0.708           0.479
# L2.IR                      -0.331719         0.218764           -1.516           0.129
# L2.tweets                   0.039316         0.046104            0.853           0.394
# L3.BTC_ret                  0.822346         0.701005            1.173           0.241
# L3.GoogleTrend              0.087905         0.046023            1.910           0.056
# L3.GOLD                     1.195705         1.668049            0.717           0.473
# L3.OIL                     -0.344371         0.443856           -0.776           0.438
# L3.SP500                    0.531865         2.064932            0.258           0.797
# L3.EPU                     -0.015969         0.044131           -0.362           0.717
# ...
# L1.BTC_ret                  0.326781         0.085775            3.810           0.000
# L1.GoogleTrend             -0.002726         0.006161           -0.442           0.658
# L1.GOLD                     0.242681         0.220961            1.098           0.272
# L1.OIL                      0.063051         0.053634            1.176           0.240
# L1.SP500                    0.234671         0.272787            0.860           0.390
# L1.EPU                      0.006588         0.005807            1.135           0.257
# L1.transactions             0.037087         0.027425            1.352           0.176
# L1.VIX                     -0.022893         0.038275           -0.598           0.550
# L1.DOWJ                    -0.094668         0.093477           -1.013           0.311
# L1.USD_KZT Change %        -0.005038         0.005989           -0.841           0.400
# L1.USD_INR Change %         0.010430         0.007395            1.410           0.158
# L1.USD_RON Change %         0.002561         0.006145            0.417           0.677
# L1.CRIX                    -0.282642         0.087504           -3.230           0.001
# L1.IR                      -0.067863         0.027780           -2.443           0.015
# L1.tweets                   0.002034         0.005404            0.376           0.707
# L2.BTC_ret                 -0.021154         0.092735           -0.228           0.820
# L2.GoogleTrend              0.002282         0.008053            0.283           0.777
# L2.GOLD                     0.009250         0.225447            0.041           0.967
# L2.OIL                     -0.134627         0.055956           -2.406           0.016
# L2.SP500                    0.316923         0.281761            1.125           0.261
# L2.EPU                      0.005518         0.006286            0.878           0.380
# L2.transactions            -0.003322         0.031806           -0.104           0.917
# L2.VIX                      0.027774         0.038639            0.719           0.472
# L2.DOWJ                     0.048309         0.092704            0.521           0.602
# L2.USD_KZT Change %        -0.011248         0.006008           -1.872           0.061
# L2.USD_INR Change %        -0.002565         0.007714           -0.333           0.739
# L2.USD_RON Change %        -0.004257         0.006224           -0.684           0.494
# L2.CRIX                     0.157913         0.092167            1.713           0.087
# L2.IR                      -0.036489         0.028370           -1.286           0.198
# L2.tweets                  -0.013575         0.005979           -2.270           0.023
# L3.BTC_ret                 -0.041191         0.090910           -0.453           0.650
# L3.GoogleTrend              0.000828         0.005969            0.139           0.890
# L3.GOLD                    -0.547600         0.216321           -2.531           0.011
# L3.OIL                      0.083829         0.057562            1.456           0.145
# L3.SP500                    0.162439         0.267791            0.607           0.544
# L3.EPU                      0.001611         0.005723            0.281           0.778
# L3.transactions            -0.015199         0.027966           -0.543           0.587
# L3.VIX                      0.024005         0.037575            0.639           0.523
# L3.DOWJ                    -0.070302         0.093772           -0.750           0.453
# L3.USD_KZT Change %         0.005507         0.005284            1.042           0.297
# L3.USD_INR Change %        -0.002349         0.007540           -0.312           0.755
# L3.USD_RON Change %         0.002844         0.005879            0.484           0.629
# L3.CRIX                     0.046772         0.085483            0.547           0.584
# L3.IR                      -0.045236         0.027693           -1.633           0.102
# L3.tweets                   0.010434         0.005154            2.024           0.043
# ======================================================================================
#
# Results for equation IR
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.008332         0.004315           -1.931           0.053
# L1.BTC_ret                 -0.203605         0.168133           -1.211           0.226
# L1.GoogleTrend             -0.004165         0.012077           -0.345           0.730
# L1.GOLD                     0.823375         0.433121            1.901           0.057
# L1.OIL                     -0.155871         0.105131           -1.483           0.138
# L1.SP500                   -0.689440         0.534707           -1.289           0.197
# L1.EPU                      0.004720         0.011382            0.415           0.678
# L1.transactions             0.047786         0.053757            0.889           0.374
# L1.VIX                      0.049109         0.075026            0.655           0.513
# L1.DOWJ                     0.149222         0.183230            0.814           0.415
# L1.USD_KZT Change %        -0.037568         0.011740           -3.200           0.001
# L1.USD_INR Change %         0.020154         0.014495            1.390           0.164
# L1.USD_RON Change %         0.007746         0.012045            0.643           0.520
# L1.CRIX                     0.316367         0.171522            1.844           0.065
# L1.IR                      -0.140548         0.054453           -2.581           0.010
# L1.tweets                   0.002643         0.010592            0.249           0.803
# L2.BTC_ret                  0.782498         0.181776            4.305           0.000
# L2.GoogleTrend              0.007441         0.015785            0.471           0.637
# L2.GOLD                     1.038270         0.441914            2.349           0.019
# L2.OIL                      0.003701         0.109684            0.034           0.973
# L2.SP500                    0.290302         0.552298            0.526           0.599
# L2.EPU                      0.006598         0.012322            0.535           0.592
# L2.transactions            -0.028572         0.062345           -0.458           0.647
# L2.VIX                      0.166562         0.075738            2.199           0.028
# L2.DOWJ                     0.384020         0.181716            2.113           0.035
# L2.USD_KZT Change %         0.000934         0.011776            0.079           0.937
# L2.USD_INR Change %        -0.024551         0.015120           -1.624           0.104
# L2.USD_RON Change %         0.011323         0.012200            0.928           0.353
# L2.CRIX                    -0.301219         0.180663           -1.667           0.095
# L2.IR                      -0.051778         0.055611           -0.931           0.352
# L2.tweets                  -0.005734         0.011720           -0.489           0.625
# L3.BTC_ret                 -0.231491         0.178199           -1.299           0.194
# L3.GoogleTrend             -0.008668         0.011699           -0.741           0.459
# L3.GOLD                     0.409218         0.424025            0.965           0.335
# L3.OIL                     -0.110691         0.112830           -0.981           0.327
# L3.SP500                    1.248854         0.524915            2.379           0.017
# L3.EPU                      0.005061         0.011218            0.451           0.652
# L3.transactions             0.039331         0.054819            0.717           0.473
# L3.VIX                      0.273512         0.073654            3.713           0.000
# L3.DOWJ                     0.587972         0.183809            3.199           0.001
# L3.USD_KZT Change %        -0.002439         0.010357           -0.235           0.814
# L3.USD_INR Change %         0.012967         0.014779            0.877           0.380
# L3.USD_RON Change %        -0.001153         0.011524           -0.100           0.920
# L3.CRIX                     0.263098         0.167561            1.570           0.116
# L3.IR                       0.029421         0.054283            0.542           0.588
# L3.tweets                   0.015116         0.010103            1.496           0.135
# ======================================================================================
#
# Results for equation tweets
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.007274         0.027234            0.267           0.789
# L1.BTC_ret                 -1.010662         1.061179           -0.952           0.341
# L1.GoogleTrend             -0.035071         0.076222           -0.460           0.645
# L1.GOLD                    -2.565242         2.733659           -0.938           0.348
# L1.OIL                     -0.175891         0.663538           -0.265           0.791
# L1.SP500                    1.602191         3.374822            0.475           0.635
# L1.EPU                      0.007492         0.071839            0.104           0.917
# L1.transactions            -0.209798         0.339289           -0.618           0.536
# L1.VIX                      0.576575         0.473527            1.218           0.223
# L1.DOWJ                     0.170158         1.156461            0.147           0.883
# L1.USD_KZT Change %        -0.083409         0.074096           -1.126           0.260
# L1.USD_INR Change %        -0.060475         0.091486           -0.661           0.509
# L1.USD_RON Change %        -0.092293         0.076020           -1.214           0.225
# L1.CRIX                     1.708530         1.082565            1.578           0.115
# L1.IR                      -0.233436         0.343685           -0.679           0.497
# L1.tweets                   0.525012         0.066852            7.853           0.000
# L2.BTC_ret                 -1.870993         1.147286           -1.631           0.103
# L2.GoogleTrend              0.164402         0.099626            1.650           0.099
# L2.GOLD                     0.303587         2.789156            0.109           0.913
# L2.OIL                      0.167920         0.692271            0.243           0.808
# L2.SP500                    2.766743         3.485850            0.794           0.427
# L2.EPU                      0.065356         0.077773            0.840           0.401
# L2.transactions            -0.024423         0.393492           -0.062           0.951
# L2.VIX                      0.384746         0.478026            0.805           0.421
# L2.DOWJ                    -0.896109         1.146906           -0.781           0.435
# L2.USD_KZT Change %         0.040418         0.074324            0.544           0.587
# L2.USD_INR Change %         0.027977         0.095433            0.293           0.769
# L2.USD_RON Change %         0.058009         0.077001            0.753           0.451
# L2.CRIX                     1.540138         1.140260            1.351           0.177
# L2.IR                       0.349378         0.350989            0.995           0.320
# L2.tweets                   0.148755         0.073971            2.011           0.044
# L3.BTC_ret                 -1.896698         1.124707           -1.686           0.092
# L3.GoogleTrend             -0.167189         0.073840           -2.264           0.024
# L3.GOLD                    -1.207141         2.676251           -0.451           0.652
# L3.OIL                      0.136149         0.712132            0.191           0.848
# L3.SP500                    2.419103         3.313017            0.730           0.465
# L3.EPU                     -0.006437         0.070805           -0.091           0.928
# L3.transactions            -0.079226         0.345991           -0.229           0.819
# L3.VIX                     -0.589249         0.464869           -1.268           0.205
# L3.DOWJ                    -0.586291         1.160117           -0.505           0.613
# L3.USD_KZT Change %         0.082166         0.065367            1.257           0.209
# L3.USD_INR Change %         0.028799         0.093278            0.309           0.758
# L3.USD_RON Change %        -0.044756         0.072733           -0.615           0.538
# L3.CRIX                     0.804380         1.057564            0.761           0.447
# L3.IR                       0.158284         0.342610            0.462           0.644
# L3.tweets                   0.262612         0.063768            4.118           0.000
# ======================================================================================
#
# Correlation matrix of residuals
#                      BTC_ret  GoogleTrend      GOLD       OIL     SP500       EPU  transactions       VIX      DOWJ  USD_KZT Change %  USD_INR Change %  USD_RON Change %      CRIX        IR    tweets
# BTC_ret             1.000000    -0.003907  0.099144  0.161895  0.368255 -0.004847      0.053886 -0.344970  0.257359          0.007205         -0.162766         -0.101686  0.803068 -0.034375  0.057508
# GoogleTrend        -0.003907     1.000000 -0.045576 -0.042495 -0.067196  0.046943     -0.023948  0.053416 -0.066901          0.006705          0.074050         -0.013726 -0.098891  0.008021  0.679174
# GOLD                0.099144    -0.045576  1.000000  0.075825  0.114047  0.057462     -0.109606 -0.062028 -0.021160         -0.126884         -0.234310         -0.313832  0.118371 -0.049602  0.016191
# OIL                 0.161895    -0.042495  0.075825  1.000000  0.345153 -0.038317     -0.024748 -0.245944  0.218149         -0.172904         -0.215127          0.085337  0.208733  0.165560  0.002229
# SP500               0.368255    -0.067196  0.114047  0.345153  1.000000  0.021866      0.001554 -0.727172  0.635456         -0.239926         -0.326106         -0.084529  0.345782  0.132330  0.011977
# EPU                -0.004847     0.046943  0.057462 -0.038317  0.021866  1.000000      0.054428 -0.009174  0.046352         -0.071229         -0.010003         -0.088299 -0.059083 -0.066251  0.010903
# transactions        0.053886    -0.023948 -0.109606 -0.024748  0.001554  0.054428      1.000000 -0.042278  0.032117         -0.092607         -0.073887         -0.036036  0.090629 -0.079000  0.031627
# VIX                -0.344970     0.053416 -0.062028 -0.245944 -0.727172 -0.009174     -0.042278  1.000000 -0.502773          0.119689          0.168945          0.066973 -0.278856 -0.025985 -0.038623
# DOWJ                0.257359    -0.066901 -0.021160  0.218149  0.635456  0.046352      0.032117 -0.502773  1.000000         -0.214398         -0.207680         -0.089239  0.244743  0.113563 -0.016999
# USD_KZT Change %    0.007205     0.006705 -0.126884 -0.172904 -0.239926 -0.071229     -0.092607  0.119689 -0.214398          1.000000          0.158330          0.096820 -0.034592 -0.324167 -0.048393
# USD_INR Change %   -0.162766     0.074050 -0.234310 -0.215127 -0.326106 -0.010003     -0.073887  0.168945 -0.207680          0.158330          1.000000          0.293547 -0.150560  0.021252 -0.005459
# USD_RON Change %   -0.101686    -0.013726 -0.313832  0.085337 -0.084529 -0.088299     -0.036036  0.066973 -0.089239          0.096820          0.293547          1.000000 -0.119171 -0.036898  0.009673
# CRIX                0.803068    -0.098891  0.118371  0.208733  0.345782 -0.059083      0.090629 -0.278856  0.244743         -0.034592         -0.150560         -0.119171  1.000000  0.069958  0.010454
# IR                 -0.034375     0.008021 -0.049602  0.165560  0.132330 -0.066251     -0.079000 -0.025985  0.113563         -0.324167          0.021252         -0.036898  0.069958  1.000000  0.047657
# tweets              0.057508     0.679174  0.016191  0.002229  0.011977  0.010903      0.031627 -0.038623 -0.016999         -0.048393         -0.005459          0.009673  0.010454  0.047657  1.000000

# %%
results = var.fit(1)
#We can check the summary of the model by.
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 25, Jan, 2022
# Time:                     15:50:11
# --------------------------------------------------------------------
# No. of Equations:         15.0000    BIC:                   -69.0735
# Nobs:                     440.000    HQIC:                  -70.4232
# Log likelihood:           6561.58    FPE:                1.08113e-31
# AIC:                     -71.3026    Det(Omega_mle):     6.32698e-32
# --------------------------------------------------------------------
# Results for equation BTC_ret
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.003543         0.002232            1.587           0.112
# L1.BTC_ret                 -0.162917         0.079225           -2.056           0.040
# L1.GoogleTrend              0.002007         0.002849            0.704           0.481
# L1.GOLD                    -0.037481         0.213819           -0.175           0.861
# L1.OIL                      0.027696         0.052237            0.530           0.596
# L1.SP500                    0.142015         0.246853            0.575           0.565
# L1.EPU                      0.000179         0.005415            0.033           0.974
# L1.transactions             0.031297         0.023343            1.341           0.180
# L1.VIX                     -0.032384         0.037304           -0.868           0.385
# L1.DOWJ                    -0.064579         0.090797           -0.711           0.477
# L1.USD_KZT Change %         0.000069         0.005051            0.014           0.989
# L1.USD_INR Change %         0.019207         0.007390            2.599           0.009
# L1.USD_RON Change %        -0.005423         0.005758           -0.942           0.346
# L1.CRIX                     0.055684         0.078967            0.705           0.481
# L1.IR                      -0.041331         0.026561           -1.556           0.120
# L1.tweets                  -0.001896         0.002818           -0.673           0.501
# ======================================================================================
#
# Results for equation GoogleTrend
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.000502         0.023461           -0.021           0.983
# L1.BTC_ret                 -1.681689         0.832653           -2.020           0.043
# L1.GoogleTrend              0.877975         0.029941           29.323           0.000
# L1.GOLD                    -1.244292         2.247240           -0.554           0.580
# L1.OIL                     -0.083201         0.549007           -0.152           0.880
# L1.SP500                   -2.535705         2.594427           -0.977           0.328
# L1.EPU                      0.022139         0.056911            0.389           0.697
# L1.transactions            -0.430938         0.245339           -1.756           0.079
# L1.VIX                      0.206317         0.392063            0.526           0.599
# L1.DOWJ                     0.998231         0.954277            1.046           0.296
# L1.USD_KZT Change %        -0.071185         0.053082           -1.341           0.180
# L1.USD_INR Change %        -0.100884         0.077674           -1.299           0.194
# L1.USD_RON Change %         0.002057         0.060515            0.034           0.973
# L1.CRIX                     2.638468         0.829937            3.179           0.001
# L1.IR                      -0.293363         0.279157           -1.051           0.293
# L1.tweets                   0.018386         0.029612            0.621           0.535
# ======================================================================================
#
# Results for equation GOLD
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.000248         0.000529           -0.469           0.639
# L1.BTC_ret                  0.023369         0.018763            1.245           0.213
# L1.GoogleTrend             -0.000832         0.000675           -1.233           0.217
# L1.GOLD                    -0.033769         0.050640           -0.667           0.505
# L1.OIL                      0.030394         0.012371            2.457           0.014
# L1.SP500                    0.029283         0.058463            0.501           0.616
# L1.EPU                      0.000944         0.001282            0.736           0.462
# L1.transactions            -0.012466         0.005529           -2.255           0.024
# L1.VIX                     -0.014851         0.008835           -1.681           0.093
# L1.DOWJ                    -0.014073         0.021504           -0.654           0.513
# L1.USD_KZT Change %        -0.000548         0.001196           -0.458           0.647
# L1.USD_INR Change %         0.005749         0.001750            3.284           0.001
# L1.USD_RON Change %        -0.004491         0.001364           -3.293           0.001
# L1.CRIX                    -0.028315         0.018702           -1.514           0.130
# L1.IR                      -0.020085         0.006291           -3.193           0.001
# L1.tweets                   0.000429         0.000667            0.644           0.520
# ======================================================================================
#
# Results for equation OIL
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.002166         0.002219            0.976           0.329
# L1.BTC_ret                  0.117653         0.078759            1.494           0.135
# L1.GoogleTrend             -0.000077         0.002832           -0.027           0.978
# L1.GOLD                    -0.329266         0.212561           -1.549           0.121
# L1.OIL                      0.087877         0.051929            1.692           0.091
# L1.SP500                   -0.735787         0.245400           -2.998           0.003
# L1.EPU                      0.000265         0.005383            0.049           0.961
# L1.transactions            -0.016925         0.023206           -0.729           0.466
# L1.VIX                     -0.073104         0.037084           -1.971           0.049
# L1.DOWJ                     0.011380         0.090263            0.126           0.900
# L1.USD_KZT Change %        -0.008521         0.005021           -1.697           0.090
# L1.USD_INR Change %        -0.011001         0.007347           -1.497           0.134
# L1.USD_RON Change %        -0.000877         0.005724           -0.153           0.878
# L1.CRIX                    -0.095662         0.078502           -1.219           0.223
# L1.IR                       0.006221         0.026405            0.236           0.814
# L1.tweets                   0.001418         0.002801            0.506           0.613
# ======================================================================================
#
# Results for equation SP500
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.001356         0.000706            1.921           0.055
# L1.BTC_ret                 -0.077420         0.025052           -3.090           0.002
# L1.GoogleTrend              0.000026         0.000901            0.029           0.977
# L1.GOLD                     0.060567         0.067613            0.896           0.370
# L1.OIL                      0.005682         0.016518            0.344           0.731
# L1.SP500                   -0.564574         0.078059           -7.233           0.000
# L1.EPU                     -0.000962         0.001712           -0.562           0.574
# L1.transactions             0.013096         0.007382            1.774           0.076
# L1.VIX                     -0.049689         0.011796           -4.212           0.000
# L1.DOWJ                     0.053115         0.028711            1.850           0.064
# L1.USD_KZT Change %        -0.005622         0.001597           -3.520           0.000
# L1.USD_INR Change %         0.007116         0.002337            3.045           0.002
# L1.USD_RON Change %        -0.002940         0.001821           -1.615           0.106
# L1.CRIX                     0.035699         0.024970            1.430           0.153
# L1.IR                      -0.014368         0.008399           -1.711           0.087
# L1.tweets                   0.000803         0.000891            0.902           0.367
# ======================================================================================
#
# Results for equation EPU
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.002221         0.018418            0.121           0.904
# L1.BTC_ret                  1.050912         0.653659            1.608           0.108
# L1.GoogleTrend              0.012256         0.023505            0.521           0.602
# L1.GOLD                    -0.730957         1.764155           -0.414           0.679
# L1.OIL                     -0.264352         0.430988           -0.613           0.540
# L1.SP500                   -3.868073         2.036708           -1.899           0.058
# L1.EPU                     -0.380875         0.044677           -8.525           0.000
# L1.transactions            -0.018222         0.192599           -0.095           0.925
# L1.VIX                     -0.393676         0.307782           -1.279           0.201
# L1.DOWJ                     0.630785         0.749138            0.842           0.400
# L1.USD_KZT Change %         0.073702         0.041671            1.769           0.077
# L1.USD_INR Change %        -0.004229         0.060976           -0.069           0.945
# L1.USD_RON Change %         0.010503         0.047506            0.221           0.825
# L1.CRIX                    -1.523143         0.651527           -2.338           0.019
# L1.IR                       0.432336         0.219147            1.973           0.049
# L1.tweets                  -0.024079         0.023246           -1.036           0.300
# ======================================================================================
#
# Results for equation transactions
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.002693         0.004078           -0.660           0.509
# L1.BTC_ret                  0.376356         0.144736            2.600           0.009
# L1.GoogleTrend             -0.005630         0.005205           -1.082           0.279
# L1.GOLD                     0.272357         0.390626            0.697           0.486
# L1.OIL                      0.013115         0.095431            0.137           0.891
# L1.SP500                   -0.778079         0.450976           -1.725           0.084
# L1.EPU                     -0.001089         0.009893           -0.110           0.912
# L1.transactions            -0.476711         0.042646          -11.178           0.000
# L1.VIX                     -0.002479         0.068150           -0.036           0.971
# L1.DOWJ                     0.212111         0.165877            1.279           0.201
# L1.USD_KZT Change %        -0.022005         0.009227           -2.385           0.017
# L1.USD_INR Change %         0.002426         0.013502            0.180           0.857
# L1.USD_RON Change %        -0.004181         0.010519           -0.398           0.691
# L1.CRIX                    -0.081288         0.144264           -0.563           0.573
# L1.IR                      -0.121961         0.048524           -2.513           0.012
# L1.tweets                   0.003623         0.005147            0.704           0.482
# ======================================================================================
#
# Results for equation VIX
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.003106         0.004171           -0.745           0.456
# L1.BTC_ret                  0.110408         0.148021            0.746           0.456
# L1.GoogleTrend              0.002296         0.005323            0.431           0.666
# L1.GOLD                    -0.491061         0.399492           -1.229           0.219
# L1.OIL                     -0.079170         0.097597           -0.811           0.417
# L1.SP500                    1.574816         0.461211            3.415           0.001
# L1.EPU                     -0.001143         0.010117           -0.113           0.910
# L1.transactions            -0.084168         0.043614           -1.930           0.054
# L1.VIX                      0.052001         0.069697            0.746           0.456
# L1.DOWJ                    -0.260171         0.169642           -1.534           0.125
# L1.USD_KZT Change %         0.018069         0.009436            1.915           0.056
# L1.USD_INR Change %        -0.019460         0.013808           -1.409           0.159
# L1.USD_RON Change %        -0.014766         0.010758           -1.373           0.170
# L1.CRIX                     0.002152         0.147538            0.015           0.988
# L1.IR                       0.041544         0.049626            0.837           0.403
# L1.tweets                  -0.007160         0.005264           -1.360           0.174
# ======================================================================================
#
# Results for equation DOWJ
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.000211         0.001581            0.133           0.894
# L1.BTC_ret                 -0.083253         0.056120           -1.483           0.138
# L1.GoogleTrend              0.002379         0.002018            1.179           0.238
# L1.GOLD                     0.256570         0.151461            1.694           0.090
# L1.OIL                      0.018499         0.037002            0.500           0.617
# L1.SP500                   -1.046286         0.174861           -5.984           0.000
# L1.EPU                     -0.000929         0.003836           -0.242           0.809
# L1.transactions             0.014728         0.016536            0.891           0.373
# L1.VIX                     -0.090109         0.026425           -3.410           0.001
# L1.DOWJ                     0.101810         0.064317            1.583           0.113
# L1.USD_KZT Change %        -0.007748         0.003578           -2.166           0.030
# L1.USD_INR Change %         0.005850         0.005235            1.118           0.264
# L1.USD_RON Change %         0.002994         0.004079            0.734           0.463
# L1.CRIX                     0.095761         0.055937            1.712           0.087
# L1.IR                       0.031026         0.018815            1.649           0.099
# L1.tweets                  -0.000959         0.001996           -0.481           0.631
# ======================================================================================
#
# Results for equation USD_KZT Change %
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.024715         0.021441            1.153           0.249
# L1.BTC_ret                  1.860816         0.760963            2.445           0.014
# L1.GoogleTrend              0.013292         0.027363            0.486           0.627
# L1.GOLD                    -8.875103         2.053756           -4.321           0.000
# L1.OIL                     -3.850495         0.501738           -7.674           0.000
# L1.SP500                    6.736200         2.371050            2.841           0.004
# L1.EPU                      0.063125         0.052011            1.214           0.225
# L1.transactions            -0.390684         0.224216           -1.742           0.081
# L1.VIX                      0.391437         0.358307            1.092           0.275
# L1.DOWJ                    -3.586493         0.872115           -4.112           0.000
# L1.USD_KZT Change %         0.108569         0.048512            2.238           0.025
# L1.USD_INR Change %        -0.298170         0.070986           -4.200           0.000
# L1.USD_RON Change %         0.068435         0.055305            1.237           0.216
# L1.CRIX                    -3.129645         0.758481           -4.126           0.000
# L1.IR                       0.540157         0.255122            2.117           0.034
# L1.tweets                  -0.028752         0.027063           -1.062           0.288
# ======================================================================================
#
# Results for equation USD_INR Change %
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.005757         0.016345           -0.352           0.725
# L1.BTC_ret                 -0.018719         0.580114           -0.032           0.974
# L1.GoogleTrend             -0.023708         0.020860           -1.137           0.256
# L1.GOLD                    -2.440658         1.565665           -1.559           0.119
# L1.OIL                      0.117110         0.382496            0.306           0.759
# L1.SP500                    3.478612         1.807552            1.924           0.054
# L1.EPU                      0.004300         0.039650            0.108           0.914
# L1.transactions            -0.035235         0.170929           -0.206           0.837
# L1.VIX                      0.901104         0.273153            3.299           0.001
# L1.DOWJ                    -0.758341         0.664851           -1.141           0.254
# L1.USD_KZT Change %         0.053690         0.036983            1.452           0.147
# L1.USD_INR Change %        -0.002787         0.054116           -0.051           0.959
# L1.USD_RON Change %        -0.064258         0.042161           -1.524           0.127
# L1.CRIX                     0.996123         0.578222            1.723           0.085
# L1.IR                       0.134653         0.194490            0.692           0.489
# L1.tweets                   0.018302         0.020631            0.887           0.375
# ======================================================================================
#
# Results for equation USD_RON Change %
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.004775         0.019391            0.246           0.805
# L1.BTC_ret                 -0.560695         0.688192           -0.815           0.415
# L1.GoogleTrend              0.011474         0.024746            0.464           0.643
# L1.GOLD                    -2.627372         1.857356           -1.415           0.157
# L1.OIL                     -0.286633         0.453757           -0.632           0.528
# L1.SP500                   -3.714419         2.144307           -1.732           0.083
# L1.EPU                      0.028078         0.047037            0.597           0.551
# L1.transactions            -0.161985         0.202774           -0.799           0.424
# L1.VIX                     -0.178303         0.324042           -0.550           0.582
# L1.DOWJ                    -2.859635         0.788715           -3.626           0.000
# L1.USD_KZT Change %         0.106381         0.043873            2.425           0.015
# L1.USD_INR Change %        -0.075006         0.064198           -1.168           0.243
# L1.USD_RON Change %         0.032997         0.050016            0.660           0.509
# L1.CRIX                     1.117525         0.685947            1.629           0.103
# L1.IR                       0.132643         0.230725            0.575           0.565
# L1.tweets                   0.006215         0.024475            0.254           0.800
# ======================================================================================
#
# Results for equation CRIX
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.003680         0.002179            1.689           0.091
# L1.BTC_ret                  0.262970         0.077337            3.400           0.001
# L1.GoogleTrend              0.000487         0.002781            0.175           0.861
# L1.GOLD                     0.211193         0.208724            1.012           0.312
# L1.OIL                      0.024956         0.050992            0.489           0.625
# L1.SP500                    0.109605         0.240971            0.455           0.649
# L1.EPU                      0.004892         0.005286            0.925           0.355
# L1.transactions             0.046306         0.022787            2.032           0.042
# L1.VIX                     -0.045468         0.036415           -1.249           0.212
# L1.DOWJ                    -0.159495         0.088634           -1.799           0.072
# L1.USD_KZT Change %        -0.005079         0.004930           -1.030           0.303
# L1.USD_INR Change %         0.008982         0.007214            1.245           0.213
# L1.USD_RON Change %         0.001624         0.005621            0.289           0.773
# L1.CRIX                    -0.234783         0.077085           -3.046           0.002
# L1.IR                      -0.053787         0.025928           -2.074           0.038
# L1.tweets                  -0.001655         0.002750           -0.602           0.547
# ======================================================================================
#
# Results for equation IR
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.006691         0.004419           -1.514           0.130
# L1.BTC_ret                 -0.629033         0.156840           -4.011           0.000
# L1.GoogleTrend             -0.000007         0.005640           -0.001           0.999
# L1.GOLD                     1.021049         0.423295            2.412           0.016
# L1.OIL                     -0.041370         0.103412           -0.400           0.689
# L1.SP500                   -1.159450         0.488691           -2.373           0.018
# L1.EPU                     -0.001082         0.010720           -0.101           0.920
# L1.transactions             0.107221         0.046213            2.320           0.020
# L1.VIX                      0.037592         0.073850            0.509           0.611
# L1.DOWJ                     0.276822         0.179750            1.540           0.124
# L1.USD_KZT Change %        -0.047109         0.009999           -4.712           0.000
# L1.USD_INR Change %         0.024323         0.014631            1.662           0.096
# L1.USD_RON Change %        -0.007530         0.011399           -0.661           0.509
# L1.CRIX                     0.725354         0.156329            4.640           0.000
# L1.IR                      -0.166964         0.052583           -3.175           0.001
# L1.tweets                   0.007190         0.005578            1.289           0.197
# ======================================================================================
#
# Results for equation tweets
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.007313         0.027896            0.262           0.793
# L1.BTC_ret                 -1.171334         0.990045           -1.183           0.237
# L1.GoogleTrend             -0.008638         0.035601           -0.243           0.808
# L1.GOLD                    -3.237807         2.672024           -1.212           0.226
# L1.OIL                     -0.133929         0.652782           -0.205           0.837
# L1.SP500                    1.242473         3.084838            0.403           0.687
# L1.EPU                     -0.047620         0.067669           -0.704           0.482
# L1.transactions            -0.350737         0.291714           -1.202           0.229
# L1.VIX                      0.517829         0.466173            1.111           0.267
# L1.DOWJ                     0.543642         1.134659            0.479           0.632
# L1.USD_KZT Change %        -0.066420         0.063116           -1.052           0.293
# L1.USD_INR Change %        -0.056394         0.092356           -0.611           0.541
# L1.USD_RON Change %        -0.056285         0.071954           -0.782           0.434
# L1.CRIX                     1.434141         0.986816            1.453           0.146
# L1.IR                      -0.402099         0.331924           -1.211           0.226
# L1.tweets                   0.849955         0.035210           24.140           0.000
# ======================================================================================
#
# Correlation matrix of residuals
#                      BTC_ret  GoogleTrend      GOLD       OIL     SP500       EPU  transactions       VIX      DOWJ  USD_KZT Change %  USD_INR Change %  USD_RON Change %      CRIX        IR    tweets
# BTC_ret             1.000000    -0.013249  0.113657  0.168778  0.381673 -0.013165      0.057739 -0.365415  0.295581         -0.020974         -0.170440         -0.111436  0.809690 -0.020821  0.024181
# GoogleTrend        -0.013249     1.000000 -0.042624 -0.013590 -0.052658  0.068804     -0.000522  0.040291 -0.035320          0.020466          0.065268         -0.025178 -0.097231 -0.018534  0.649761
# GOLD                0.113657    -0.042624  1.000000  0.095468  0.151356  0.077135     -0.109077 -0.083364  0.059849         -0.180330         -0.240047         -0.302344  0.141782  0.008886  0.005432
# OIL                 0.168778    -0.013590  0.095468  1.000000  0.320264 -0.036072      0.008208 -0.240810  0.264598         -0.156549         -0.192005          0.051267  0.243035  0.125380  0.007086
# SP500               0.381673    -0.052658  0.151356  0.320264  1.000000  0.025754      0.017075 -0.726091  0.652602         -0.285660         -0.342367         -0.106082  0.373565  0.184165  0.004209
# EPU                -0.013165     0.068804  0.077135 -0.036072  0.025754  1.000000      0.004329 -0.026144  0.022359         -0.026538         -0.017650         -0.091608 -0.061258 -0.066656  0.016813
# transactions        0.057739    -0.000522 -0.109077  0.008208  0.017075  0.004329      1.000000 -0.053501  0.073051         -0.101778         -0.055384         -0.017831  0.091622 -0.051337  0.015851
# VIX                -0.365415     0.040291 -0.083364 -0.240810 -0.726091 -0.026144     -0.053501  1.000000 -0.498708          0.133942          0.198567          0.086528 -0.302872 -0.052000 -0.022428
# DOWJ                0.295581    -0.035320  0.059849  0.264598  0.652602  0.022359      0.073051 -0.498708  1.000000         -0.304728         -0.223645         -0.105217  0.294044  0.160901 -0.018199
# USD_KZT Change %   -0.020974     0.020466 -0.180330 -0.156549 -0.285660 -0.026538     -0.101778  0.133942 -0.304728          1.000000          0.156187          0.071381 -0.085177 -0.427267 -0.003072
# USD_INR Change %   -0.170440     0.065268 -0.240047 -0.192005 -0.342367 -0.017650     -0.055384  0.198567 -0.223645          0.156187          1.000000          0.309010 -0.154727  0.002728 -0.007543
# USD_RON Change %   -0.111436    -0.025178 -0.302344  0.051267 -0.106082 -0.091608     -0.017831  0.086528 -0.105217          0.071381          0.309010          1.000000 -0.119597 -0.037119  0.020180
# CRIX                0.809690    -0.097231  0.141782  0.243035  0.373565 -0.061258      0.091622 -0.302872  0.294044         -0.085177         -0.154727         -0.119597  1.000000  0.083818 -0.009332
# IR                 -0.020821    -0.018534  0.008886  0.125380  0.184165 -0.066656     -0.051337 -0.052000  0.160901         -0.427267          0.002728         -0.037119  0.083818  1.000000  0.026587
# tweets              0.024181     0.649761  0.005432  0.007086  0.004209  0.016813      0.015851 -0.022428 -0.018199         -0.003072         -0.007543          0.020180 -0.009332  0.026587  1.000000

# %% [markdown]
# ### Model 2: transactions, IR, EPU, DOWJ, Tweets

# %%
#Create a dataframe with the variables of the model
model2_df = data_btc[["BTC_ret", "transactions", "IR", "EPU", "DOWJ", "tweets"]]

# %%
model2_df.head()
# Out:
#              BTC_ret  transactions        IR       EPU      DOWJ    tweets
# 2020-01-06  0.047161     -0.056445  0.000000  0.313885 -0.001171 -1.199177
# 2020-01-07  0.049527      0.139940  0.000000 -0.352743  0.001236 -1.110570
# 2020-01-08 -0.010322     -0.078760  0.000000 -0.131692  0.008488 -1.113182
# 2020-01-09 -0.025165      0.012617  0.000000 -0.236952  0.004725 -1.119611
# 2020-01-10  0.035837      0.026586 -0.006473  0.036318 -0.006101 -1.164497

# %%
#First ADF test on every column
for name, column in model2_df.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "BTC_ret"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.3617
#  No. Lags Chosen       = 7
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "transactions"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -14.0723
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "IR"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.1165
#  No. Lags Chosen       = 9
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0009. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "EPU"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -18.0367
#  No. Lags Chosen       = 2
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "DOWJ"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.1328
#  No. Lags Chosen       = 8
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "tweets"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.3883
#  No. Lags Chosen       = 12
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.5879. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.

# %%
#Tweets are not stationary - transform with first difference 
model2_df_ADF = model2_df
model2_df_ADF['tweets'] = model2_df.tweets.diff()
# Out:
# <ipython-input-100-1199b2c1a627>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model2_df_ADF['tweets'] = model2_df.tweets.diff()

# %%
model2_df_ADF.dropna(inplace=True)
model2_df_ADF.head()
# Out:
# <ipython-input-116-1a18bde0f33a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model2_df_ADF.dropna(inplace=True)
#              BTC_ret  transactions        IR       EPU      DOWJ    tweets
# 2020-01-07  0.049527      0.139940  0.000000 -0.352743  0.001236  0.088607
# 2020-01-08 -0.010322     -0.078760  0.000000 -0.131692  0.008488 -0.002612
# 2020-01-09 -0.025165      0.012617  0.000000 -0.236952  0.004725 -0.006430
# 2020-01-10  0.035837      0.026586 -0.006473  0.036318 -0.006101 -0.044886
# 2020-01-13 -0.005913     -0.125942  0.000000  0.515000  0.015580 -0.059493

# %%
#Second ADF test on every column (after difference tweets)
for name, column in model2_df_ADF.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "BTC_ret"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.3095
#  No. Lags Chosen       = 7
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "transactions"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -14.0586
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "IR"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.1119
#  No. Lags Chosen       = 9
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0009. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "EPU"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -18.044
#  No. Lags Chosen       = 2
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "DOWJ"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.1325
#  No. Lags Chosen       = 8
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "tweets"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -10.334
#  No. Lags Chosen       = 11
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %%
#Plot model 2
model2_df_ADF[['BTC_ret', "transactions", "IR", "EPU", "DOWJ", "tweets"]].plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
#OLS model
model2_ols = ols("BTC_ret ~ transactions + IR + EPU + DOWJ + tweets", model2_df_ADF)
fit = model2_ols.fit()
print(fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                BTC_ret   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.078
# Method:                 Least Squares   F-statistic:                     8.466
# Date:                Tue, 25 Jan 2022   Prob (F-statistic):           1.17e-07
# Time:                        16:12:25   Log-Likelihood:                 747.78
# No. Observations:                 440   AIC:                            -1484.
# Df Residuals:                     434   BIC:                            -1459.
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.0037      0.002      1.721      0.086      -0.001       0.008
# transactions    -0.0068      0.022     -0.307      0.759      -0.051       0.037
# IR              -0.0309      0.022     -1.391      0.165      -0.075       0.013
# EPU             -0.0041      0.005     -0.788      0.431      -0.014       0.006
# DOWJ             0.4134      0.064      6.474      0.000       0.288       0.539
# tweets           0.0026      0.004      0.738      0.461      -0.004       0.010
# ==============================================================================
# Omnibus:                      232.443   Durbin-Watson:                   2.190
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4945.911
# Skew:                          -1.776   Prob(JB):                         0.00
# Kurtosis:                      19.036   Cond. No.                         30.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Select lag length
var_model2 = VAR(model2_df_ADF)
selectioncriteria_model2= var_model2.select_order()
selectioncriteria_model2.summary()
# Out:
# /Users/carlarunden/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
#VAR model based on AIC and FPE - lag 4
var_model2_lag4 = var_model2.fit(4)
var_model2_lag4.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 25, Jan, 2022
# Time:                     16:19:25
# --------------------------------------------------------------------
# No. of Equations:         6.00000    BIC:                   -24.5328
# Nobs:                     436.000    HQIC:                  -25.3820
# Log likelihood:           2092.04    FPE:                5.45260e-12
# AIC:                     -25.9357    Det(Omega_mle):     3.90226e-12
# --------------------------------------------------------------------
# Results for equation BTC_ret
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.002460         0.002237            1.100           0.271
# L1.BTC_ret             -0.097885         0.051449           -1.903           0.057
# L1.transactions         0.027153         0.027280            0.995           0.320
# L1.IR                  -0.039090         0.024855           -1.573           0.116
# L1.EPU                  0.002105         0.005929            0.355           0.723
# L1.DOWJ                 0.051770         0.072876            0.710           0.477
# L1.tweets               0.007983         0.004100            1.947           0.052
# L2.BTC_ret              0.044060         0.051151            0.861           0.389
# L2.transactions         0.008205         0.031557            0.260           0.795
# L2.IR                  -0.040617         0.024641           -1.648           0.099
# L2.EPU                  0.005322         0.006398            0.832           0.405
# L2.DOWJ                -0.058420         0.073077           -0.799           0.424
# L2.tweets              -0.001193         0.004568           -0.261           0.794
# L3.BTC_ret             -0.046712         0.054796           -0.852           0.394
# L3.transactions        -0.013117         0.031593           -0.415           0.678
# L3.IR                  -0.073621         0.024023           -3.065           0.002
# L3.EPU                  0.003098         0.006404            0.484           0.629
# L3.DOWJ                 0.069110         0.069936            0.988           0.323
# L3.tweets               0.010591         0.004552            2.326           0.020
# L4.BTC_ret              0.138374         0.053934            2.566           0.010
# L4.transactions         0.028061         0.027083            1.036           0.300
# L4.IR                  -0.001944         0.023951           -0.081           0.935
# L4.EPU                  0.004077         0.005965            0.684           0.494
# L4.DOWJ                 0.050716         0.070636            0.718           0.473
# L4.tweets              -0.002144         0.004191           -0.512           0.609
# ==================================================================================
#
# Results for equation transactions
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.004407         0.004018           -1.097           0.273
# L1.BTC_ret              0.272884         0.092405            2.953           0.003
# L1.transactions        -0.613871         0.048996          -12.529           0.000
# L1.IR                  -0.042702         0.044640           -0.957           0.339
# L1.EPU                  0.006029         0.010649            0.566           0.571
# L1.DOWJ                 0.173703         0.130888            1.327           0.184
# L1.tweets               0.000457         0.007363            0.062           0.950
# L2.BTC_ret              0.174169         0.091870            1.896           0.058
# L2.transactions        -0.315436         0.056677           -5.565           0.000
# L2.IR                   0.009724         0.044256            0.220           0.826
# L2.EPU                  0.016342         0.011490            1.422           0.155
# L2.DOWJ                 0.203248         0.131250            1.549           0.121
# L2.tweets              -0.003128         0.008204           -0.381           0.703
# L3.BTC_ret             -0.024150         0.098415           -0.245           0.806
# L3.transactions        -0.088021         0.056743           -1.551           0.121
# L3.IR                  -0.034735         0.043145           -0.805           0.421
# L3.EPU                  0.023969         0.011503            2.084           0.037
# L3.DOWJ                -0.091563         0.125607           -0.729           0.466
# L3.tweets              -0.019283         0.008176           -2.358           0.018
# L4.BTC_ret             -0.087958         0.096868           -0.908           0.364
# L4.transactions        -0.100357         0.048642           -2.063           0.039
# L4.IR                  -0.010198         0.043018           -0.237           0.813
# L4.EPU                  0.015295         0.010713            1.428           0.153
# L4.DOWJ                -0.090373         0.126865           -0.712           0.476
# L4.tweets              -0.006151         0.007528           -0.817           0.414
# ==================================================================================
#
# Results for equation IR
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.008119         0.004472           -1.816           0.069
# L1.BTC_ret             -0.012013         0.102834           -0.117           0.907
# L1.transactions         0.078107         0.054526            1.432           0.152
# L1.IR                  -0.053992         0.049678           -1.087           0.277
# L1.EPU                  0.001773         0.011850            0.150           0.881
# L1.DOWJ                -0.080624         0.145660           -0.554           0.580
# L1.tweets              -0.001999         0.008194           -0.244           0.807
# L2.BTC_ret              0.724800         0.102239            7.089           0.000
# L2.transactions        -0.048280         0.063074           -0.765           0.444
# L2.IR                   0.000217         0.049251            0.004           0.996
# L2.EPU                  0.002376         0.012787            0.186           0.853
# L2.DOWJ                 0.266579         0.146063            1.825           0.068
# L2.tweets              -0.005483         0.009130           -0.601           0.548
# L3.BTC_ret             -0.002512         0.109523           -0.023           0.982
# L3.transactions        -0.005755         0.063147           -0.091           0.927
# L3.IR                   0.076839         0.048015            1.600           0.110
# L3.EPU                 -0.002279         0.012801           -0.178           0.859
# L3.DOWJ                 0.507933         0.139784            3.634           0.000
# L3.tweets               0.000222         0.009099            0.024           0.981
# L4.BTC_ret              0.017325         0.107800            0.161           0.872
# L4.transactions        -0.020476         0.054132           -0.378           0.705
# L4.IR                   0.141568         0.047873            2.957           0.003
# L4.EPU                 -0.005113         0.011922           -0.429           0.668
# L4.DOWJ                -0.316813         0.141183           -2.244           0.025
# L4.tweets              -0.002118         0.008377           -0.253           0.800
# ==================================================================================
#
# Results for equation EPU
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.005580         0.018560           -0.301           0.764
# L1.BTC_ret             -0.350697         0.426838           -0.822           0.411
# L1.transactions        -0.002927         0.226322           -0.013           0.990
# L1.IR                   0.138134         0.206201            0.670           0.503
# L1.EPU                 -0.478176         0.049188           -9.721           0.000
# L1.DOWJ                -0.398773         0.604597           -0.660           0.510
# L1.tweets              -0.007192         0.034013           -0.211           0.833
# L2.BTC_ret             -0.254163         0.424367           -0.599           0.549
# L2.transactions         0.068760         0.261804            0.263           0.793
# L2.IR                  -0.036851         0.204426           -0.180           0.857
# L2.EPU                 -0.256744         0.053077           -4.837           0.000
# L2.DOWJ                -0.167855         0.606271           -0.277           0.782
# L2.tweets              -0.026161         0.037896           -0.690           0.490
# L3.BTC_ret             -0.084934         0.454600           -0.187           0.852
# L3.transactions        -0.006027         0.262107           -0.023           0.982
# L3.IR                  -0.150764         0.199298           -0.756           0.449
# L3.EPU                 -0.255400         0.053133           -4.807           0.000
# L3.DOWJ                -0.020108         0.580206           -0.035           0.972
# L3.tweets              -0.003629         0.037768           -0.096           0.923
# L4.BTC_ret             -0.527025         0.447452           -1.178           0.239
# L4.transactions        -0.270949         0.224686           -1.206           0.228
# L4.IR                  -0.303411         0.198708           -1.527           0.127
# L4.EPU                 -0.057847         0.049484           -1.169           0.242
# L4.DOWJ                -0.492212         0.586014           -0.840           0.401
# L4.tweets               0.011699         0.034772            0.336           0.737
# ==================================================================================
#
# Results for equation DOWJ
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.001438         0.001576           -0.912           0.362
# L1.BTC_ret             -0.028962         0.036242           -0.799           0.424
# L1.transactions        -0.003290         0.019217           -0.171           0.864
# L1.IR                   0.045963         0.017508            2.625           0.009
# L1.EPU                 -0.002548         0.004176           -0.610           0.542
# L1.DOWJ                -0.066854         0.051335           -1.302           0.193
# L1.tweets               0.001640         0.002888            0.568           0.570
# L2.BTC_ret              0.178200         0.036032            4.946           0.000
# L2.transactions        -0.038426         0.022229           -1.729           0.084
# L2.IR                   0.054412         0.017357            3.135           0.002
# L2.EPU                 -0.001848         0.004507           -0.410           0.682
# L2.DOWJ                 0.169140         0.051478            3.286           0.001
# L2.tweets              -0.000075         0.003218           -0.023           0.981
# L3.BTC_ret             -0.001258         0.038599           -0.033           0.974
# L3.transactions        -0.042380         0.022255           -1.904           0.057
# L3.IR                  -0.019853         0.016922           -1.173           0.241
# L3.EPU                 -0.002411         0.004511           -0.534           0.593
# L3.DOWJ                 0.039586         0.049264            0.804           0.422
# L3.tweets              -0.000588         0.003207           -0.183           0.855
# L4.BTC_ret              0.025717         0.037992            0.677           0.498
# L4.transactions        -0.020608         0.019078           -1.080           0.280
# L4.IR                  -0.070053         0.016872           -4.152           0.000
# L4.EPU                  0.000304         0.004202            0.072           0.942
# L4.DOWJ                -0.040766         0.049758           -0.819           0.413
# L4.tweets              -0.000438         0.002952           -0.148           0.882
# ==================================================================================
#
# Results for equation tweets
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.008928         0.026972            0.331           0.741
# L1.BTC_ret              0.199683         0.620277            0.322           0.748
# L1.transactions        -0.100254         0.328889           -0.305           0.760
# L1.IR                  -0.128436         0.299650           -0.429           0.668
# L1.EPU                 -0.022949         0.071479           -0.321           0.748
# L1.DOWJ                 0.289884         0.878594            0.330           0.741
# L1.tweets              -0.511785         0.049428          -10.354           0.000
# L2.BTC_ret             -0.170748         0.616686           -0.277           0.782
# L2.transactions         0.093741         0.380452            0.246           0.805
# L2.IR                   0.162542         0.297070            0.547           0.584
# L2.EPU                  0.051075         0.077130            0.662           0.508
# L2.DOWJ                -0.434066         0.881027           -0.493           0.622
# L2.tweets              -0.298357         0.055070           -5.418           0.000
# L3.BTC_ret             -0.408521         0.660620           -0.618           0.536
# L3.transactions        -0.024521         0.380891           -0.064           0.949
# L3.IR                  -0.029617         0.289617           -0.102           0.919
# L3.EPU                  0.025121         0.077213            0.325           0.745
# L3.DOWJ                 0.247358         0.843150            0.293           0.769
# L3.tweets              -0.186595         0.054884           -3.400           0.001
# L4.BTC_ret              0.427610         0.650233            0.658           0.511
# L4.transactions         0.177916         0.326512            0.545           0.586
# L4.IR                  -0.118028         0.288760           -0.409           0.683
# L4.EPU                  0.031267         0.071909            0.435           0.664
# L4.DOWJ                -0.027935         0.851590           -0.033           0.974
# L4.tweets              -0.064778         0.050530           -1.282           0.200
# ==================================================================================
#
# Correlation matrix of residuals
#                  BTC_ret  transactions        IR       EPU      DOWJ    tweets
# BTC_ret         1.000000      0.075144 -0.021567  0.005392  0.312198  0.065596
# transactions    0.075144      1.000000 -0.038037  0.023235  0.060574  0.032972
# IR             -0.021567     -0.038037  1.000000 -0.096704  0.171486  0.054606
# EPU             0.005392      0.023235 -0.096704  1.000000  0.026601  0.015366
# DOWJ            0.312198      0.060574  0.171486  0.026601  1.000000 -0.016141
# tweets          0.065596      0.032972  0.054606  0.015366 -0.016141  1.000000

# %%
#VAR model based on BIC - lag 1
var_model2_lag1 = var_model2.fit(1)
var_model2_lag1.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 25, Jan, 2022
# Time:                     16:20:56
# --------------------------------------------------------------------
# No. of Equations:         6.00000    BIC:                   -25.2669
# Nobs:                     439.000    HQIC:                  -25.5035
# Log likelihood:           1936.37    FPE:                7.19513e-12
# AIC:                     -25.6576    Det(Omega_mle):     6.54360e-12
# --------------------------------------------------------------------
# Results for equation BTC_ret
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.003680         0.002207            1.667           0.096
# L1.BTC_ret             -0.112902         0.049565           -2.278           0.023
# L1.transactions         0.028244         0.022974            1.229           0.219
# L1.IR                  -0.034644         0.023042           -1.504           0.133
# L1.EPU                 -0.000259         0.005345           -0.048           0.961
# L1.DOWJ                -0.004224         0.069033           -0.061           0.951
# L1.tweets               0.007496         0.003682            2.036           0.042
# ==================================================================================
#
# Results for equation transactions
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.003800         0.004066           -0.934           0.350
# L1.BTC_ret              0.255102         0.091299            2.794           0.005
# L1.transactions        -0.464166         0.042319          -10.968           0.000
# L1.IR                  -0.094646         0.042443           -2.230           0.026
# L1.EPU                 -0.001718         0.009845           -0.174           0.861
# L1.DOWJ                 0.068934         0.127160            0.542           0.588
# L1.tweets               0.003892         0.006782            0.574           0.566
# ==================================================================================
#
# Results for equation IR
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.006564         0.004722           -1.390           0.165
# L1.BTC_ret             -0.184079         0.106042           -1.736           0.083
# L1.transactions         0.151914         0.049152            3.091           0.002
# L1.IR                  -0.071361         0.049297           -1.448           0.148
# L1.EPU                 -0.005573         0.011435           -0.487           0.626
# L1.DOWJ                 0.020752         0.147693            0.141           0.888
# L1.tweets              -0.000171         0.007878           -0.022           0.983
# ==================================================================================
#
# Results for equation EPU
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.004012         0.018482           -0.217           0.828
# L1.BTC_ret             -0.235067         0.414999           -0.566           0.571
# L1.transactions        -0.087070         0.192359           -0.453           0.651
# L1.IR                   0.124149         0.192925            0.644           0.520
# L1.EPU                 -0.375741         0.044750           -8.396           0.000
# L1.DOWJ                -0.346951         0.578001           -0.600           0.548
# L1.tweets               0.001005         0.030830            0.033           0.974
# ==================================================================================
#
# Results for equation DOWJ
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.000451         0.001649           -0.273           0.784
# L1.BTC_ret             -0.049914         0.037028           -1.348           0.178
# L1.transactions         0.023884         0.017163            1.392           0.164
# L1.IR                   0.024787         0.017213            1.440           0.150
# L1.EPU                 -0.002704         0.003993           -0.677           0.498
# L1.DOWJ                -0.061698         0.051571           -1.196           0.232
# L1.tweets               0.001428         0.002751            0.519           0.604
# ==================================================================================
#
# Results for equation tweets
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.005055         0.026560            0.190           0.849
# L1.BTC_ret             -0.081506         0.596398           -0.137           0.891
# L1.transactions        -0.172278         0.276441           -0.623           0.533
# L1.IR                  -0.214859         0.277255           -0.775           0.438
# L1.EPU                 -0.036742         0.064311           -0.571           0.568
# L1.DOWJ                 0.344943         0.830651            0.415           0.678
# L1.tweets              -0.390322         0.044305           -8.810           0.000
# ==================================================================================
#
# Correlation matrix of residuals
#                  BTC_ret  transactions        IR       EPU      DOWJ    tweets
# BTC_ret         1.000000      0.045012 -0.014415 -0.012886  0.283615  0.065176
# transactions    0.045012      1.000000 -0.000884  0.001053  0.101447  0.034438
# IR             -0.014415     -0.000884  1.000000 -0.104214  0.226535  0.033930
# EPU            -0.012886      0.001053 -0.104214  1.000000  0.028012  0.014071
# DOWJ            0.283615      0.101447  0.226535  0.028012  1.000000 -0.012495
# tweets          0.065176      0.034438  0.033930  0.014071 -0.012495  1.000000

# %%
#VAR model based on HQIC - lag 2
var_model2_lag2 = var_model2.fit(2)
var_model2_lag2.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 25, Jan, 2022
# Time:                     16:21:00
# --------------------------------------------------------------------
# No. of Equations:         6.00000    BIC:                   -25.1789
# Nobs:                     438.000    HQIC:                  -25.6190
# Log likelihood:           2022.42    FPE:                5.61385e-12
# AIC:                     -25.9059    Det(Omega_mle):     4.71027e-12
# --------------------------------------------------------------------
# Results for equation BTC_ret
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.003395         0.002228            1.524           0.128
# L1.BTC_ret             -0.102410         0.050607           -2.024           0.043
# L1.transactions         0.033936         0.026321            1.289           0.197
# L1.IR                  -0.034515         0.023423           -1.474           0.141
# L1.EPU                  0.001280         0.005797            0.221           0.825
# L1.DOWJ                -0.002491         0.069816           -0.036           0.972
# L1.tweets               0.005280         0.004021            1.313           0.189
# L2.BTC_ret              0.075880         0.050629            1.499           0.134
# L2.transactions         0.021086         0.026372            0.800           0.424
# L2.IR                  -0.009782         0.023497           -0.416           0.677
# L2.EPU                  0.003289         0.005795            0.568           0.570
# L2.DOWJ                -0.044326         0.069341           -0.639           0.523
# L2.tweets              -0.006077         0.004036           -1.506           0.132
# ==================================================================================
#
# Results for equation transactions
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.004683         0.003960           -1.183           0.237
# L1.BTC_ret              0.295876         0.089964            3.289           0.001
# L1.transactions        -0.594902         0.046791          -12.714           0.000
# L1.IR                  -0.061176         0.041639           -1.469           0.142
# L1.EPU                  0.000806         0.010306            0.078           0.938
# L1.DOWJ                 0.117316         0.124112            0.945           0.345
# L1.tweets               0.005573         0.007149            0.780           0.436
# L2.BTC_ret              0.159307         0.090004            1.770           0.077
# L2.transactions        -0.268739         0.046882           -5.732           0.000
# L2.IR                  -0.004536         0.041770           -0.109           0.914
# L2.EPU                  0.006163         0.010301            0.598           0.550
# L2.DOWJ                 0.135616         0.123268            1.100           0.271
# L2.tweets               0.006936         0.007175            0.967           0.334
# ==================================================================================
#
# Results for equation IR
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.009197         0.004480           -2.053           0.040
# L1.BTC_ret             -0.105204         0.101776           -1.034           0.301
# L1.transactions         0.086026         0.052934            1.625           0.104
# L1.IR                  -0.046877         0.047106           -0.995           0.320
# L1.EPU                 -0.001388         0.011659           -0.119           0.905
# L1.DOWJ                 0.090025         0.140408            0.641           0.521
# L1.tweets              -0.001691         0.008088           -0.209           0.834
# L2.BTC_ret              0.675922         0.101821            6.638           0.000
# L2.transactions        -0.048119         0.053038           -0.907           0.364
# L2.IR                  -0.037273         0.047255           -0.789           0.430
# L2.EPU                  0.000278         0.011654            0.024           0.981
# L2.DOWJ                 0.312075         0.139453            2.238           0.025
# L2.tweets              -0.003456         0.008117           -0.426           0.670
# ==================================================================================
#
# Results for equation EPU
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.004676         0.018536           -0.252           0.801
# L1.BTC_ret             -0.223662         0.421114           -0.531           0.595
# L1.transactions        -0.053819         0.219024           -0.246           0.806
# L1.IR                   0.085537         0.194911            0.439           0.661
# L1.EPU                 -0.432149         0.048242           -8.958           0.000
# L1.DOWJ                -0.409230         0.580960           -0.704           0.481
# L1.tweets              -0.011039         0.033464           -0.330           0.741
# L2.BTC_ret             -0.182685         0.421302           -0.434           0.665
# L2.transactions         0.028545         0.219453            0.130           0.897
# L2.IR                  -0.055144         0.195524           -0.282           0.778
# L2.EPU                 -0.139850         0.048219           -2.900           0.004
# L2.DOWJ                -0.557580         0.577007           -0.966           0.334
# L2.tweets              -0.026457         0.033584           -0.788           0.431
# ==================================================================================
#
# Results for equation DOWJ
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.000748         0.001559           -0.480           0.631
# L1.BTC_ret             -0.011768         0.035422           -0.332           0.740
# L1.transactions         0.008982         0.018423            0.488           0.626
# L1.IR                   0.039324         0.016395            2.399           0.016
# L1.EPU                 -0.002156         0.004058           -0.531           0.595
# L1.DOWJ                -0.063284         0.048867           -1.295           0.195
# L1.tweets               0.001529         0.002815            0.543           0.587
# L2.BTC_ret              0.191680         0.035438            5.409           0.000
# L2.transactions        -0.015211         0.018459           -0.824           0.410
# L2.IR                   0.060838         0.016447            3.699           0.000
# L2.EPU                  0.000080         0.004056            0.020           0.984
# L2.DOWJ                 0.109718         0.048535            2.261           0.024
# L2.tweets              -0.000391         0.002825           -0.138           0.890
# ==================================================================================
#
# Results for equation tweets
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.008075         0.026374            0.306           0.759
# L1.BTC_ret              0.206814         0.599163            0.345           0.730
# L1.transactions        -0.078521         0.311629           -0.252           0.801
# L1.IR                  -0.178679         0.277320           -0.644           0.519
# L1.EPU                 -0.020647         0.068639           -0.301           0.764
# L1.DOWJ                 0.175672         0.826594            0.213           0.832
# L1.tweets              -0.470404         0.047613           -9.880           0.000
# L2.BTC_ret             -0.265979         0.599432           -0.444           0.657
# L2.transactions         0.074597         0.312240            0.239           0.811
# L2.IR                   0.226257         0.278193            0.813           0.416
# L2.EPU                  0.049210         0.068607            0.717           0.473
# L2.DOWJ                -0.413755         0.820969           -0.504           0.614
# L2.tweets              -0.206981         0.047783           -4.332           0.000
# ==================================================================================
#
# Correlation matrix of residuals
#                  BTC_ret  transactions        IR       EPU      DOWJ    tweets
# BTC_ret         1.000000      0.056439 -0.037784 -0.012623  0.298260  0.053941
# transactions    0.056439      1.000000 -0.045078  0.013330  0.067180  0.049270
# IR             -0.037784     -0.045078  1.000000 -0.096298  0.137417  0.048075
# EPU            -0.012623      0.013330 -0.096298  1.000000  0.050208  0.009536
# DOWJ            0.298260      0.067180  0.137417  0.050208  1.000000 -0.007890
# tweets          0.053941      0.049270  0.048075  0.009536 -0.007890  1.000000

# %% [markdown]
# ### Model 3: gold, oil, S&P, IR, google trend

# %%
data_m3 = data_btc.filter(['BTC_ret','GoogleTrend','GOLD','OIL','SP500'], axis=1)
# data_m3.index = pd.DatetimeIndex(data_m3.index).to_period('D')

# %%
data_m3 = data_m3.merge(yahoofin_IR.IR, how='left', right_index=True, left_index=True)

# %%
# from sklearn import preprocessing

# %%
# #normalizing instead of standardizing (with standard scaler) the Google Trend; 
# GoogleTrend_norm = pd.DataFrame(preprocessing.normalize([df_x.Bitcoin]))
# GoogleTrend_norm = GoogleTrend_norm.transpose()
# GoogleTrend_norm.index=df_x.index
# # GoogleTrend_norm.head()
# # GoogleTrend_norm.describe()
# GoogleTrend_norm.info()

# %%
#making Google Trend stationary by taking the first difference
data_m3['GT_change'] = data_m3.GoogleTrend.diff()

# %%
# data_m3 = data_m3.merge(GoogleTrend_norm, how='left', right_index=True, left_index=True)
# data_m3 = data_m3.rename(columns = {0:'GoogleTrend_norm'})
data_m3.dropna(inplace=True)

# %%
for name, column in data_m3.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "BTC_ret"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.3095
#  No. Lags Chosen       = 7
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "GoogleTrend"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.699
#  No. Lags Chosen       = 18
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.4316. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "GOLD"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -11.8164
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.445
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "OIL"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.3008
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0004. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "SP500"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.1026
#  No. Lags Chosen       = 11
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "IR"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.2174
#  No. Lags Chosen       = 16
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0006. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "GT_change"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -8.8315
#  No. Lags Chosen       = 17
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.868
#  Critical value 10%    = -2.57
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %%
# model_3.info()
# data_m3.head()
data_m3.describe()
# print(data_m3.columns)
# Out:
#           BTC_ret  GoogleTrend        GOLD         OIL       SP500  \
# count  440.000000   440.000000  440.000000  440.000000  440.000000
# mean     0.003603     0.025178   -0.000067    0.001766    0.000795
# std      0.046385     1.043234    0.011304    0.046174    0.016557
# min     -0.464730    -1.132656   -0.051069   -0.282206   -0.127652
# 25%     -0.015440    -0.696358   -0.004489   -0.012115   -0.004380
# 50%      0.002509    -0.337196    0.000528    0.002380    0.001676
# 75%      0.025238     0.352685    0.006064    0.016815    0.007842
# max      0.171821     5.102467    0.041633    0.319634    0.088808
#
#                IR   GT_change
# count  440.000000  440.000000
# mean     0.225386    0.000190
# std      0.430062    0.502305
# min      0.040000   -2.170723
# 25%      0.070000   -0.146075
# 50%      0.090000   -0.014463
# 75%      0.092500    0.090474
# max      1.600000    3.862562

# %%
data_m3[['BTC_ret', 'OIL', 'GOLD', 'SP500', 'GT_change', 'IR']].plot(figsize=(20,10))
# data_m3[['BTC_ret', 'OIL', 'GOLD', 'SP500', 'GoogleTrend', 'IR']].plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
# model_3 = ols("BTC_ret ~ OIL + GOLD + SP500 + GoogleTrend + IR", data_m3)
# fit_3 = model_3.fit()
# print(fit_3.summary())

# %%
#model with stationary Google Trend
model_GT_diff = ols("BTC_ret ~ OIL + GOLD + SP500 + GT_change + IR", data_m3)
fit_GT_diff = model_GT_diff.fit()
print(fit_GT_diff.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                BTC_ret   R-squared:                       0.151
# Model:                            OLS   Adj. R-squared:                  0.141
# Method:                 Least Squares   F-statistic:                     15.44
# Date:                Tue, 25 Jan 2022   Prob (F-statistic):           5.54e-14
# Time:                        15:51:06   Log-Likelihood:                 763.32
# No. Observations:                 440   AIC:                            -1515.
# Df Residuals:                     434   BIC:                            -1490.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0030      0.002      1.306      0.192      -0.002       0.008
# OIL            0.0304      0.047      0.646      0.518      -0.062       0.123
# GOLD           0.3072      0.184      1.673      0.095      -0.054       0.668
# SP500          1.0048      0.131      7.647      0.000       0.747       1.263
# GT_change     -0.0009      0.004     -0.227      0.820      -0.009       0.007
# IR            -0.0012      0.005     -0.249      0.804      -0.011       0.008
# ==============================================================================
# Omnibus:                      166.424   Durbin-Watson:                   2.138
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2401.366
# Skew:                          -1.206   Prob(JB):                         0.00
# Kurtosis:                      14.188   Cond. No.                         92.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
data_m3_1 = data_m3.drop(columns=['GoogleTrend'])

# %%
var_m3 = VAR(data_m3_1)
# Out:
# /Users/carlarunden/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'

# %%
order_m3 = var_m3.select_order()
order_m3.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
#the select_order function suggests the lag of 11 (based on AIC and FPE)
results_var_m3_11 = var_m3.fit(11)
#We can check the summary of the model by.
results_var_m3_11.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 25, Jan, 2022
# Time:                     16:16:06
# --------------------------------------------------------------------
# No. of Equations:         6.00000    BIC:                   -34.4515
# Nobs:                     429.000    HQIC:                  -36.7544
# Log likelihood:           4955.86    FPE:                2.46466e-17
# AIC:                     -38.2574    Det(Omega_mle):     1.03184e-17
# --------------------------------------------------------------------
# Results for equation BTC_ret
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.004018         0.002643            1.520           0.128
# L1.BTC_ret            0.034562         0.054835            0.630           0.529
# L1.GOLD              -0.023368         0.192578           -0.121           0.903
# L1.OIL               -0.009698         0.057185           -0.170           0.865
# L1.SP500              0.267736         0.185764            1.441           0.150
# L1.IR                 0.010746         0.059536            0.180           0.857
# L1.GT_change          0.006187         0.004218            1.467           0.142
# L2.BTC_ret            0.026065         0.054776            0.476           0.634
# L2.GOLD               0.161683         0.190292            0.850           0.396
# L2.OIL               -0.063205         0.057790           -1.094           0.274
# L2.SP500             -0.049152         0.187543           -0.262           0.793
# L2.IR                -0.073514         0.083238           -0.883           0.377
# L2.GT_change         -0.005940         0.004247           -1.398           0.162
# L3.BTC_ret            0.005069         0.056277            0.090           0.928
# L3.GOLD              -0.424275         0.190509           -2.227           0.026
# L3.OIL                0.067903         0.057424            1.182           0.237
# L3.SP500              0.061760         0.180269            0.343           0.732
# L3.IR                -0.028591         0.078591           -0.364           0.716
# L3.GT_change          0.003781         0.004241            0.891           0.373
# L4.BTC_ret            0.145673         0.055987            2.602           0.009
# L4.GOLD              -0.349080         0.198769           -1.756           0.079
# L4.OIL               -0.096432         0.057237           -1.685           0.092
# L4.SP500             -0.144988         0.177955           -0.815           0.415
# L4.IR                 0.097686         0.076066            1.284           0.199
# L4.GT_change         -0.006061         0.004300           -1.410           0.159
# L5.BTC_ret           -0.045641         0.056001           -0.815           0.415
# L5.GOLD              -0.139182         0.198993           -0.699           0.484
# L5.OIL                0.078027         0.056361            1.384           0.166
# L5.SP500              0.124505         0.178464            0.698           0.485
# L5.IR                -0.081240         0.078626           -1.033           0.301
# L5.GT_change          0.011382         0.004259            2.673           0.008
# L6.BTC_ret            0.025459         0.055931            0.455           0.649
# L6.GOLD               0.219285         0.199902            1.097           0.273
# L6.OIL               -0.027425         0.056342           -0.487           0.626
# L6.SP500             -0.049919         0.178440           -0.280           0.780
# L6.IR                 0.499421         0.078103            6.394           0.000
# L6.GT_change          0.000339         0.004267            0.080           0.937
# L7.BTC_ret            0.094279         0.055741            1.691           0.091
# L7.GOLD              -0.295320         0.201529           -1.465           0.143
# L7.OIL                0.023824         0.055352            0.430           0.667
# L7.SP500              0.301678         0.181343            1.664           0.096
# L7.IR                -0.660498         0.084358           -7.830           0.000
# L7.GT_change          0.002400         0.004293            0.559           0.576
# L8.BTC_ret           -0.190255         0.054570           -3.486           0.000
# L8.GOLD               0.257782         0.200674            1.285           0.199
# L8.OIL               -0.021705         0.055594           -0.390           0.696
# L8.SP500             -0.350412         0.184216           -1.902           0.057
# L8.IR                 0.304016         0.095231            3.192           0.001
# L8.GT_change          0.000348         0.004335            0.080           0.936
# L9.BTC_ret           -0.060378         0.053857           -1.121           0.262
# L9.GOLD               0.190504         0.199722            0.954           0.340
# L9.OIL               -0.005701         0.051629           -0.110           0.912
# L9.SP500              0.160488         0.186756            0.859           0.390
# L9.IR                -0.211317         0.104228           -2.027           0.043
# L9.GT_change          0.002595         0.004267            0.608           0.543
# L10.BTC_ret           0.107793         0.053560            2.013           0.044
# L10.GOLD              0.314300         0.202821            1.550           0.121
# L10.OIL              -0.071348         0.051132           -1.395           0.163
# L10.SP500             0.030285         0.188451            0.161           0.872
# L10.IR                0.156817         0.107649            1.457           0.145
# L10.GT_change        -0.005074         0.004268           -1.189           0.235
# L11.BTC_ret           0.060178         0.053414            1.127           0.260
# L11.GOLD             -0.193024         0.204692           -0.943           0.346
# L11.OIL              -0.005641         0.051345           -0.110           0.913
# L11.SP500            -0.083058         0.176921           -0.469           0.639
# L11.IR               -0.020177         0.066631           -0.303           0.762
# L11.GT_change        -0.004053         0.004284           -0.946           0.344
# ================================================================================
#
# Results for equation GOLD
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                -0.000224         0.000725           -0.309           0.757
# L1.BTC_ret            0.002753         0.015036            0.183           0.855
# L1.GOLD              -0.007306         0.052804           -0.138           0.890
# L1.OIL                0.012013         0.015680            0.766           0.444
# L1.SP500              0.164138         0.050936            3.222           0.001
# L1.IR                -0.027058         0.016325           -1.657           0.097
# L1.GT_change          0.000424         0.001157            0.367           0.714
# L2.BTC_ret           -0.000534         0.015019           -0.036           0.972
# L2.GOLD              -0.083704         0.052177           -1.604           0.109
# L2.OIL                0.001989         0.015846            0.126           0.900
# L2.SP500              0.018384         0.051423            0.357           0.721
# L2.IR                 0.053648         0.022824            2.351           0.019
# L2.GT_change          0.000468         0.001165            0.402           0.688
# L3.BTC_ret            0.013835         0.015431            0.897           0.370
# L3.GOLD               0.023174         0.052237            0.444           0.657
# L3.OIL                0.001345         0.015745            0.085           0.932
# L3.SP500             -0.049606         0.049429           -1.004           0.316
# L3.IR                -0.022847         0.021549           -1.060           0.289
# L3.GT_change         -0.000111         0.001163           -0.095           0.924
# L4.BTC_ret           -0.000211         0.015351           -0.014           0.989
# L4.GOLD              -0.108278         0.054502           -1.987           0.047
# L4.OIL               -0.003964         0.015694           -0.253           0.801
# L4.SP500              0.093795         0.048794            1.922           0.055
# L4.IR                -0.002169         0.020857           -0.104           0.917
# L4.GT_change         -0.001815         0.001179           -1.539           0.124
# L5.BTC_ret           -0.003444         0.015355           -0.224           0.823
# L5.GOLD              -0.015902         0.054563           -0.291           0.771
# L5.OIL                0.030189         0.015454            1.953           0.051
# L5.SP500              0.036236         0.048934            0.741           0.459
# L5.IR                 0.009137         0.021559            0.424           0.672
# L5.GT_change         -0.000511         0.001168           -0.438           0.662
# L6.BTC_ret            0.000741         0.015336            0.048           0.961
# L6.GOLD              -0.002836         0.054812           -0.052           0.959
# L6.OIL               -0.015768         0.015449           -1.021           0.307
# L6.SP500             -0.045968         0.048928           -0.940           0.347
# L6.IR                 0.024591         0.021416            1.148           0.251
# L6.GT_change         -0.000836         0.001170           -0.714           0.475
# L7.BTC_ret           -0.012048         0.015284           -0.788           0.431
# L7.GOLD              -0.018316         0.055258           -0.331           0.740
# L7.OIL                0.023026         0.015177            1.517           0.129
# L7.SP500             -0.044032         0.049723           -0.886           0.376
# L7.IR                -0.038614         0.023131           -1.669           0.095
# L7.GT_change          0.000503         0.001177            0.427           0.669
# L8.BTC_ret            0.001737         0.014963            0.116           0.908
# L8.GOLD               0.006860         0.055024            0.125           0.901
# L8.OIL               -0.017821         0.015244           -1.169           0.242
# L8.SP500             -0.034142         0.050511           -0.676           0.499
# L8.IR                 0.057332         0.026112            2.196           0.028
# L8.GT_change          0.000988         0.001189            0.831           0.406
# L9.BTC_ret            0.006424         0.014767            0.435           0.664
# L9.GOLD               0.017911         0.054763            0.327           0.744
# L9.OIL                0.003369         0.014156            0.238           0.812
# L9.SP500              0.012921         0.051208            0.252           0.801
# L9.IR                -0.070389         0.028579           -2.463           0.014
# L9.GT_change         -0.001173         0.001170           -1.002           0.316
# L10.BTC_ret          -0.007474         0.014686           -0.509           0.611
# L10.GOLD             -0.014091         0.055613           -0.253           0.800
# L10.OIL              -0.038112         0.014020           -2.718           0.007
# L10.SP500            -0.039867         0.051672           -0.772           0.440
# L10.IR                0.004001         0.029517            0.136           0.892
# L10.GT_change        -0.001195         0.001170           -1.021           0.307
# L11.BTC_ret           0.004394         0.014646            0.300           0.764
# L11.GOLD             -0.040531         0.056126           -0.722           0.470
# L11.OIL               0.015003         0.014079            1.066           0.287
# L11.SP500            -0.028664         0.048511           -0.591           0.555
# L11.IR                0.013513         0.018270            0.740           0.460
# L11.GT_change        -0.000889         0.001175           -0.757           0.449
# ================================================================================
#
# Results for equation OIL
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.001510         0.002391            0.632           0.528
# L1.BTC_ret            0.113167         0.049590            2.282           0.022
# L1.GOLD              -0.096861         0.174159           -0.556           0.578
# L1.OIL                0.050378         0.051716            0.974           0.330
# L1.SP500              0.222410         0.167996            1.324           0.186
# L1.IR                 0.036405         0.053842            0.676           0.499
# L1.GT_change          0.004719         0.003815            1.237           0.216
# L2.BTC_ret            0.053452         0.049537            1.079           0.281
# L2.GOLD              -0.098427         0.172091           -0.572           0.567
# L2.OIL               -0.175160         0.052262           -3.352           0.001
# L2.SP500              0.360517         0.169605            2.126           0.034
# L2.IR                 0.268422         0.075277            3.566           0.000
# L2.GT_change          0.000446         0.003841            0.116           0.908
# L3.BTC_ret            0.096505         0.050895            1.896           0.058
# L3.GOLD              -0.697964         0.172287           -4.051           0.000
# L3.OIL               -0.098576         0.051932           -1.898           0.058
# L3.SP500             -0.310494         0.163027           -1.905           0.057
# L3.IR                -0.274744         0.071074           -3.866           0.000
# L3.GT_change          0.000059         0.003835            0.015           0.988
# L4.BTC_ret            0.070967         0.050632            1.402           0.161
# L4.GOLD              -0.133230         0.179757           -0.741           0.459
# L4.OIL               -0.087308         0.051762           -1.687           0.092
# L4.SP500              0.285820         0.160934            1.776           0.076
# L4.IR                -0.106708         0.068790           -1.551           0.121
# L4.GT_change          0.004567         0.003888            1.175           0.240
# L5.BTC_ret           -0.066377         0.050644           -1.311           0.190
# L5.GOLD              -0.175597         0.179960           -0.976           0.329
# L5.OIL                0.098077         0.050970            1.924           0.054
# L5.SP500             -0.343102         0.161394           -2.126           0.034
# L5.IR                 0.184785         0.071106            2.599           0.009
# L5.GT_change          0.001442         0.003851            0.375           0.708
# L6.BTC_ret            0.049372         0.050581            0.976           0.329
# L6.GOLD               0.406584         0.180782            2.249           0.025
# L6.OIL               -0.035049         0.050953           -0.688           0.492
# L6.SP500              0.241525         0.161373            1.497           0.134
# L6.IR                -0.031150         0.070633           -0.441           0.659
# L6.GT_change         -0.004849         0.003859           -1.257           0.209
# L7.BTC_ret           -0.023955         0.050410           -0.475           0.635
# L7.GOLD              -0.298054         0.182253           -1.635           0.102
# L7.OIL                0.092079         0.050058            1.839           0.066
# L7.SP500              0.621451         0.163998            3.789           0.000
# L7.IR                -0.174873         0.076289           -2.292           0.022
# L7.GT_change         -0.001052         0.003882           -0.271           0.786
# L8.BTC_ret           -0.076705         0.049351           -1.554           0.120
# L8.GOLD               0.009058         0.181480            0.050           0.960
# L8.OIL                0.169306         0.050276            3.368           0.001
# L8.SP500             -0.245260         0.166596           -1.472           0.141
# L8.IR                 0.153957         0.086122            1.788           0.074
# L8.GT_change          0.001034         0.003920            0.264           0.792
# L9.BTC_ret            0.012082         0.048706            0.248           0.804
# L9.GOLD              -0.257915         0.180619           -1.428           0.153
# L9.OIL               -0.075499         0.046691           -1.617           0.106
# L9.SP500              0.666932         0.168894            3.949           0.000
# L9.IR                -0.062838         0.094258           -0.667           0.505
# L9.GT_change         -0.003306         0.003859           -0.857           0.392
# L10.BTC_ret          -0.008508         0.048437           -0.176           0.861
# L10.GOLD              0.223797         0.183422            1.220           0.222
# L10.OIL               0.043524         0.046241            0.941           0.347
# L10.SP500             0.239165         0.170426            1.403           0.161
# L10.IR               -0.328905         0.097353           -3.378           0.001
# L10.GT_change         0.004960         0.003860            1.285           0.199
# L11.BTC_ret          -0.078630         0.048305           -1.628           0.104
# L11.GOLD              0.124137         0.185113            0.671           0.502
# L11.OIL               0.133833         0.046434            2.882           0.004
# L11.SP500            -0.079490         0.159999           -0.497           0.619
# L11.IR                0.331339         0.060258            5.499           0.000
# L11.GT_change         0.000798         0.003874            0.206           0.837
# ================================================================================
#
# Results for equation SP500
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.002679         0.000800            3.347           0.001
# L1.BTC_ret            0.024238         0.016602            1.460           0.144
# L1.GOLD               0.004829         0.058304            0.083           0.934
# L1.OIL               -0.046596         0.017313           -2.691           0.007
# L1.SP500             -0.090663         0.056241           -1.612           0.107
# L1.IR                -0.000593         0.018025           -0.033           0.974
# L1.GT_change          0.000413         0.001277            0.323           0.746
# L2.BTC_ret            0.030807         0.016584            1.858           0.063
# L2.GOLD               0.015055         0.057612            0.261           0.794
# L2.OIL                0.035306         0.017496            2.018           0.044
# L2.SP500              0.138596         0.056780            2.441           0.015
# L2.IR                 0.033698         0.025201            1.337           0.181
# L2.GT_change          0.000127         0.001286            0.099           0.921
# L3.BTC_ret           -0.003386         0.017038           -0.199           0.842
# L3.GOLD              -0.169922         0.057678           -2.946           0.003
# L3.OIL                0.009000         0.017386            0.518           0.605
# L3.SP500             -0.033252         0.054578           -0.609           0.542
# L3.IR                 0.039292         0.023794            1.651           0.099
# L3.GT_change         -0.000076         0.001284           -0.059           0.953
# L4.BTC_ret            0.015622         0.016950            0.922           0.357
# L4.GOLD              -0.026721         0.060179           -0.444           0.657
# L4.OIL               -0.039822         0.017329           -2.298           0.022
# L4.SP500             -0.093929         0.053877           -1.743           0.081
# L4.IR                -0.096705         0.023029           -4.199           0.000
# L4.GT_change          0.000106         0.001302            0.081           0.935
# L5.BTC_ret           -0.021522         0.016955           -1.269           0.204
# L5.GOLD               0.069642         0.060246            1.156           0.248
# L5.OIL                0.011772         0.017064            0.690           0.490
# L5.SP500             -0.004882         0.054031           -0.090           0.928
# L5.IR                 0.011014         0.023805            0.463           0.644
# L5.GT_change          0.000779         0.001289            0.604           0.546
# L6.BTC_ret            0.028048         0.016933            1.656           0.098
# L6.GOLD               0.021672         0.060522            0.358           0.720
# L6.OIL               -0.029395         0.017058           -1.723           0.085
# L6.SP500             -0.082370         0.054024           -1.525           0.127
# L6.IR                 0.144316         0.023646            6.103           0.000
# L6.GT_change         -0.001516         0.001292           -1.174           0.241
# L7.BTC_ret           -0.008649         0.016876           -0.512           0.608
# L7.GOLD              -0.074259         0.061014           -1.217           0.224
# L7.OIL               -0.012921         0.016758           -0.771           0.441
# L7.SP500              0.121946         0.054903            2.221           0.026
# L7.IR                -0.247985         0.025540           -9.710           0.000
# L7.GT_change         -0.000898         0.001300           -0.691           0.490
# L8.BTC_ret           -0.021388         0.016521           -1.295           0.195
# L8.GOLD               0.020367         0.060755            0.335           0.737
# L8.OIL               -0.022666         0.016831           -1.347           0.178
# L8.SP500             -0.191504         0.055772           -3.434           0.001
# L8.IR                 0.205377         0.028832            7.123           0.000
# L8.GT_change          0.000061         0.001312            0.046           0.963
# L9.BTC_ret            0.002254         0.016306            0.138           0.890
# L9.GOLD              -0.111791         0.060467           -1.849           0.064
# L9.OIL                0.026202         0.015631            1.676           0.094
# L9.SP500              0.148318         0.056542            2.623           0.009
# L9.IR                -0.071250         0.031556           -2.258           0.024
# L9.GT_change         -0.000022         0.001292           -0.017           0.986
# L10.BTC_ret           0.021070         0.016216            1.299           0.194
# L10.GOLD             -0.023100         0.061405           -0.376           0.707
# L10.OIL              -0.032136         0.015481           -2.076           0.038
# L10.SP500             0.078150         0.057055            1.370           0.171
# L10.IR               -0.038581         0.032592           -1.184           0.237
# L10.GT_change         0.000431         0.001292            0.333           0.739
# L11.BTC_ret           0.026291         0.016171            1.626           0.104
# L11.GOLD              0.005954         0.061972            0.096           0.923
# L11.OIL              -0.017618         0.015545           -1.133           0.257
# L11.SP500            -0.161157         0.053564           -3.009           0.003
# L11.IR                0.015485         0.020173            0.768           0.443
# L11.GT_change        -0.001373         0.001297           -1.059           0.290
# ================================================================================
#
# Results for equation IR
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                -0.001600         0.002318           -0.690           0.490
# L1.BTC_ret            0.023438         0.048091            0.487           0.626
# L1.GOLD               0.257537         0.168892            1.525           0.127
# L1.OIL               -0.011578         0.050152           -0.231           0.817
# L1.SP500              0.074227         0.162916            0.456           0.649
# L1.IR                 1.003535         0.052214           19.220           0.000
# L1.GT_change         -0.001485         0.003699           -0.401           0.688
# L2.BTC_ret            0.225233         0.048039            4.689           0.000
# L2.GOLD              -0.150382         0.166887           -0.901           0.368
# L2.OIL               -0.007668         0.050682           -0.151           0.880
# L2.SP500             -0.170676         0.164476           -1.038           0.299
# L2.IR                -0.133892         0.073000           -1.834           0.067
# L2.GT_change         -0.001628         0.003725           -0.437           0.662
# L3.BTC_ret            0.017212         0.049356            0.349           0.727
# L3.GOLD               0.611483         0.167077            3.660           0.000
# L3.OIL                0.009047         0.050361            0.180           0.857
# L3.SP500              0.463778         0.158097            2.934           0.003
# L3.IR                 0.055428         0.068924            0.804           0.421
# L3.GT_change          0.001082         0.003719            0.291           0.771
# L4.BTC_ret            0.004840         0.049101            0.099           0.921
# L4.GOLD              -0.003576         0.174321           -0.021           0.984
# L4.OIL               -0.035624         0.050197           -0.710           0.478
# L4.SP500             -0.068671         0.156067           -0.440           0.660
# L4.IR                 0.124032         0.066710            1.859           0.063
# L4.GT_change         -0.000175         0.003771           -0.046           0.963
# L5.BTC_ret            0.044007         0.049113            0.896           0.370
# L5.GOLD              -0.046878         0.174518           -0.269           0.788
# L5.OIL                0.172403         0.049429            3.488           0.000
# L5.SP500              0.212063         0.156514            1.355           0.175
# L5.IR                -0.012518         0.068956           -0.182           0.856
# L5.GT_change         -0.002652         0.003735           -0.710           0.478
# L6.BTC_ret           -0.036475         0.049051           -0.744           0.457
# L6.GOLD               0.208819         0.175315            1.191           0.234
# L6.OIL               -0.095001         0.049412           -1.923           0.055
# L6.SP500              0.495610         0.156493            3.167           0.002
# L6.IR                -0.055543         0.068497           -0.811           0.417
# L6.GT_change         -0.000712         0.003743           -0.190           0.849
# L7.BTC_ret           -0.028352         0.048885           -0.580           0.562
# L7.GOLD              -0.145254         0.176741           -0.822           0.411
# L7.OIL               -0.016392         0.048544           -0.338           0.736
# L7.SP500              0.554716         0.159039            3.488           0.000
# L7.IR                -0.057867         0.073982           -0.782           0.434
# L7.GT_change         -0.002877         0.003765           -0.764           0.445
# L8.BTC_ret            0.069324         0.047858            1.449           0.147
# L8.GOLD              -0.145167         0.175992           -0.825           0.409
# L8.OIL               -0.009791         0.048756           -0.201           0.841
# L8.SP500             -0.261967         0.161558           -1.622           0.105
# L8.IR                 0.597326         0.083518            7.152           0.000
# L8.GT_change         -0.002173         0.003802           -0.572           0.568
# L9.BTC_ret           -0.071720         0.047233           -1.518           0.129
# L9.GOLD              -0.677593         0.175157           -3.868           0.000
# L9.OIL               -0.030544         0.045279           -0.675           0.500
# L9.SP500              0.444931         0.163786            2.717           0.007
# L9.IR                -0.677010         0.091408           -7.406           0.000
# L9.GT_change          0.001418         0.003742            0.379           0.705
# L10.BTC_ret          -0.013505         0.046972           -0.288           0.774
# L10.GOLD             -0.310835         0.177875           -1.747           0.081
# L10.OIL              -0.007896         0.044843           -0.176           0.860
# L10.SP500            -0.450956         0.165272           -2.729           0.006
# L10.IR                0.256954         0.094409            2.722           0.006
# L10.GT_change         0.004852         0.003743            1.296           0.195
# L11.BTC_ret          -0.006609         0.046844           -0.141           0.888
# L11.GOLD             -0.092950         0.179516           -0.518           0.605
# L11.OIL               0.032420         0.045030            0.720           0.472
# L11.SP500            -0.136857         0.155160           -0.882           0.378
# L11.IR               -0.112285         0.058436           -1.921           0.055
# L11.GT_change        -0.002050         0.003757           -0.546           0.585
# ================================================================================
#
# Results for equation GT_change
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                -0.026642         0.033047           -0.806           0.420
# L1.BTC_ret            0.682618         0.685528            0.996           0.319
# L1.GOLD              -0.045575         2.407542           -0.019           0.985
# L1.OIL               -0.250229         0.714907           -0.350           0.726
# L1.SP500             -0.828228         2.322348           -0.357           0.721
# L1.IR                 0.350334         0.744300            0.471           0.638
# L1.GT_change         -0.197941         0.052734           -3.754           0.000
# L2.BTC_ret            0.508811         0.684789            0.743           0.457
# L2.GOLD              -1.399998         2.378956           -0.588           0.556
# L2.OIL                0.418590         0.722466            0.579           0.562
# L2.SP500              0.113942         2.344591            0.049           0.961
# L2.IR                -0.496467         1.040614           -0.477           0.633
# L2.GT_change         -0.094411         0.053098           -1.778           0.075
# L3.BTC_ret            0.035055         0.703559            0.050           0.960
# L3.GOLD               0.019064         2.381669            0.008           0.994
# L3.OIL               -0.147142         0.717896           -0.205           0.838
# L3.SP500              2.371487         2.253656            1.052           0.293
# L3.IR                -0.215203         0.982512           -0.219           0.827
# L3.GT_change         -0.197471         0.053016           -3.725           0.000
# L4.BTC_ret            1.048832         0.699926            1.498           0.134
# L4.GOLD               1.149358         2.484937            0.463           0.644
# L4.OIL               -0.086823         0.715551           -0.121           0.903
# L4.SP500             -0.257960         2.224727           -0.116           0.908
# L4.IR                -0.266554         0.950948           -0.280           0.779
# L4.GT_change          0.020384         0.053754            0.379           0.705
# L5.BTC_ret           -0.441293         0.700101           -0.630           0.528
# L5.GOLD               1.992457         2.487738            0.801           0.423
# L5.OIL                0.196300         0.704607            0.279           0.781
# L5.SP500              1.829231         2.231089            0.820           0.412
# L5.IR                 0.267932         0.982958            0.273           0.785
# L5.GT_change         -0.082801         0.053239           -1.555           0.120
# L6.BTC_ret            1.103611         0.699223            1.578           0.114
# L6.GOLD               2.694202         2.499102            1.078           0.281
# L6.OIL               -0.031453         0.704369           -0.045           0.964
# L6.SP500             -1.766539         2.230792           -0.792           0.428
# L6.IR                -0.137275         0.976415           -0.141           0.888
# L6.GT_change         -0.105461         0.053350           -1.977           0.048
# L7.BTC_ret            0.907322         0.696857            1.302           0.193
# L7.GOLD               3.392419         2.519434            1.347           0.178
# L7.OIL               -1.142539         0.691992           -1.651           0.099
# L7.SP500              0.212629         2.267084            0.094           0.925
# L7.IR                -0.201827         1.054612           -0.191           0.848
# L7.GT_change         -0.149596         0.053664           -2.788           0.005
# L8.BTC_ret            0.717821         0.682215            1.052           0.293
# L8.GOLD               1.790695         2.508747            0.714           0.475
# L8.OIL                0.485643         0.695011            0.699           0.485
# L8.SP500             -1.963902         2.302994           -0.853           0.394
# L8.IR                 0.886880         1.190542            0.745           0.456
# L8.GT_change         -0.070138         0.054194           -1.294           0.196
# L9.BTC_ret            0.657598         0.673305            0.977           0.329
# L9.GOLD              -0.808394         2.496851           -0.324           0.746
# L9.OIL                0.287282         0.645442            0.445           0.656
# L9.SP500             -0.525228         2.334758           -0.225           0.822
# L9.IR                -0.042795         1.303013           -0.033           0.974
# L9.GT_change         -0.085750         0.053343           -1.608           0.108
# L10.BTC_ret           0.756808         0.669581            1.130           0.258
# L10.GOLD              2.532911         2.535593            0.999           0.318
# L10.OIL              -0.232776         0.639234           -0.364           0.716
# L10.SP500             1.472759         2.355940            0.625           0.532
# L10.IR               -0.329322         1.345792           -0.245           0.807
# L10.GT_change        -0.154650         0.053359           -2.898           0.004
# L11.BTC_ret          -0.261201         0.667758           -0.391           0.696
# L11.GOLD              0.872809         2.558978            0.341           0.733
# L11.OIL              -0.185488         0.641900           -0.289           0.773
# L11.SP500             1.428226         2.211795            0.646           0.518
# L11.IR                0.186253         0.832998            0.224           0.823
# L11.GT_change        -0.065000         0.053557           -1.214           0.225
# ================================================================================
#
# Correlation matrix of residuals
#               BTC_ret      GOLD       OIL     SP500        IR  GT_change
# BTC_ret      1.000000  0.078489  0.100930  0.293686  0.005542  -0.021130
# GOLD         0.078489  1.000000 -0.001963  0.120774  0.009640  -0.035070
# OIL          0.100930 -0.001963  1.000000  0.281787  0.042468  -0.044527
# SP500        0.293686  0.120774  0.281787  1.000000  0.038507  -0.107991
# IR           0.005542  0.009640  0.042468  0.038507  1.000000   0.011904
# GT_change   -0.021130 -0.035070 -0.044527 -0.107991  0.011904   1.000000

# %%
#the select_order function suggests the lag of 1 (based on BIC)
results_var_m3_1 = var_m3.fit(1)
#We can check the summary of the model by.
results_var_m3_1.summary()

# %%
#the select_order function suggests the lag of 2 (based on HQIC)
results_var_m3_2 = var_m3.fit(2)
#We can check the summary of the model by.
results_var_m3_2.summary()

# %% [markdown]
# #### If needed also ARDL
